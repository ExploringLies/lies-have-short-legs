# %% [markdown]
# # Imports & General stuff

# %%
def fix_layout(width:int=95):
    from IPython.core.display import display, HTML
    display(HTML('<style>.container { width:' + str(width) + '% !important; }</style>'))
    
fix_layout()
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# This notebook is dedicated to datasets analysis.
#
# Here we will concentrate on connecting our datasets into one dataframe that will later be used to extract meaningful information that can help us answer our research questions.
#
# In addition, data cleaning is performed where necessary since we will not use all the data provided. The goal of this notebook is to make data as easy as possible to use for future plotting and data story writing.
#
# So, let's dive into our data!

# %%
import os
import re
import json
import time
import datetime
from functools import reduce
from itertools import product

from json import load, JSONDecodeError
from functional import pseq, seq
import pandas as pd
import pandas_profiling
import requests
import pathlib

# necessary to load the utils, which are in src
import sys
sys.path.append('../src')

from utils import file, logging
from utils.statement_handling import extract_information, safe_json_read

from importlib import reload
import seaborn as sns
sns.set(style="whitegrid", palette="pastel")

# %matplotlib inline
import utils.statement_handling as SH
reload(SH)
# Out:
# <module 'utils.statement_handling' from '../src/utils/statement_handling.py'>

# %%
def group_and_count(df, groupby_column, with_pct=False, with_avg=False):
    result = df.groupby(groupby_column).size().sort_values(ascending=False).reset_index().rename(columns={0: 'count'})
    if with_pct:
        result['count_pct'] = result['count'] / result['count'].sum()
    if with_avg:
        result['count_avg'] = result['count'].mean()
    return result

# %%
directory_liar_dataset = "../data/liar_dataset"
directory_statements = f"{directory_liar_dataset}/statements"
directory_visualizations = "../docs/data_insight"
directory_election_results = "../data/election_results"
directory_county_data = "../data/county_data"

# %% [markdown]
# # Statements

# %%
statements = seq(pathlib.Path(directory_statements).iterdir()).map(safe_json_read)\
                               .filter(lambda x: len(x) > 0)\
                               .map(extract_information)\
                               .to_pandas()

statements['statement_date'] = pd.to_datetime(statements['statement_date'])
statements.head()
# Out:
# ERROR:root:File ../data/liar_dataset/statements/5355.json is empty or something...
# ERROR:root:File ../data/liar_dataset/statements/9.json is empty or something...
#        author_name_slug                              context        label  \
# 0        lauren-carroll  a speech at Northwestern University  mostly-true
# 1        manuela-tobias                             in an ad  barely-true
# 2  brittany-alana-davis                              remarks  mostly-true
# 3              dan-levy   a speech to the AFL-CIO Convention  barely-true
# 4        c-eugene-emery               a television interview        false
#
#         party          ruling_date  \
# 0    Democrat  2014-10-08T14:09:46
# 1  Republican  2017-08-25T11:24:04
# 2  Republican  2012-08-21T16:40:06
# 3    Democrat  2016-04-06T13:02:13
# 4   Newsmaker  2011-05-31T00:01:00
#
#                                  speaker_current_job speaker_first_name  \
# 0                                          President             Barack
# 1
# 2                U.S. representative from Fort Myers             Connie
# 3                             Presidential candidate            Hillary
# 4  President, Rhode Society for the Prevention of...               E.J.
#
#   speaker_home_state       speaker_last_name  \
# 0           Illinois                   Obama
# 1                     Senate Leadership Fund
# 2            Florida                    Mack
# 3           New York                 Clinton
# 4       Rhode Island               Finocchio
#
#                                            statement statement_date  \
# 0  The cost of health care is now the single-bigg...     2014-10-02
# 1  Says Kelli Ward hosted a town hall on chemtrai...     2017-08-22
# 2  A small business in my district needed 31 diff...     2012-08-11
# 3  When mentioning Villanova&rsquo;s buzzer-beati...     2016-04-06
# 4  Most of your serial killers, most of your peop...     2011-04-24
#
#    statement_id statement_type statement_type_description  \
# 0         10039          Claim                 blog post
# 1         14464          Claim                 blog post
# 2          6501          Claim                 blog post
# 3         12192          Claim                 blog post
# 4          3824          Claim                 blog post
#
#                  subject
# 0                Deficit
# 1    Candidate Biography
# 2  Government regulation
# 3                 Sports
# 4                Animals

# %%
statements.shape
# Out:
# (15471, 15)

# %% [markdown]
# So how to regroup all these or part of these?
# We can use the mean of communication for example:
# radio/tv/facebook/twitter/internet
# and these classes can have overlap...

# %%
statements['clean_context'] = statements['context'].apply(SH.clean_up_context)

# %%
def _count_for_last_name_(df, last_name):
    return group_and_count(df.loc[df['speaker_last_name'].str.contains(last_name, flags=re.IGNORECASE), :], 'label', with_pct=True)\
            .rename(columns={'count': f'count_{last_name}', 'count_pct': f'count_pct{last_name}'})

# %%
pd.merge(_count_for_last_name_(statements, 'obama'), _count_for_last_name_(statements, 'trump'), on='label')
# Out:
#          label  count_obama  count_pctobama  count_trump  count_pcttrump
# 0  mostly-true          169        0.267829           74        0.112977
# 1    half-true          162        0.256735           93        0.141985
# 2         true          127        0.201268           30        0.045802
# 3        false           73        0.115689          217        0.331298
# 4  barely-true           71        0.112520          137        0.209160
# 5    full-flop           13        0.020602            7        0.010687
# 6   pants-fire            9        0.014263           97        0.148092

# %%
statements['statement_date'].describe()
# Out:
# count                   15471
# unique                   3555
# top       2011-10-11 00:00:00
# freq                       26
# first     1995-04-01 00:00:00
# last      2018-11-22 00:00:00
# Name: statement_date, dtype: object

# %% [markdown]
# # Federal Election Results

# %% [markdown]
# ## Loading

# %%
pd.options.display.max_colwidth = 300
pd.options.display.max_columns = 300

# %%
from itertools import product
from functools import reduce

def add_ending(f):
    """ File ending depending on a year
    
    Parameters
    ----------
    f: str
        Name of the file
    
    ToDos:
    - do 2012 it's a special snowflake
    """
    if '2016' in f:
        return f"{f}x"
    else:
        return f


election_files = [(add_ending(f'{directory_election_results}/federalelections{year}.xls'), year) for year in [2014, 2016]]

# %%
election_results_cols_of_interest = ['CANDIDATE NAME', 'PRIMARY VOTES', 'PRIMARY %', 'STATE']

def fix_columns_election_results(df, year, type_):
    """we are only interested in the primary votes, since these reflect the opinion the most"""
    #print(df.columns)
    df = df.loc[:, election_results_cols_of_interest].rename(columns={
        'CANDIDATE NAME': 'candidate_name',
        'PRIMARY VOTES': f'primary_votes_{type_.lower()}_{year}',
        'PRIMARY %': f'primary_votes_{type_.lower()}_{year}_pct',
        'STATE': f'state_{type_.lower()}_{year}'})
              
    return df


def get_only_voting_results(df):
    return df.loc[df['CANDIDATE NAME'].notna() & df['PRIMARY VOTES'].notna() & df['CANDIDATE NAME'].ne('Scattered') & df['CANDIDATE NAME'].ne('All Others'), :]


def prep_election_results(df, year, type_):
    return fix_columns_election_results(get_only_voting_results(df), year, type_)

# %%
def combine_first(df, columns, target_column_name, drop_cols=False):
    df = df.copy()
    df[target_column_name] = df[columns[0]]
    for c in columns[1:]:
        df[target_column_name] = df[target_column_name].combine_first(df[c])
        
    if drop_cols:
        df = df.drop(columns=columns)
        
    return df

# %%
def handle_states(df):
    df = combine_first(df, [c for c in df.columns if 'state' in c], 'state')
    return df.drop(columns=[c for c in df.columns if 'state' in c and c != 'state'])

# %%
election_results = [prep_election_results(pd.read_excel(f, sheet_name=f'{year} US {type_} Results by State'), year, type_) for (f, year), type_ in product(election_files, ['Senate', 'House'])]

# we let the results as they are, merge, and then check if the person is a senator or a member of the house based on the other results
# yes they did a spelling mistake
election_results += [prep_election_results(pd.read_excel(f'{directory_election_results}/federalelections2012.xls', sheet_name=f'2012 US House & Senate Resuts'), 2012, 'all')]
election_results = reduce(lambda acc, el: pd.merge(acc, el, on='candidate_name', how='outer'), election_results)

election_results = election_results.loc[election_results['primary_votes_all_2012'].ne('Convention') & election_results['primary_votes_all_2012_pct'].ne('Convention'), :] # No clue what they mean by that, but we don't have any other data for these guys anyway

election_results = handle_states(election_results)

# Converting pct fields to numbers
for c in election_results.columns:
    if c.startswith('primary') and c.endswith('pct'):
        election_results[c] = pd.to_numeric(election_results[c])

# %% [markdown]
# ## Number of useful politicians / election results

# %% [markdown]
# **Comments**
#
# - currently only politicians which participated in at least two elections are considered "interesting"
#
#
# **TODO**
#
# - for the politician for which we have data for a prior election, find out why they are no longer part of it

# %%
election_results.head()
# Out:
#        candidate_name primary_votes_senate_2014  \
# 0      Sessions, Jeff                 Unopposed
# 1       Sullivan, Dan                     44740
# 2         Miller, Joe                     35904
# 3     Treadwell, Mead                     27807
# 4  Jaramillo, John M.                      3246
#
#    primary_votes_senate_2014_pct primary_votes_house_2014  \
# 0                            NaN                      NaN
# 1                       0.400548                      NaN
# 2                       0.321441                      NaN
# 3                       0.248950                      NaN
# 4                       0.029061                      NaN
#
#    primary_votes_house_2014_pct primary_votes_senate_2016  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    primary_votes_senate_2016_pct primary_votes_house_2016  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
#
#    primary_votes_house_2016_pct primary_votes_all_2012  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#    primary_votes_all_2012_pct    state
# 0                         NaN  Alabama
# 1                         NaN   Alaska
# 2                         NaN   Alaska
# 3                         NaN   Alaska
# 4                         NaN   Alaska

# %%
election_results.shape
# Out:
# (5653, 12)

# %%
idx_multiple_election_results = election_results.loc[:, [c for c in election_results.columns if any((c.endswith(str(y)) for y in [2012, 2014, 2016]))]].notna().sum(axis=1) > 1

print(f"we have multple election results for {idx_multiple_election_results.sum()} politicians ({idx_multiple_election_results.mean()}%)")
# Out:
# we have multple election results for 1110 politicians (0.19635591721209977%)

# %%
election_results[idx_multiple_election_results].head()
# Out:
#               candidate_name primary_votes_senate_2014  \
# 16             Gardner, Cory                    338324
# 19               Wade, Kevin                     18181
# 32             Schatz, Brian                    115445
# 33  Hanabusa, Colleen Wakako                    113663
# 36             Roco, John P.                      4425
#
#     primary_votes_senate_2014_pct primary_votes_house_2014  \
# 16                       1.000000                      NaN
# 19                       0.756627                      NaN
# 32                       0.493460                      NaN
# 33                       0.485843                      NaN
# 36                       0.123572                      NaN
#
#     primary_votes_house_2014_pct primary_votes_senate_2016  \
# 16                           NaN                       NaN
# 19                           NaN                       NaN
# 32                           NaN                    162905
# 33                           NaN                       NaN
# 36                           NaN                      3956
#
#     primary_votes_senate_2016_pct primary_votes_house_2016  \
# 16                            NaN                      NaN
# 19                            NaN                      NaN
# 32                       0.861662                      NaN
# 33                            NaN                    74022
# 36                       0.110303                      NaN
#
#     primary_votes_house_2016_pct primary_votes_all_2012  \
# 16                           NaN                  49340
# 19                           NaN              Unopposed
# 32                           NaN                    NaN
# 33                      0.803757                    NaN
# 36                           NaN                    545
#
#     primary_votes_all_2012_pct     state
# 16                    1.000000  Colorado
# 19                         NaN  Delaware
# 32                         NaN    Hawaii
# 33                         NaN    Hawaii
# 36                    0.011285    Hawaii

# %% [markdown]
# # Influence of statements on election results

# %% [markdown]
# ## joining statements and election results

# %%
# we join on last names and state
election_results[['candidate_last_name',  'candidate_first_name', 'candidate_name_misc']] = election_results['candidate_name'].str.split(', ', expand=True)

t = election_results.loc[idx_multiple_election_results, ['state'] + [c for c in election_results.columns if c.endswith('pct') or c.startswith('candidate') and not c.endswith('misc')]]
statements_with_elections =  statements.merge(t, left_on=['speaker_last_name', 'speaker_home_state'], right_on=['candidate_last_name', 'state'])

# %% [markdown]
# ## Simpliyfing the label

# %%
labels_of_interest = ['false',
                      'mostly-true',
                      'half-true',
                      'barely-true',
                      'true',
                      'pants-fire',
                      #'full-flop',
                      #'half-flip',
                      #'no-flip',
                     ]

statements_with_elections = statements_with_elections.loc[statements_with_elections['label'].isin(labels_of_interest), :]

def simplify_label(l):
    if l in ['pants-fire', 'false']:
        return 'false'
    else:
        return 'true'


statements_with_elections['simple_label'] = statements_with_elections['label'].apply(simplify_label)

# %%
def simplify_votes(df):
    df = df.copy()
    for y in [2014, 2016]:
        cols = [c for c in df.columns if str(y) in c and c.endswith('pct')]
        for c in cols:
            df.loc[df[c[:-4]] == 'Unopposed', c] = 1.0
        df = combine_first(df, cols, f'primary_votes_{y}', drop_cols=True)
        
    return df.rename(columns={'primary_votes_all_2012_pct': 'primary_votes_2012'})

# %%
simple_votes = simplify_votes(election_results)

# %% [markdown]
# ## Counting lies in between elections

# %% [markdown]
# - we know for each candidate the election date -> sum statements between these dates -> compare with votes
# -

# %%
statements['statement_month'] = statements.statement_date.dt.year * 100 + statements.statement_date.dt.month

# %%
periods = [(201011, 201211), (201211, 201411), (201411, 201611), (200811, 201211), (201211, 201611)]

def agg_for_years(statements, ys):
    statements = statements.loc[statements['statement_month'].lt(ys[1]) & statements['statement_month'].gt(ys[0])]
    statements['simple_label'] = statements['label'].apply(simplify_label)

    return statements.groupby(['speaker_last_name', 'speaker_home_state', 'simple_label']).size().reset_index(name='count_{0}_{1}'.format(str(ys[0])[:4], str(ys[1])[:4]))



simple_votes_2012_2014 = simple_votes.loc[simple_votes['primary_votes_2012'].notnull() & simple_votes['primary_votes_2014'].notnull()]
statements_with_elections_2012_2014 =  simple_votes_2012_2014.merge(agg_for_years(statements, periods[0]), right_on=['speaker_last_name', 'speaker_home_state'], left_on=['candidate_last_name', 'state'])\
    .merge(agg_for_years(statements, periods[1]), on=['speaker_last_name', 'speaker_home_state', 'simple_label'])

simple_votes_2014_2016 = simple_votes.loc[simple_votes['primary_votes_2014'].notnull() & simple_votes['primary_votes_2016'].notnull()]
statements_with_elections_2014_2016 =  simple_votes_2014_2016.merge(agg_for_years(statements, periods[1]), right_on=['speaker_last_name', 'speaker_home_state'], left_on=['candidate_last_name', 'state'])\
    .merge(agg_for_years(statements, periods[2]), on=['speaker_last_name', 'speaker_home_state', 'simple_label'])

simple_votes_2012_2016 = simple_votes.loc[simple_votes['primary_votes_2012'].notnull() & simple_votes['primary_votes_2016'].notnull()]
statements_with_elections_2012_2016 =  simple_votes_2012_2016.merge(agg_for_years(statements, (200811, 201211)), right_on=['speaker_last_name', 'speaker_home_state'], left_on=['candidate_last_name', 'state'])\
    .merge(agg_for_years(statements, (201211, 201611)), on=['speaker_last_name', 'speaker_home_state', 'simple_label'])

coi_p1 = ['state', 'candidate_name', 'primary_votes_2012', 'primary_votes_2014', 'simple_label', 'count_2010_2012', 'count_2012_2014']
coi_p2 = ['state', 'candidate_name', 'primary_votes_2016', 'simple_label', 'count_2014_2016'] + ['speaker_last_name', 'speaker_home_state']
coi_p3 = ['state', 'candidate_name', 'simple_label', 'count_2008_2012', 'count_2012_2016']

combined = statements_with_elections_2012_2014.loc[:, coi_p1]\
    .merge(statements_with_elections_2014_2016.loc[:, coi_p2], on=['state', 'candidate_name', 'simple_label'], how='outer')\
    .merge(statements_with_elections_2012_2016.loc[:, coi_p3], on=['state', 'candidate_name', 'simple_label'], how='outer')
# Out:
# /home/sam/.local/bin/miniconda3/envs/sci/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
import numpy as np

def _period_year_(period):
    return [str(p)[:4] for p in period]

def ratio_for_period(statements, period):
    """Calculates the ratio between false and true statements for the given period (defined as a tuple of two "year-months").
    If no true statements exists the ratio will be `np.inf`.
    
    Example:
    
    >>> ratio_for_period(statements, (201011, 201211))
    """
    _t = agg_for_years(statements, period)

    _t = pd.pivot_table(_t, index=['speaker_last_name', 'speaker_home_state'], values='count_{0}_{1}'.format(*_period_year_(period)), columns='simple_label', ).reset_index()
    _t = _t.loc[_t['false'].notnull()] # we are only interested in the impact of lies -> drop the rows for which we don't have any lies
    _t['ratio_false_true_statements'] = np.inf # 
    _h = _t['true'].notnull()
    _t.loc[_t['true'].notnull(), 'ratio_false_true_statements'] = _t.loc[_h, 'false'] / _t.loc[_h, 'true']
    return _t[['ratio_false_true_statements', 'speaker_last_name', 'speaker_home_state']].rename(columns={'ratio_false_true_statements': 'ratio_false_true_statements_{0}_{1}'.format(*_period_year_(period))})

# %%
true_false_ratios = reduce(lambda acc, el: acc.merge(el, on=['speaker_last_name', 'speaker_home_state'], how='outer'), [ratio_for_period(statements, p) for p in periods])
# Out:
# /home/sam/.local/bin/miniconda3/envs/sci/lib/python3.6/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
_t = combined.drop_duplicates(subset=['state', 'candidate_name']).drop(columns=['simple_label'])

# not very many people left... 7! but the primary votes for 2016 are missing
_t = _t.merge(true_false_ratios, on=['speaker_last_name', 'speaker_home_state'], how='outer')
for l, r in [(2012, 2014), (2014, 2016), (2012, 2016)]:
    _t[f'diff_votes_{l}_{r}'] = _t[f'primary_votes_{l}'] - _t[f'primary_votes_{r}']
    #_t[f'diff_ratio_{l}_{r}'] = _t[f'ratio_2010_2012'] - _t['ratio_2012_2014']
_t.loc[(_t['diff_votes_2012_2014'].notnull() | _t['diff_votes_2012_2016'].notnull() | _t['diff_votes_2014_2016'].notnull()), sorted(_t.columns)]
# Out:
#                 candidate_name  count_2008_2012  count_2010_2012  \
# 0              Brown, Scott P.              NaN              1.0
# 1                Issa, Darrell              2.0              1.0
# 2         Wilson, Frederica S.              NaN              1.0
# 3                  Garcia, Joe              NaN              2.0
# 4            Labrador, Raul R.              1.0              1.0
# 5             Hoyer, Steny H.               NaN              2.0
# 6           Van Hollen, Chris               NaN              3.0
# 7          Pascrell, Bill, Jr.              7.0              4.0
# 8               Collins, Chris              5.0              5.0
# 9                Johnson, Bill              2.0              2.0
# 10            Boehner, John A.              NaN              8.0
# 11               Kaptur, Marcy             10.0              9.0
# 12            Fudge, Marcia L.              6.0              6.0
# 13                   Ryan, Tim              NaN              6.0
# 14                Renacci, Jim             10.0              8.0
# 15               Walden, Greg               NaN              2.0
# 16           Blumenauer, Earl               1.0              1.0
# 17          Langevin, James R.              3.0              1.0
# 18           Blackburn, Marsha              3.0              3.0
# 19              Gohmert, Louie              NaN              2.0
# 20                    Poe, Ted              1.0              1.0
# 21             Hensarling, Jeb              2.0              1.0
# 22             McCaul, Michael              NaN              3.0
# 23             Hinojosa, Rubén              NaN              2.0
# 24             Williams, Roger              4.0              4.0
# 25                 Moore, Gwen              NaN              5.0
# 40         Cicilline, David N.             15.0             12.0
# 41             Castro, Joaquin              9.0              9.0
# 42                Smith, Lamar              4.0              3.0
# 43              Doggett, Lloyd              9.0              6.0
# 44            Forbes, J. Randy              6.0              6.0
# 45  Goodlatte, Robert W. "Bob"              2.0              2.0
# 46                  Ryan, Paul              5.0              5.0
# 47                 Duffy, Sean              5.0              4.0
#
#     count_2012_2014  count_2012_2016  count_2014_2016  diff_votes_2012_2014  \
# 0               6.0              NaN              NaN              0.985513
# 1               1.0              1.0              NaN             -0.007841
# 2               1.0              NaN              NaN             -0.140475
# 3               1.0              NaN              NaN             -0.466317
# 4               1.0              1.0              NaN              0.020846
# 5               1.0              NaN              NaN             -0.153222
# 6               1.0              NaN              NaN              0.009273
# 7               1.0              1.0              NaN             -0.388210
# 8               2.0              2.0              NaN             -0.401394
# 9               1.0              1.0              NaN             -0.160607
# 10              4.0              NaN              NaN              0.123195
# 11              2.0              2.0              NaN             -0.438205
# 12              2.0              2.0              NaN             -0.105909
# 13              1.0              NaN              NaN              0.149549
# 14              2.0              2.0              NaN              0.000000
# 15              2.0              NaN              NaN              0.237260
# 16              4.0              4.0              NaN              0.002381
# 17              2.0              2.0              NaN             -0.259052
# 18              1.0              1.0              NaN              0.158086
# 19              4.0              NaN              NaN              0.000000
# 20              2.0              2.0              NaN              0.000000
# 21              1.0              1.0              NaN              0.000000
# 22              2.0              NaN              NaN             -0.162349
# 23              3.0              NaN              NaN             -0.288415
# 24              3.0              3.0              NaN             -0.748851
# 25              1.0              NaN              NaN              0.287553
# 40              6.0              9.0              3.0             -0.008673
# 41              3.0              9.0              6.0              0.000000
# 42              1.0              2.0              1.0              0.161994
# 43              4.0              6.0              2.0             -0.267509
# 44              3.0              7.0              4.0             -0.102837
# 45              2.0              7.0              4.0             -0.335102
# 46              2.0              3.0              1.0              0.053071
# 47              4.0              8.0              4.0              0.118370
#
#     diff_votes_2012_2016  diff_votes_2014_2016  primary_votes_2012  \
# 0                    NaN                   NaN            0.994554
# 1                    NaN                   NaN            0.610908
# 2                    NaN                   NaN            0.663808
# 3                    NaN                   NaN            0.533683
# 4                    NaN                   NaN            0.806493
# 5                    NaN                   NaN            0.846778
# 6                    NaN                   NaN            0.922086
# 7                    NaN                   NaN            0.611790
# 8                    NaN                   NaN            0.598606
# 9                    NaN                   NaN            0.839393
# 10                   NaN                   NaN            0.838155
# 11                   NaN                   NaN            0.561795
# 12                   NaN                   NaN            0.894091
# 13                   NaN                   NaN            1.000000
# 14                   NaN                   NaN            1.000000
# 15                   NaN                   NaN            0.992559
# 16                   NaN                   NaN            0.988680
# 17                   NaN                   NaN            0.740948
# 18                   NaN                   NaN            1.000000
# 19                   NaN                   NaN            1.000000
# 20                   NaN                   NaN            1.000000
# 21                   NaN                   NaN            1.000000
# 22                   NaN                   NaN            0.837651
# 23                   NaN                   NaN            0.711585
# 24                   NaN                   NaN            0.251149
# 25                   NaN                   NaN            0.996680
# 40             -0.053963             -0.045290            0.621384
# 41              0.000000              0.000000            1.000000
# 42              0.165524              0.003530            0.766331
# 43             -0.267509              0.000000            0.732491
# 44              0.490859              0.593696            0.897163
# 45             -0.114270              0.220832            0.664898
# 46              0.155202              0.102132            0.995786
# 47              0.100181             -0.018189            0.994665
#
#     primary_votes_2014  primary_votes_2016  \
# 0             0.009041                 NaN
# 1             0.618749                 NaN
# 2             0.804283                 NaN
# 3             1.000000                 NaN
# 4             0.785647                 NaN
# 5             1.000000                 NaN
# 6             0.912813                 NaN
# 7             1.000000                 NaN
# 8             1.000000                 NaN
# 9             1.000000                 NaN
# 10            0.714960                 NaN
# 11            1.000000                 NaN
# 12            1.000000                 NaN
# 13            0.850451                 NaN
# 14            1.000000                 NaN
# 15            0.755299                 NaN
# 16            0.986298                 NaN
# 17            1.000000                 NaN
# 18            0.841914                 NaN
# 19            1.000000                 NaN
# 20            1.000000                 NaN
# 21            1.000000                 NaN
# 22            1.000000                 NaN
# 23            1.000000                 NaN
# 24            1.000000                 NaN
# 25            0.709127                 NaN
# 40            0.630057            0.675347
# 41            1.000000            1.000000
# 42            0.604337            0.600807
# 43            1.000000            1.000000
# 44            1.000000            0.406304
# 45            1.000000            0.779168
# 46            0.942716            0.840584
# 47            0.876295            0.894485
#
#     ratio_false_true_statements_2008_2012  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 40                               0.333333
# 41                                    NaN
# 42                               0.666667
# 43                                    NaN
# 44                                    NaN
# 45                                    NaN
# 46                               0.178571
# 47                                    NaN
#
#     ratio_false_true_statements_2010_2012  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 40                               0.333333
# 41                                    NaN
# 42                               1.500000
# 43                                    NaN
# 44                                    NaN
# 45                                    NaN
# 46                               0.192308
# 47                                    NaN
#
#     ratio_false_true_statements_2012_2014  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 40                                    NaN
# 41                                    NaN
# 42                               0.333333
# 43                                    NaN
# 44                                    NaN
# 45                               0.500000
# 46                               0.133333
# 47                                    NaN
#
#     ratio_false_true_statements_2012_2016  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# 5                                     NaN
# 6                                     NaN
# 7                                     NaN
# 8                                     NaN
# 9                                     NaN
# 10                                    NaN
# 11                                    NaN
# 12                                    NaN
# 13                                    NaN
# 14                                    NaN
# 15                                    NaN
# 16                                    NaN
# 17                                    NaN
# 18                                    NaN
# 19                                    NaN
# 20                                    NaN
# 21                                    NaN
# 22                                    NaN
# 23                                    NaN
# 24                                    NaN
# 25                                    NaN
# 40                                    NaN
# 41                                    NaN
# 42                               0.400000
# 43                                    NaN
# 44                                    NaN
# 45                               0.142857
# 46                               0.090909
# 47                               0.250000
#
#     ratio_false_true_statements_2014_2016 speaker_home_state  \
# 0                                     NaN                NaN
# 1                                     NaN                NaN
# 2                                     NaN                NaN
# 3                                     NaN                NaN
# 4                                     NaN                NaN
# 5                                     NaN                NaN
# 6                                     NaN                NaN
# 7                                     NaN                NaN
# 8                                     NaN                NaN
# 9                                     NaN                NaN
# 10                                    NaN                NaN
# 11                                    NaN                NaN
# 12                                    NaN                NaN
# 13                                    NaN                NaN
# 14                                    NaN                NaN
# 15                                    NaN                NaN
# 16                                    NaN                NaN
# 17                                    NaN                NaN
# 18                                    NaN                NaN
# 19                                    NaN                NaN
# 20                                    NaN                NaN
# 21                                    NaN                NaN
# 22                                    NaN                NaN
# 23                                    NaN                NaN
# 24                                    NaN                NaN
# 25                                    NaN                NaN
# 40                                    NaN       Rhode Island
# 41                                    NaN              Texas
# 42                               0.500000              Texas
# 43                                    NaN              Texas
# 44                                    NaN           Virginia
# 45                                    NaN           Virginia
# 46                               0.055556          Wisconsin
# 47                               0.500000          Wisconsin
#
#    speaker_last_name          state
# 0                NaN  New Hampshire
# 1                NaN     California
# 2                NaN        Florida
# 3                NaN        Florida
# 4                NaN          Idaho
# 5                NaN       Maryland
# 6                NaN       Maryland
# 7                NaN     New Jersey
# 8                NaN       New York
# 9                NaN           Ohio
# 10               NaN           Ohio
# 11               NaN           Ohio
# 12               NaN           Ohio
# 13               NaN           Ohio
# 14               NaN           Ohio
# 15               NaN         Oregon
# 16               NaN         Oregon
# 17               NaN   Rhode Island
# 18               NaN      Tennessee
# 19               NaN          Texas
# 20               NaN          Texas
# 21               NaN          Texas
# 22               NaN          Texas
# 23               NaN          Texas
# 24               NaN          Texas
# 25               NaN      Wisconsin
# 40         Cicilline   Rhode Island
# 41            Castro          Texas
# 42             Smith          Texas
# 43           Doggett          Texas
# 44            Forbes       Virginia
# 45         Goodlatte       Virginia
# 46              Ryan      Wisconsin
# 47             Duffy      Wisconsin

# %%
votes_idx = (_t['diff_votes_2012_2014'].notnull() | _t['diff_votes_2012_2016'].notnull() | _t['diff_votes_2014_2016'].notnull())
statement_idx = reduce(lambda acc, el: acc | el, [_t[c].notnull() for c in _t.columns if c.startswith('ratio_false_true_statements')])
# Out:
#                 candidate_name  diff_votes_2012_2014  diff_votes_2012_2016  \
# 40         Cicilline, David N.             -0.008673             -0.053963
# 42                Smith, Lamar              0.161994              0.165524
# 45  Goodlatte, Robert W. "Bob"             -0.335102             -0.114270
# 46                  Ryan, Paul              0.053071              0.155202
# 47                 Duffy, Sean              0.118370              0.100181
#
#     diff_votes_2014_2016  ratio_false_true_statements_2008_2012  \
# 40             -0.045290                               0.333333
# 42              0.003530                               0.666667
# 45              0.220832                                    NaN
# 46              0.102132                               0.178571
# 47             -0.018189                                    NaN
#
#     ratio_false_true_statements_2010_2012  \
# 40                               0.333333
# 42                               1.500000
# 45                                    NaN
# 46                               0.192308
# 47                                    NaN
#
#     ratio_false_true_statements_2012_2014  \
# 40                                    NaN
# 42                               0.333333
# 45                               0.500000
# 46                               0.133333
# 47                                    NaN
#
#     ratio_false_true_statements_2012_2016  \
# 40                                    NaN
# 42                               0.400000
# 45                               0.142857
# 46                               0.090909
# 47                               0.250000
#
#     ratio_false_true_statements_2014_2016
# 40                                    NaN
# 42                               0.500000
# 45                                    NaN
# 46                               0.055556
# 47                               0.500000

# %%
_f = _t.loc[votes_idx & statement_idx, sorted([c for c in _t.columns if c.startswith('diff_votes') or c.startswith('ratio_')] + ['candidate_name'])]

_f['diff_ratio_2012_2014'] = _f['ratio_false_true_statements_2010_2012'] - _f['ratio_false_true_statements_2012_2014']
_f['diff_ratio_2012_2016'] = _f['ratio_false_true_statements_2008_2012'] - _f['ratio_false_true_statements_2012_2016']
_f['diff_ratio_2014_2016'] = _f['ratio_false_true_statements_2012_2014'] - _f['ratio_false_true_statements_2014_2016']

_f = _f[[c for c in _f.columns if c.startswith('diff_ratio') or c.startswith('diff_votes')] + ['candidate_name']]

# %%
import matplotlib.pyplot as plt
_ratios = _f.loc[_f.notnull().all(axis=1), [c for c in _f.columns if c.startswith('diff_ratio')]].values.reshape(-1)
_votes = _f.loc[_f.notnull().all(axis=1), [c for c in _f.columns if c.startswith('diff_votes')]].values.reshape(-1)

_d = pd.DataFrame([_ratios, _votes]).T
_d.columns = ['ratio', 'votes']

sns.lmplot(x='ratio', y='votes', data=_d)
plt.xlabel('Difference in ratios over election period')
plt.ylabel('Difference in election results')
plt.title('Difference in false-true ratio to election results')
plt.tight_layout()
plt.savefig('../docs/images/difference_false_true_ratio_to_election_results.png')
# Out:
# /home/sam/.local/bin/miniconda3/envs/sci/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
_ys = [c for c in _t.columns if c.startswith('diff_votes')]
_cs = [c for c in _t.columns if c.startswith('ratio') and any([c[-9:] == p[-9:] for p in _ys])] + _ys

# %%
_tt = _t.loc[votes_idx & statement_idx, sorted(_cs + ['candidate_name'])]
_tt
# Out:
#                 candidate_name  diff_votes_2012_2014  diff_votes_2012_2016  \
# 40         Cicilline, David N.             -0.008673             -0.053963
# 42                Smith, Lamar              0.161994              0.165524
# 45  Goodlatte, Robert W. "Bob"             -0.335102             -0.114270
# 46                  Ryan, Paul              0.053071              0.155202
# 47                 Duffy, Sean              0.118370              0.100181
#
#     diff_votes_2014_2016  ratio_false_true_statements_2012_2014  \
# 40             -0.045290                                    NaN
# 42              0.003530                               0.333333
# 45              0.220832                               0.500000
# 46              0.102132                               0.133333
# 47             -0.018189                                    NaN
#
#     ratio_false_true_statements_2012_2016  \
# 40                                    NaN
# 42                               0.400000
# 45                               0.142857
# 46                               0.090909
# 47                               0.250000
#
#     ratio_false_true_statements_2014_2016
# 40                                    NaN
# 42                               0.500000
# 45                                    NaN
# 46                               0.055556
# 47                               0.500000

# %%
_ratios = _tt.loc[:, [c for c in _tt.columns if c.startswith('ratio')]].values.reshape(-1)
_votes = _tt.loc[:, [c for c in _tt.columns if c.startswith('diff_votes')]].values.reshape(-1)

_d = pd.DataFrame([_ratios, _votes]).T
_d.columns = ['ratio', 'votes']
_d = _d[_d.notna().all(axis=1)]

sns.lmplot(x='ratio', y='votes', data=_d)
plt.xlabel('False-True Ratio in election period')
plt.ylabel('Difference in election results')
plt.title('Difference in election results to false-true ratio')
plt.tight_layout()
plt.savefig('../docs/images/difference_election_results.png')
# Out:
# /home/sam/.local/bin/miniconda3/envs/sci/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
_d.shape
# Out:
# (10, 2)

# %%
combined.loc[:, sorted(combined.columns)]
# Out:
#             candidate_name  count_2008_2012  count_2010_2012  count_2012_2014  \
# 0          Brown, Scott P.              NaN              1.0              6.0
# 1          Brown, Scott P.              NaN              1.0              6.0
# 2            Issa, Darrell              2.0              1.0              1.0
# 3     Wilson, Frederica S.              NaN              1.0              1.0
# 4              Garcia, Joe              NaN              2.0              1.0
# 5        Labrador, Raul R.              1.0              1.0              1.0
# 6         Hoyer, Steny H.               NaN              2.0              1.0
# 7       Van Hollen, Chris               NaN              3.0              1.0
# 8      Pascrell, Bill, Jr.              7.0              4.0              1.0
# 9           Collins, Chris              5.0              5.0              2.0
# 10          Collins, Chris              5.0              5.0              2.0
# 11          Collins, Chris              5.0              5.0              2.0
# 12          Collins, Chris              5.0              5.0              2.0
# 13          Collins, Chris              5.0              5.0              2.0
# 14          Collins, Chris              5.0              5.0              2.0
# 15          Collins, Chris              5.0              5.0              2.0
# 16          Collins, Chris              5.0              5.0              2.0
# 17          Collins, Chris              5.0              5.0              2.0
# 18          Collins, Chris              5.0              5.0              2.0
# 19          Collins, Chris              5.0              5.0              2.0
# 20          Collins, Chris              5.0              5.0              2.0
# 21          Collins, Chris              5.0              5.0              2.0
# 22          Collins, Chris              5.0              5.0              2.0
# 23          Collins, Chris              5.0              5.0              2.0
# 24          Collins, Chris              5.0              5.0              2.0
# 25          Collins, Chris              5.0              5.0              2.0
# 26          Collins, Chris              5.0              5.0              2.0
# 27          Collins, Chris              5.0              5.0              2.0
# 28          Collins, Chris              5.0              5.0              2.0
# 29          Collins, Chris              5.0              5.0              2.0
# ..                     ...              ...              ...              ...
# 200  Maloney, Sean Patrick              1.0              NaN              NaN
# 201  Maloney, Sean Patrick              1.0              NaN              NaN
# 202  Maloney, Sean Patrick              1.0              NaN              NaN
# 203  Maloney, Sean Patrick              1.0              NaN              NaN
# 204  Maloney, Sean Patrick              1.0              NaN              NaN
# 205  Maloney, Sean Patrick              1.0              NaN              NaN
# 206  Maloney, Sean Patrick              1.0              NaN              NaN
# 207  Maloney, Sean Patrick              1.0              NaN              NaN
# 208  Maloney, Sean Patrick              1.0              NaN              NaN
# 209  Maloney, Sean Patrick              1.0              NaN              NaN
# 210      DeFazio, Peter A.              4.0              NaN              NaN
# 211      DeFazio, Peter A.              4.0              NaN              NaN
# 212        Hensarling, Jeb              1.0              NaN              NaN
# 213           Brady, Kevin              1.0              NaN              NaN
# 214        Williams, Roger              2.0              NaN              NaN
# 215         Sessions, Pete              1.0              NaN              NaN
# 216         Pelosi, Nancy               6.0              NaN              NaN
# 217         Pelosi, Nancy              13.0              NaN              NaN
# 218            Price, Tom               5.0              NaN              NaN
# 219           Woodall, Rob              1.0              NaN              NaN
# 220            King, Steve              1.0              NaN              NaN
# 221            King, Steve              1.0              NaN              NaN
# 222       Tarkanian, Danny              1.0              NaN              NaN
# 223    Shea-Porter, Carol               1.0              NaN              NaN
# 224    Shea-Porter, Carol               1.0              NaN              NaN
# 225    Shea-Porter, Carol               1.0              NaN              NaN
# 226    Shea-Porter, Carol               1.0              NaN              NaN
# 227            Jordan, Jim              8.0              NaN              NaN
# 228      Bonamici, Suzanne              3.0              NaN              NaN
# 229      Bonamici, Suzanne              3.0              NaN              NaN
#
#      count_2012_2016  count_2014_2016  primary_votes_2012  primary_votes_2014  \
# 0                NaN              NaN            0.994554            0.009041
# 1                NaN              NaN            0.994554            0.498554
# 2                1.0              NaN            0.610908            0.618749
# 3                NaN              NaN            0.663808            0.804283
# 4                NaN              NaN            0.533683            1.000000
# 5                1.0              NaN            0.806493            0.785647
# 6                NaN              NaN            0.846778            1.000000
# 7                NaN              NaN            0.922086            0.912813
# 8                1.0              NaN            0.611790            1.000000
# 9                2.0              NaN            0.598606            1.000000
# 10               2.0              NaN            0.598606            1.000000
# 11               2.0              NaN            0.598606            1.000000
# 12               2.0              NaN            0.598606            1.000000
# 13               2.0              NaN            0.598606            1.000000
# 14               2.0              NaN            0.598606            1.000000
# 15               2.0              NaN            0.598606            1.000000
# 16               2.0              NaN            0.598606            1.000000
# 17               2.0              NaN            0.598606            1.000000
# 18               2.0              NaN            0.598606            1.000000
# 19               2.0              NaN            0.598606            1.000000
# 20               2.0              NaN            0.598606            1.000000
# 21               2.0              NaN            0.598606            1.000000
# 22               2.0              NaN            0.598606            1.000000
# 23               2.0              NaN            0.598606            1.000000
# 24               2.0              NaN            0.598606            1.000000
# 25               2.0              NaN            0.598606            1.000000
# 26               2.0              NaN            0.598606            1.000000
# 27               2.0              NaN            0.598606            1.000000
# 28               2.0              NaN            0.598606            1.000000
# 29               2.0              NaN            0.598606            1.000000
# ..               ...              ...                 ...                 ...
# 200              1.0              NaN                 NaN                 NaN
# 201              1.0              NaN                 NaN                 NaN
# 202              1.0              NaN                 NaN                 NaN
# 203              1.0              NaN                 NaN                 NaN
# 204              1.0              NaN                 NaN                 NaN
# 205              1.0              NaN                 NaN                 NaN
# 206              1.0              NaN                 NaN                 NaN
# 207              1.0              NaN                 NaN                 NaN
# 208              1.0              NaN                 NaN                 NaN
# 209              1.0              NaN                 NaN                 NaN
# 210              1.0              NaN                 NaN                 NaN
# 211              1.0              NaN                 NaN                 NaN
# 212              1.0              NaN                 NaN                 NaN
# 213              2.0              NaN                 NaN                 NaN
# 214              1.0              NaN                 NaN                 NaN
# 215              1.0              NaN                 NaN                 NaN
# 216              4.0              NaN                 NaN                 NaN
# 217              5.0              NaN                 NaN                 NaN
# 218              7.0              NaN                 NaN                 NaN
# 219              2.0              NaN                 NaN                 NaN
# 220              1.0              NaN                 NaN                 NaN
# 221              1.0              NaN                 NaN                 NaN
# 222              2.0              NaN                 NaN                 NaN
# 223              3.0              NaN                 NaN                 NaN
# 224              3.0              NaN                 NaN                 NaN
# 225              3.0              NaN                 NaN                 NaN
# 226              3.0              NaN                 NaN                 NaN
# 227              4.0              NaN                 NaN                 NaN
# 228              1.0              NaN                 NaN                 NaN
# 229              1.0              NaN                 NaN                 NaN
#
#      primary_votes_2016 simple_label speaker_home_state speaker_last_name  \
# 0                   NaN         true                NaN               NaN
# 1                   NaN         true                NaN               NaN
# 2                   NaN        false                NaN               NaN
# 3                   NaN         true                NaN               NaN
# 4                   NaN         true                NaN               NaN
# 5                   NaN         true                NaN               NaN
# 6                   NaN         true                NaN               NaN
# 7                   NaN         true                NaN               NaN
# 8                   NaN         true                NaN               NaN
# 9                   NaN         true                NaN               NaN
# 10                  NaN         true                NaN               NaN
# 11                  NaN         true                NaN               NaN
# 12                  NaN         true                NaN               NaN
# 13                  NaN         true                NaN               NaN
# 14                  NaN         true                NaN               NaN
# 15                  NaN         true                NaN               NaN
# 16                  NaN         true                NaN               NaN
# 17                  NaN         true                NaN               NaN
# 18                  NaN         true                NaN               NaN
# 19                  NaN         true                NaN               NaN
# 20                  NaN         true                NaN               NaN
# 21                  NaN         true                NaN               NaN
# 22                  NaN         true                NaN               NaN
# 23                  NaN         true                NaN               NaN
# 24                  NaN         true                NaN               NaN
# 25                  NaN         true                NaN               NaN
# 26                  NaN         true                NaN               NaN
# 27                  NaN         true                NaN               NaN
# 28                  NaN         true                NaN               NaN
# 29                  NaN         true                NaN               NaN
# ..                  ...          ...                ...               ...
# 200                 NaN         true                NaN               NaN
# 201                 NaN         true                NaN               NaN
# 202                 NaN         true                NaN               NaN
# 203                 NaN         true                NaN               NaN
# 204                 NaN         true                NaN               NaN
# 205                 NaN         true                NaN               NaN
# 206                 NaN         true                NaN               NaN
# 207                 NaN         true                NaN               NaN
# 208                 NaN         true                NaN               NaN
# 209                 NaN         true                NaN               NaN
# 210                 NaN         true                NaN               NaN
# 211                 NaN         true                NaN               NaN
# 212                 NaN         true                NaN               NaN
# 213                 NaN         true                NaN               NaN
# 214                 NaN        false                NaN               NaN
# 215                 NaN         true                NaN               NaN
# 216                 NaN        false                NaN               NaN
# 217                 NaN         true                NaN               NaN
# 218                 NaN         true                NaN               NaN
# 219                 NaN         true                NaN               NaN
# 220                 NaN        false                NaN               NaN
# 221                 NaN        false                NaN               NaN
# 222                 NaN         true                NaN               NaN
# 223                 NaN         true                NaN               NaN
# 224                 NaN         true                NaN               NaN
# 225                 NaN         true                NaN               NaN
# 226                 NaN         true                NaN               NaN
# 227                 NaN         true                NaN               NaN
# 228                 NaN        false                NaN               NaN
# 229                 NaN        false                NaN               NaN
#
#              state
# 0    New Hampshire
# 1    New Hampshire
# 2       California
# 3          Florida
# 4          Florida
# 5            Idaho
# 6         Maryland
# 7         Maryland
# 8       New Jersey
# 9         New York
# 10        New York
# 11        New York
# 12        New York
# 13        New York
# 14        New York
# 15        New York
# 16        New York
# 17        New York
# 18        New York
# 19        New York
# 20        New York
# 21        New York
# 22        New York
# 23        New York
# 24        New York
# 25        New York
# 26        New York
# 27        New York
# 28        New York
# 29        New York
# ..             ...
# 200       New York
# 201       New York
# 202       New York
# 203       New York
# 204       New York
# 205       New York
# 206       New York
# 207       New York
# 208       New York
# 209       New York
# 210         Oregon
# 211         Oregon
# 212          Texas
# 213          Texas
# 214          Texas
# 215          Texas
# 216     California
# 217     California
# 218        Georgia
# 219        Georgia
# 220           Iowa
# 221           Iowa
# 222         Nevada
# 223  New Hampshire
# 224  New Hampshire
# 225  New Hampshire
# 226  New Hampshire
# 227           Ohio
# 228         Oregon
# 229         Oregon
#
# [230 rows x 13 columns]

# %%
statements
# Out:
#             author_name_slug  \
# 0             lauren-carroll
# 1             manuela-tobias
# 2       brittany-alana-davis
# 3                   dan-levy
# 4             c-eugene-emery
# 5              dylan-baddour
# 6              joshua-gillin
# 7               eric-stirgus
# 8               sue-owen-aas
# 9               eric-stirgus
# 10              nadia-pflaum
# 11             jon-greenberg
# 12            louis-jacobson
# 13            louis-jacobson
# 14                 dan-clark
# 15               dror-sharon
# 16           miriam-valverde
# 17            louis-jacobson
# 18       angie-drobnic-holan
# 19               amy-sherman
# 20             robert-farley
# 21            steve-contorno
# 22             tom-kertscher
# 23             robert-farley
# 24             katie-sanders
# 25     nancy-madsen-virginia
# 26            louis-jacobson
# 27             keely-herring
# 28                 dan-clark
# 29              jacob-geiger
# ...                      ...
# 15441    angie-drobnic-holan
# 15442            erin-oneill
# 15443         louis-jacobson
# 15444         c-eugene-emery
# 15445             jake-berry
# 15446             george-ash
# 15447            erin-oneill
# 15448    angie-drobnic-holan
# 15449       aaron-sharockman
# 15450           bill-wichert
# 15451       aaron-sharockman
# 15452    angie-drobnic-holan
# 15453            lukas-pleva
# 15454            sarah-hauer
# 15455        w-gardner-selby
# 15456           anthony-cave
# 15457          jon-greenberg
# 15458          jon-greenberg
# 15459          joshua-gillin
# 15460          jon-greenberg
# 15461          jon-greenberg
# 15462             bill-adair
# 15463          tom-kertscher
# 15464           eric-stirgus
# 15465          katie-sanders
# 15466          joshua-gillin
# 15467          sophie-kaplan
# 15468         alexander-lane
# 15469         maryalice-gill
# 15470              tom-tobin
#
#                                                                        context  \
# 0                                          a speech at Northwestern University
# 1                                                                     in an ad
# 2                                                                      remarks
# 3                                           a speech to the AFL-CIO Convention
# 4                                                       a television interview
# 5                               a Cocks not Glocks call to protest on Facebook
# 6                                                               Internet posts
# 7                                                                 an interview
# 8                                                                     an email
# 9                                                              a press release
# 10                                                       in a press conference
# 11                               an opinion piece in the "Washington Examiner"
# 12                                         an interview with CNN's Jake Tapper
# 13                                                               a campaign ad
# 14                                                      an article on LinkedIn
# 15                                            an op-ed in the Bismarck Tribune
# 16                                                             a CNN town hall
# 17                                                       posts on the Internet
# 18                                                             a television ad
# 19                                                                     a tweet
# 20                                              the Kagan confirmation hearing
# 21                                     an op-ed for the "Wall Street Journal."
# 22                                                                    a report
# 23                                             a debate in Simi Valley, Calif.
# 24                                                        2013-14 veto message
# 25                                                                   a web ad.
# 26                                                                     a tweet
# 27                                                             a Facebook meme
# 28                                                                     a tweet
# 29                                an e-mail newsletter and House floor speech.
# ...                                                                        ...
# 15441                                                         a television ad.
# 15442                                                an interview with NJToday
# 15443                                                            a campaign ad
# 15444                                                   an appearance on MSNBC
# 15445                                   a town hall meeting in Merrimack, N.H.
# 15446                                                            a campaign ad
# 15447                                                     an e-mail newsletter
# 15448                                                          a television ad
# 15449                                                          an Internet ad.
# 15450                                                a video posted on YouTube
# 15451  an interview with his brother, former President George W. Bush, on CNN.
# 15452                                            a video statement on Facebook
# 15453                                                            a campaign ad
# 15454                                                                 a speech
# 15455                                                a speech in Tyler, Texas.
# 15456                        remarks made on the Fox News segment, Outnumbered
# 15457                                            a "Fox News Sunday" interview
# 15458                                                    an interview on MSNBC
# 15459                                                          a press release
# 15460                 an interview with "This Week" host George Stephanopoulos
# 15461                                                          a Facebook post
# 15462                                                                  a TV ad
# 15463                                                                  a video
# 15464                                         in editorials and op-ed articles
# 15465                                                an episode of 'The Trews'
# 15466                                                           Internet posts
# 15467                                         public testimony before Congress
# 15468                                              a debate in Hempstead, N.Y.
# 15469                                           a house party in New Hampshire
# 15470                                                            New Hampshire
#
#              label          ruling_date  \
# 0      mostly-true  2014-10-08T14:09:46
# 1      barely-true  2017-08-25T11:24:04
# 2      mostly-true  2012-08-21T16:40:06
# 3      barely-true  2016-04-06T13:02:13
# 4            false  2011-05-31T00:01:00
# 5        half-true  2016-10-07T19:11:53
# 6       pants-fire  2017-04-19T10:58:15
# 7             true  2011-03-04T06:00:00
# 8       pants-fire  2012-04-04T16:21:13
# 9             true  2012-08-22T06:00:00
# 10     barely-true  2016-06-10T10:47:12
# 11     barely-true  2015-03-04T16:35:53
# 12           false  2016-04-06T12:16:54
# 13            true  2012-07-16T16:39:48
# 14       half-true  2017-08-18T00:00:00
# 15     mostly-true  2018-11-01T13:22:35
# 16     barely-true  2018-02-23T13:59:49
# 17      pants-fire  2018-10-24T16:48:35
# 18       half-true  2014-02-14T12:03:38
# 15467                                                                               The violent crime rate has risen, and the homicide rate has risen by more than 20 percent in just two years, really after 30 years of decline in violent crime.
# 15468                                                                                                                                The centerpiece of Senator McCains education policy is to increase the voucher program in D.C. by 2,000 slots.
# 15469                                                                                        Says that when President Obama visited El Paso, he pronounced that the border with Mexico and the United States was safer than it ever was in history.
# 15470                                                                                                                             If African-Americans vote their percentage of the population in 2008, Mississippi is suddenly a Democratic state.
#
#       statement_date  statement_id statement_type  \
# 0         2014-10-02         10039          Claim
# 1         2017-08-22         14464          Claim
# 2         2012-08-11          6501          Claim
# 3         2016-04-06         12192          Claim
# 4         2011-04-24          3824          Claim
# 5         2016-08-24         13221          Claim
# 6         2017-04-10         14008          Claim
# 7         2011-02-22          3348          Claim
# 8         2012-02-19          5681          Claim
# 9         2012-07-26          6511          Claim
# 10        2016-05-25         12487          Claim
# 11        2015-02-27         10581          Claim
# 12        2016-04-03         12188          Claim
# 13        2012-07-14          6267          Claim
# 14        2017-07-18         14440          Claim
# 15        2018-10-28         16146          Claim
# 16        2018-02-21         15071          Claim
# 17        2018-10-18         16075          Claim
# 18        2014-02-12          8926          Claim
# 19        2018-01-04         14898          Claim
# 20        2010-06-28          1981          Claim
# 21        2014-04-02          9142          Claim
# 22        2014-03-25          9110          Claim
# 23        2008-01-30           328         Attack
# 24        2013-05-20          7803          Claim
# 25        2014-01-16          8897         Attack
# 26        2016-11-27         13492          Claim
# 27        2015-06-30         11058          Claim
# 28        2018-05-10         15406          Claim
# 29        2011-02-18          3458          Claim
# ...              ...           ...            ...
# 15441     2007-09-14            68          Claim
# 15442     2012-09-20          6776          Claim
# 15443     2012-02-24          5472         Attack
# 15444     2016-07-27         12843          Claim
# 15445     2012-08-23          6634          Claim
# 15446     2016-06-14         13207          Claim
# 15447     2012-07-20          6327          Claim
# 15448     2011-11-28          4855         Attack
# 15449     2010-03-10          1587          Claim
# 15450     2012-06-26          6213          Claim
# 15451     2010-11-14          2818          Claim
# 15452     2011-01-12          3050          Claim
# 15453     2010-08-31          2358         Attack
# 15454     2016-06-03         12507          Claim
# 15455     2012-05-16          5936          Claim
# 15456     2016-02-08         11917          Claim
# 15457     2017-10-08         14615          Claim
# 15458     2014-05-28          9386          Claim
# 15459     2015-08-10         11195         Attack
# 15460     2015-08-09         11178          Claim
# 15461     2012-07-05          6356          Claim
# 15462     2007-12-12           224          Claim
# 15463     2015-08-03         11160         Attack
# 15464     2011-06-24          5303          Claim
# 15465     2015-05-26         10888          Claim
# 15466     2017-04-13         14003          Claim
# 15467     2017-11-14         14804          Claim
# 15468     2008-10-15           808         Attack
# 15469     2011-08-13          4386          Claim
# 15470     2007-08-20            43          Claim
#
#                          statement_type_description  clean_context  \
# 0                                        blog post          speech
# 1                                        blog post              ad
# 2                                        blog post          others
# 3                                        blog post          speech
# 4                                        blog post       interview
# 5                                        blog post        facebook
# 6                                        blog post        _ignore_
# 7                                        blog post       interview
# 8                                        blog post        _ignore_
# 9                                        blog post   press release
# 10                                       blog post              tv
# 11                                       blog post         article
# 12                                       blog post       interview
# 13                                       blog post        campaign
# 14                                       blog post         article
# 15                                       blog post         article
# 16                                       blog post              tv
# 17                                       blog post        _ignore_
# 18                                       blog post              tv
# 19                                       blog post           tweet
# 20                                       blog post          speech
# 21                                       blog post         article
# 22                                       blog post          others
# 23     <p>\r\n\tA criticism of a candidate.</p>\r\n         debate
# 24                                       blog post          others
# 25     <p>\r\n\tA criticism of a candidate.</p>\r\n             ad
# 26                                       blog post           tweet
# 27                                       blog post        facebook
# 28                                       blog post           tweet
# 29                                       blog post          speech
# ...                                             ...            ...
# 15441                                    blog post              tv
# 15442                                    blog post       interview
# 15443  <p>\r\n\tA criticism of a candidate.</p>\r\n       campaign
# 15444                                    blog post              tv
# 15445                                    blog post        _ignore_
# 15446                                    blog post        campaign
# 15447                                    blog post         article
# 15448  <p>\r\n\tA criticism of a candidate.</p>\r\n             tv
# 15449                                    blog post        _ignore_
# 15450                                    blog post        _ignore_
# 15451                                    blog post       interview
# 15452                                    blog post        facebook
# 15453  <p>\r\n\tA criticism of a candidate.</p>\r\n       campaign
# 15454                                    blog post          speech
# 15455                                    blog post          speech
# 15456                                    blog post             fox
# 15457                                    blog post       interview
# 15458                                    blog post       interview
# 15459  <p>\r\n\tA criticism of a candidate.</p>\r\n  press release
# 15460                                    blog post       interview
# 15461                                    blog post        facebook
# 15462                                    blog post              tv
# 15463  <p>\r\n\tA criticism of a candidate.</p>\r\n       _ignore_
# 15464                                    blog post         article
# 15465                                    blog post              tv
# 15466                                    blog post        _ignore_
# 15467                                    blog post          others
# 15468  <p>\r\n\tA criticism of a candidate.</p>\r\n         debate
# 15469                                    blog post          others
# 15470                                    blog post          others
#
#        statement_month
# 0               201410
# 1               201708
# 2               201208
# 3               201604
# 4               201104
# 5               201608
# 6               201704
# 7               201102
# 8               201202
# 9               201207
# 10              201605
# 11              201502
# 12              201604
# 13              201207
# 14              201707
# 15              201810
# 16              201802
# 17              201810
# 18              201402
# 19              201801
# 20              201006
# 21              201404
# 22              201403
# 23              200801
# 24              201305
# 25              201401
# 26              201611
# 27              201506
# 28              201805
# 29              201102
# ...                ...
# 15441           200709
# 15442           201209
# 15443           201202
# 15444           201607
# 15445           201208
# 15446           201606
# 15447           201207
# 15448           201111
# 15449           201003
# 15450           201206
# 15451           201011
# 15452           201101
# 15453           201008
# 15454           201606
# 15455           201205
# 15456           201602
# 15457           201710
# 15458           201405
# 15459           201508
# 15460           201508
# 15461           201207
# 15462           200712
# 15463           201508
# 15464           201106
# 15465           201505
# 15466           201704
# 15467           201711
# 15468           200810
# 15469           201108
# 15470           200708
#
# [15471 rows x 15 columns]

# %%
statements[(statements['speaker_first_name'].isnull() | statements['speaker_first_name'].str.strip().eq('')) == False][:1].values
# Out:
# array([['lauren-carroll', 'a speech at Northwestern University',
#         'mostly-true', '2014-10-08T14:09:46', 'President', 'Barack',
#         'Illinois', 'Obama',
#         'The cost of health care is now the single-biggest factor driving down the federal budget deficit.',
#         Timestamp('2014-10-02 00:00:00'), 10039, 'Claim', 'blog post ',
#         'speech', 201410]], dtype=object)

# %%
##

# %%
# new stuff

# %%
statements.columns
# Out:
# Index(['author_name_slug', 'context', 'label', 'ruling_date',
#        'speaker_current_job', 'speaker_first_name', 'speaker_home_state',
#        'speaker_last_name', 'statement', 'statement_date', 'statement_id',
#        'statement_type', 'statement_type_description', 'clean_context'],
#       dtype='object')

# %%
statements.dtypes
# Out:
# author_name_slug                      object
# context                               object
# label                                 object
# ruling_date                           object
# speaker_current_job                   object
# speaker_first_name                    object
# speaker_home_state                    object
# speaker_last_name                     object
# statement                             object
# statement_date                datetime64[ns]
# statement_id                           int64
# statement_type                        object
# statement_type_description            object
# clean_context                         object
# dtype: object

# %%
statements['statement_month'] = statements['statement_date'].dt.year * 100 + statements['statement_date'].dt.month

# %%
import matplotlib.pyplot as plt

sns.distplot(statements.loc[statements['statement_month'] > 201000, 'statement_month'], kde=False)
sns.distplot(statements.loc[(statements['statement_month'] > 201000) & statements['label'].isin(['false', 'pants-fire']), 'statement_month'], kde=False)


election_dates['month'] = election_dates['Date'].dt.year * 100 + election_dates['Date'].dt.month

for election_day in election_dates.loc[election_dates['month'] > 201000, 'month']:
    plt.axvline(election_day)
# Out:
# /home/sam/.local/bin/miniconda3/envs/sci/lib/python3.6/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
election_dates = pd.read_csv('../data/usa_election_dates.csv')
election_dates['Date'] = pd.to_datetime(election_dates['Date'])

election_dates
# Out:
#          Date                         Details          Type
# 0  2000-11-07  United States elections, 2000   Presidential
# 1  2001-11-06  United States elections, 2001       Off-year
# 2  2002-11-05  United States elections, 2002        Midterm
# 3  2003-11-04  United States elections, 2003       Off-year
# 4  2004-11-02  United States elections, 2004   Presidential
# 5  2005-11-08  United States elections, 2005       Off-year
# 6  2006-11-07  United States elections, 2006        Midterm
# 7  2007-11-06  United States elections, 2007       Off-year
# 8  2008-11-04  United States elections, 2008   Presidential
# 9  2009-11-03  United States elections, 2009       Off-year
# 10 2010-11-02  United States elections, 2010        Midterm
# 11 2011-11-08  United States elections, 2011       Off-year
# 12 2012-11-06  United States elections, 2012   Presidential
# 13 2013-11-05  United States elections, 2013       Off-year
# 14 2014-11-04  United States elections, 2014        Midterm
# 15 2015-11-03  United States elections, 2015       Off-year
# 16 2016-11-08  United States elections, 2016   Presidential
# 17 2017-11-07  United States elections, 2017       Off-year
# 18 2018-11-06  United States elections, 2018        Midterm
# 19 2019-11-05  United States elections, 2019       Off-year
# 20 2020-11-03  United States elections, 2020   Presidential

# %%
# we are only interest in people and they have a first name
lies = lies.loc[lies['speaker_first_name'].notnull(), :]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-26-88c26cf180bd> in <module>()
#       1 # we are only interest in people and they have a first name
# ----> 2 lies = lies.loc[lies['speaker_first_name'].notnull(), :]
#
# NameError: name 'lies' is not defined

# %%
# to aggregate the statements
lies['statement_year'] = lies['statement_date'].dt.year

# for the merging
lies['speaker_full_name'] = lies['speaker_last_name'] + ', ' + lies['speaker_first_name']

# %% [markdown]
# ### Cleaning job titles

# %%
# todo expand this and check this! this is just a quick and dirty fix
# is it really houseman? probably not...
_job_titles_of_interest = [('senat', 'senator'), ('governor', None), ('congress', 'congressman'), ('mayor', None), ('president', None), ('house', 'houseman'), ('rep', 'houseman')]
job_titles_of_interest = [out if out is not None else j for j, out in _job_titles_of_interest]

def cleaned_job_title(jt):
    jt = str(jt).lower()
    
    for j, out in _job_titles_of_interest:
        if j in jt:
            return out if out is not None else j
    else:
        return jt

lies['speakers_job_title_cleaned'] = lies['speakers_job_title'].apply(cleaned_job_title)

# %%
_t = lies.merge(election_results, left_on='speaker_full_name', right_on='CANDIDATE NAME', how='outer')

# %%
print(f"found election results for {_t['CANDIDATE NAME'].notnull().sum()} ({_t['CANDIDATE NAME'].notnull().mean()}%) people")
# Out:
# found election results for 4952 (0.328403740301081%) people

# %%
votes_cols = [c for c in _t.columns if 'votes' in c]
useful_idx = reduce(lambda acc, el: acc | el, [_t[c].notnull() for c in votes_cols]) & _t['speaker'].notnull() 

print(f"found useful results for {useful_idx.sum()} people")

columns_of_interest = ['label', 'label_as_nb', 'subject', 'speaker', 'speakers_job_title_cleaned', 'state_info', 'party_affiliation', 'context', 'statement_date'] + votes_cols
_t.loc[useful_idx, columns_of_interest]
# Out:
# found useful results for 1461 people
#              label  label_as_nb  \
# 1115     half-true          4.0
# 1116   mostly-true          2.0
# 1117   barely-true          6.0
# 1118          true          0.0
# 1119         false          8.0
# 1120    pants-fire         10.0
# 1121          true          0.0
# 1122   mostly-true          2.0
# 1123   barely-true          6.0
# 1124         false          8.0
# 1125          true          0.0
# 1126         false          8.0
# 1127          true          0.0
# 1128     half-true          4.0
# 1129     half-true          4.0
# 1130   barely-true          6.0
# 1131   mostly-true          2.0
# 1132         false          8.0
# 1133          true          0.0
# 1134     half-true          4.0
# 1422         false          8.0
# 1423     half-true          4.0
# 1424     half-true          4.0
# 1425         false          8.0
# 1426    pants-fire         10.0
# 1427     half-true          4.0
# 1428     half-true          4.0
# 1429     half-true          4.0
# 1430         false          8.0
# 1431   barely-true          6.0
# ...            ...          ...
# 10900    half-true          4.0
# 10923  mostly-true          2.0
# 10939  barely-true          6.0
# 10953        false          8.0
# 10976         true          0.0
# 10988    half-true          4.0
# 10992  barely-true          6.0
# 11007    half-true          4.0
# 11043    half-true          4.0
# 11044  barely-true          6.0
# 11063         true          0.0
# 11091        false          8.0
# 11114  barely-true          6.0
# 11268  barely-true          6.0
# 11269        false          8.0
# 11281         true          0.0
# 11288    half-true          4.0
# 11289    half-true          4.0
# 11317        false          8.0
# 11329  barely-true          6.0
# 11395  mostly-true          2.0
# 11399  barely-true          6.0
# 11439  mostly-true          2.0
# 11444  mostly-true          2.0
# 11453        false          8.0
# 11516    half-true          4.0
# 11517    half-true          4.0
# 11520        false          8.0
# 11542         true          0.0
# 11582        false          8.0
#
#                                                                         subject  \
# 1115                                  financial-regulation,foreign-policy,water
# 1116                                               crime,criminal-justice,women
# 1117   city-government,civil-rights,criminal-justice,public-safety,state-budget
# 1118                              city-government,infrastructure,transportation
# 1119                                  children,crime,criminal-justice,sexuality
# 1120                                  corrections-and-updates,health-care,women
# 1124                a speech at a state Democratic Party dinner
# 1125                                             a news release
# 1126                       an interview with a weekly newspaper
# 1127                                                    a tweet
# 1128                                               an interview
# 1129                                               an interview
# 1130             a speech at the Democratic National Convention
# 1131                                                    a tweet
# 1132                                              a song/speech
# 1133                                                   a speech
# 1134                                             a news release
# 1422                                          a news conference
# 1423                                      an interview on MSNBC
# 1424                                         a press conference
# 1425                                                    a tweet
# 1426                                                a blog post
# 1427                                             a news release
# 1428                                            a press release
# 1429                                                     Denver
# 1430                                   during a news conference
# 1431                      an interview on the Charlie Rose Show
# ...                                                         ...
# 10900                                    a letter to the editor
# 10923                                             a campaign ad
# 10939                           an interview on Fox News Sunday
# 10953                                         an opinion column
# 10976                                           in a Reddit AMA
# 10988                                          a campaign tweet
# 10992                                      a House floor speech
# 11007                                            an email blast
# 11043                                            an oped column
# 11044                                a speech in the U.S. House
# 11063                                     a campaign commercial
# 11091                                            a news release
# 11114                                     a campaign commercial
# 11268                                                   a TV ad
# 11269                                         in a TV interview
# 11281                        press release, Rep. Betty McCollum
# 11288  her victory speech after winning the Democratic primary.
# 11289  her victory speech after winning the Democratic primary.
# 11317            in a letter co-signed with others in Congress.
# 11329                                            a news release
# 11395                             comments on ABC's "This Week"
# 11399                      an interview on Fox Business Network
# 11439                                              an interview
# 11444                                     an interview on MSNBC
# 11453                                                  a debate
# 11516                                             a campaign ad
# 11517                                             a campaign ad
# 11520                                                   a tweet
# 11542                                             Press release
# 11582                                                   a TV ad
#
#       statement_date primary_votes_senate_2014  primary_votes_senate_2014_pct  \
# 1115      2016-04-27                       NaN                            NaN
# 1116      2012-12-11                       NaN                            NaN
# 1117      2015-08-26                       NaN                            NaN
# 1118      2015-01-14                       NaN                            NaN
# 1119      2014-05-29                       NaN                            NaN
# 1120      2011-12-27                       NaN                            NaN
# 1121      2016-11-18                       NaN                            NaN
# 1122      2016-06-23                       NaN                            NaN
# 1123      2014-11-11                       NaN                            NaN
# 1124      2011-04-30                       NaN                            NaN
# 1125      2010-10-07                       NaN                            NaN
# 1126      2010-12-15                       NaN                            NaN
# 1127      2016-03-16                       NaN                            NaN
# 1128      2013-09-29                       NaN                            NaN
# 1129      2016-08-15                       NaN                            NaN
# 1130      2012-09-04                       NaN                            NaN
# 1131      2015-01-07                       NaN                            NaN
# 1132      2012-04-28                       NaN                            NaN
# 1133      2015-09-29                       NaN                            NaN
# 1134      2013-07-24                       NaN                            NaN
# 1422      2014-11-13                       NaN                            NaN
# 1423      2013-05-13                       NaN                            NaN
# 1424      2010-02-04                       NaN                            NaN
# 1425      2014-06-17                       NaN                            NaN
# 1426      2010-09-23                       NaN                            NaN
# 1427      2010-06-04                       NaN                            NaN
# 1428      2010-03-18                       NaN                            NaN
# 1429      2008-08-25                       NaN                            NaN
# 1430      2009-01-08                       NaN                            NaN
# 1431      2009-10-05                       NaN                            NaN
# ...              ...                       ...                            ...
# 10900     2011-02-01                       NaN                            NaN
# 10923     2013-08-06                    125787                       0.361559
# 10939     2014-10-19                       NaN                            NaN
# 10988                    50916                      0.537327
# 10992                      NaN                           NaN
# 11007                      NaN                           NaN
# 11043                    49813                      0.614179
# 11044                    49813                      0.614179
# 11063                      NaN                           NaN
# 11091                      NaN                           NaN
# 11114                    23260                      0.571232
# 11268                    60502                      0.724167
# 11269                    60502                      0.724167
# 11281                      NaN                           NaN
# 11288                    13801                      0.712788
# 11289                Unopposed                           NaN
# 11317                    35350                      0.821654
# 11329                    30704                      1.000000
# 11395                    40380                      0.917227
# 11399                Unopposed                           NaN
# 11439                     9165                      0.344471
# 11444                    48393                      1.000000
# 11453                      NaN                           NaN
# 11516                      NaN                           NaN
# 11517                      NaN                           NaN
# 11520                Unopposed                           NaN
# 11542                    33624                      0.289147
# 11582                      NaN                           NaN
#
# [1461 rows x 17 columns]

# %%
_t.loc[useful_idx, 'speakers_job_title_cleaned'].value_counts()
# Out:
# senator                                                                                                 580
# houseman                                                                                                353
# milwaukee county executive                                                                              166
# congressman                                                                                             111
# nan                                                                                                     101
# governor                                                                                                 41
# small business owner                                                                                     13
# businessman                                                                                              13
# retired social worker                                                                                     8
# conservative activist                                                                                     7
# state assembly member, 78th district                                                                      7
# mayor                                                                                                     6
# alaska department of public resources commissioner                                                        5
# attorney                                                                                                  5
# member of state assembly, 82nd district                                                                   4
# developer                                                                                                 4
# nova southeastern university law professor                                                                4
# pediatric neurosurgeon                                                                                    4
# assemblywoman                                                                                             3
# actor                                                                                                     3
# candidate                                                                                                 3
# miami-dade school board member                                                                            2
# tompkins county legislator                                                                                2
# radiologist and radio station owner                                                                       2
# legislator                                                                                                2
# state assemblyman                                                                                         2
# management consultant                                                                                     2
# lawyer                                                                                                    2
# pinal county sheriff                                                                                      1
# director of communications for lamp post group, a venture capital incubator in chatt                      1
# private attorney                                                                                          1
# secretary, libertarian party of wisconsin midwest regional director, our america initiative lead coo      1
# investment manager                                                                                        1
# winnebago county executive                                                                                1
# Name: speakers_job_title_cleaned, dtype: int64

# %%
_t.loc[_t['speakers_job_title_cleaned'].isin(job_titles_of_interest) & useful_idx, columns_of_interest]
# Out:
#              label  label_as_nb  \
# 1115     half-true          4.0
# 1116   mostly-true          2.0
# 1117   barely-true          6.0
# 1118          true          0.0
# 1119         false          8.0
# 1120    pants-fire         10.0
# 1121          true          0.0
# 1122   mostly-true          2.0
# 1123   barely-true          6.0
# 1124         false          8.0
# 1125          true          0.0
# 1126         false          8.0
# 1127          true          0.0
# 1128     half-true          4.0
# 1129     half-true          4.0
# 1130   barely-true          6.0
# 1131   mostly-true          2.0
# 1132         false          8.0
# 1133          true          0.0
# 1134     half-true          4.0
# 1422         false          8.0
# 1423     half-true          4.0
# 1424     half-true          4.0
# 1425         false          8.0
# 1426    pants-fire         10.0
# 1427     half-true          4.0
# 1428     half-true          4.0
# 1429     half-true          4.0
# 1430         false          8.0
# 1431   barely-true          6.0
# ...            ...          ...
# 10479        false          8.0
# 10480  mostly-true          2.0
# 10520  barely-true          6.0
# 10538  barely-true          6.0
# 10539  mostly-true          2.0
# 10581         true          0.0
# 10582    half-true          4.0
# 10588  mostly-true          2.0
# 10609        false          8.0
# 10664        false          8.0
# 10670        false          8.0
# 10682         true          0.0
# 10775  mostly-true          2.0
# 10807    half-true          4.0
# 10900    half-true          4.0
# 10939  barely-true          6.0
# 10976         true          0.0
# 10992  barely-true          6.0
# 11007    half-true          4.0
# 11043    half-true          4.0
# 11044  barely-true          6.0
# 11281         true          0.0
# 11288    half-true          4.0
# 11289    half-true          4.0
# 11317        false          8.0
# 11329  barely-true          6.0
# 11395  mostly-true          2.0
# 11399  barely-true          6.0
# 11453        false          8.0
# 11520        false          8.0
#
#                                                                         subject  \
# 1115                                  financial-regulation,foreign-policy,water
# 1116                                               crime,criminal-justice,women
# 1117   city-government,civil-rights,criminal-justice,public-safety,state-budget
# 1118                              city-government,infrastructure,transportation
# 1119                                  children,crime,criminal-justice,sexuality
# 1120                                  corrections-and-updates,health-care,women
# 1121                           civil-rights,crime,criminal-justice,legal-issues
# 1122                                        crime,guns,terrorism,transportation
# 1123                                      economy,health-care,medicaid,medicare
# 1124                                          labor,state-budget,state-finances
# 1125                                                             crime,families
# 1126                                                      census,income,poverty
# 1127                                        congress,legal-issues,supreme-court
# 1128                              crime,government-regulation,health-care,women
# 1129                                               crime,criminal-justice,urban
# 1130                                            abortion,crime,criminal-justice
# 1131                        congress,economy,elections,job-accomplishments,jobs
# 1132                                                       income,poverty,taxes
# 1133              abortion,federal-budget,health-care,polls,public-health,women
# 1134                                federal-budget,financial-regulation,housing
# 1422                                                                health-care
# 1423                                                                health-care
# 1424                                                    federal-budget,stimulus
# 1425                                                         immigration,sports
# 1426                                                                    economy
# 1427                                                economy,job-accomplishments
# 1428                                                 federal-budget,health-care
# 1429                                                       candidates-biography
# 1430                                                             federal-budget
# 1431                                  environment,foreign-policy,transportation
# ...                                                                         ...
# 10479                                                                    census
# 10480                                                                    census
# 10520                                            candidates-biography,elections
# 10538               agriculture,children,corrections-and-updates,families,labor
# 10539                                                     government-efficiency
# 10581                                                                  congress
# 10582                                                                     taxes
# 10588                                                   civil-rights,crime,guns
# 10609                                                                     crime
# 10664                                                   health-care,immigration
# 10670                       government-regulation,infrastructure,small-business
# 10682                                                            congress,polls
# 10775                                                            guns,terrorism
# 10807                                                     congress,income,women
# 10900                                                               health-care
# 10939                  ebola,foreign-policy,israel,public-health,transportation
# 10976                                                                 elections
# 10992                             climate-change,federal-budget,science,weather
# 11007                                                             history,taxes
# 11043                                        crime,criminal-justice,health-care
# 11044                                                                   economy
# 11281                                                   federal-budget,military
# 11288                                                      congress,environment
# 11289                                                      congress,environment
# 11317     consumer-safety,government-regulation,public-safety,market-regulation
# 11329                                                               immigration
# 11395                                                                      jobs
# 11399                                         foreign-policy,military,terrorism
# 11453                                                              legal-issues
# 11520                                                         health-care,polls
#
#                        speaker speakers_job_title_cleaned         state_info  \
# 1115                gwen-moore                   houseman          Wisconsin
# 1116                gwen-moore                   houseman          Wisconsin
# 1117                gwen-moore                   houseman          Wisconsin
# 1426           democrat
# 1427           democrat
# 1428           democrat
# 1429           democrat
# 1430           democrat
# 1431           democrat
# ...                 ...
# 10479        republican
# 10480        republican
# 10520        republican
# 10538        republican
# 10539        republican
# 10581        republican
# 10582        republican
# 10588          democrat
# 10609        republican
# 10664        republican
# 10670        republican
# 10682          democrat
# 10775          democrat
# 10807          democrat
# 10900        republican
# 10939        republican
# 10976          democrat
# 10992        republican
# 11007        republican
# 11043        republican
# 11044        republican
# 11281          democrat
# 11288          democrat
# 11289          democrat
# 11317        republican
# 11329          democrat
# 11395          democrat
# 11399        republican
# 11453        republican
# 11520        republican
#
#                                                         context  \
# 1115                                    a congressional hearing
# 1116                       a letter to congressional leadership
# 1117                                      comments to reporters
# 1118                                  a newspaper opinion piece
# 1119                                 remarks on the House floor
# 1120                                                     tweets
# 1121                                               an interview
# 1122                                                    a tweet
# 1123                                          a radio interview
# 1124                a speech at a state Democratic Party dinner
# 1125                                             a news release
# 1126                       an interview with a weekly newspaper
# 1127                                                    a tweet
# 1128                                               an interview
# 1129                                               an interview
# 1130             a speech at the Democratic National Convention
# 1131                                                    a tweet
# 1132                                              a song/speech
# 1133                                                   a speech
# 1134                                             a news release
# 1422                                          a news conference
# 1423                                      an interview on MSNBC
# 1424                                         a press conference
# 1425                                                    a tweet
# 1426                                                a blog post
# 1427                                             a news release
# 1428                                            a press release
# 1429                                                     Denver
# 1430                                   during a news conference
# 1431                      an interview on the Charlie Rose Show
# ...                                                         ...
# 10479                                          an op ed article
# 10480                                          an op ed article
# 10520                                         his campaign blog
# 10538                                           a press release
# 10539                                           a press release
# 10581                                                 a meeting
# 10582                                                  a speech
# 10588                                        an MSNBC interview
# 10609                                                  a debate
# 10664               the audience at a joint session of Congress
# 10670                   in a blog post on his campaign website.
# 10682                           an op-ed published in The Hill.
# 10775                                                  a speech
# 10807                                           a press release
# 10900                                    a letter to the editor
# 10939                           an interview on Fox News Sunday
# 10976                                           in a Reddit AMA
# 10992                                      a House floor speech
# 11007                                            an email blast
# 11043                                            an oped column
# 11044                                a speech in the U.S. House
# 11281                        press release, Rep. Betty McCollum
# 11288  her victory speech after winning the Democratic primary.
# 11289  her victory speech after winning the Democratic primary.
# 11317            in a letter co-signed with others in Congress.
# 11329                                            a news release
# 11395                             comments on ABC's "This Week"
# 11399                      an interview on Fox Business Network
# 11453                                                  a debate
# 11520                                                   a tweet
#
#       statement_date primary_votes_senate_2014  primary_votes_senate_2014_pct  \
# 1115      2016-04-27                       NaN                            NaN
# 1116      2012-12-11                       NaN                            NaN
# 1117      2015-08-26                       NaN                            NaN
# 1118      2015-01-14                       NaN                            NaN
# 1119      2014-05-29                       NaN                            NaN
# 1120      2011-12-27                       NaN                            NaN
# 1121      2016-11-18                       NaN                            NaN
# 1122      2016-06-23                       NaN                            NaN
# 1123      2014-11-11                       NaN                            NaN
# 1124      2011-04-30                       NaN                            NaN
# 1125      2010-10-07                       NaN                            NaN
# 1126      2010-12-15                       NaN                            NaN
# 1127      2016-03-16                       NaN                            NaN
# 1121                       NaN                           NaN
# 1122                       NaN                           NaN
# 1123                       NaN                           NaN
# 1124                       NaN                           NaN
# 1125                       NaN                           NaN
# 1126                       NaN                           NaN
# 1127                       NaN                           NaN
# 1128                       NaN                           NaN
# 1129                       NaN                           NaN
# 1130                       NaN                           NaN
# 1131                       NaN                           NaN
# 1132                       NaN                           NaN
# 1133                       NaN                           NaN
# 1134                       NaN                           NaN
# 1422                    169537                      0.781125
# 1423                    169537                      0.781125
# 1424                    169537                      0.781125
# 1425                    169537                      0.781125
# 1426                    169537                      0.781125
# 1427                    169537                      0.781125
# 1428                    169537                      0.781125
# 1429                    169537                      0.781125
# 1430                    169537                      0.781125
# 1431                    169537                      0.781125
# ...                        ...                           ...
# 10479                    14817                      0.784176
# 10480                    14817                      0.784176
# 10520                   101026                      1.000000
# 10538                Unopposed                           NaN
# 10539                Unopposed                           NaN
# 10581                    24201                      1.000000
# 10582                    24201                      1.000000
# 10588                   144719                      0.990419
# 10609                      NaN                           NaN
# 10664                Unopposed                           NaN
# 10670                    31964                      0.838972
# 10682                    32103                      1.000000
# 10775                      NaN                           NaN
# 10807                      NaN                           NaN
# 10900                      NaN                           NaN
# 10939                    88266                      0.993483
# 10976                      NaN                           NaN
# 10992                      NaN                           NaN
# 11007                      NaN                           NaN
# 11043                    49813                      0.614179
# 11044                    49813                      0.614179
# 11281                      NaN                           NaN
# 11288                    13801                      0.712788
# 11289                Unopposed                           NaN
# 11317                    35350                      0.821654
# 11329                    30704                      1.000000
# 11395                    40380                      0.917227
# 11399                Unopposed                           NaN
# 11453                      NaN                           NaN
# 11520                Unopposed                           NaN
#
# [1091 rows x 17 columns]

# %% [markdown]
# Now, our dataframe looks like this:

# %%
_t.head(1)
# Out:
#    statement_id      label  \
# 0       10540.0  half-true
#
#                                                                                                                                        statement  \
# 0  When did the decline of coal start? It started when natural gas took off that started to begin in (President George W.) Bushs administration.
#
#                               subject         speaker speakers_job_title  \
# 0  energy,history,job-accomplishments  scott-surovell     State delegate
#
#   state_info party_affiliation  barely_true_counts  false_counts  \
# 0   Virginia          democrat                 0.0           0.0
#
#    half_true_counts  mostly_true_counts  pants_on_fire_counts  \
# 0               1.0                 1.0                   0.0
#
#            context  label_as_nb author_name_slug          ruling_date  \
# 0  a floor speech.          4.0      sean-gorman  2015-02-23T00:00:00
#
#   speaker_current_job speaker_first_name speaker_home_state speaker_last_name  \
# 0      State delegate              Scott           Virginia          Surovell
#
#   statement_date  statement_year speaker_full_name speakers_job_title_cleaned  \
# 0     2015-02-04          2015.0   Surovell, Scott             state delegate
#
#   CANDIDATE NAME primary_votes_senate_2014  primary_votes_senate_2014_pct  \
# 0            NaN                       NaN                            NaN
#
#   primary_votes_house_2014  primary_votes_house_2014_pct  \
# 0                      NaN                           NaN
#
#   primary_votes_senate_2016  primary_votes_senate_2016_pct  \
# 0                       NaN                            NaN
#
#   primary_votes_house_2016  primary_votes_house_2016_pct
# 0                      NaN                           NaN

# %% [markdown]
# # County Data

# %%
# load data file
county_raw = pd.read_csv(f"{directory_county_data}/acs2015_county_data.csv")
US_states = county_raw['State'].unique()
county_raw.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native  Asian  Pacific  Citizen   Income  IncomeErr  IncomePerCap  \
# 0     0.4    1.0      0.0    40725  51281.0     2391.0         24974
# 1     0.6    0.7      0.0   147695  50254.0     1263.0         27317
# 2     0.2    0.4      0.0    20714  32964.0     2973.0         16824
# 3     0.4    0.1      0.0    17495  38678.0     3995.0         18431
# 4     0.3    0.1      0.0    42345  45813.0     3141.0         20532
#
#    IncomePerCapErr  Poverty  ChildPoverty  Professional  Service  Office  \
# 0             1080     12.9          18.6          33.2     17.0    24.2
# 1              711     13.4          19.2          33.1     17.7    27.1
# 2              798     26.7          45.3          26.8     16.1    23.1
# 3             1618     16.8          27.9          21.5     17.9    17.8
# 4              708     16.7          27.2          28.5     14.1    23.9
#
#    Construction  Production  Drive  Carpool  Transit  Walk  OtherTransp  \
# 0           8.6        17.1   87.5      8.8      0.1   0.5          1.3
# 1          10.8        11.2   84.7      8.8      0.1   1.0          1.4
# 2          10.8        23.1   83.8     10.9      0.4   1.8          1.5
# 3          19.0        23.7   83.2     13.5      0.5   0.6          1.5
# 4          13.5        19.9   84.9     11.2      0.4   0.9          0.4
#
#    WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0         1.8         26.5     23986         73.6        20.9           5.5
# 1         3.9         26.4     85953         81.5        12.3           5.8
# 2         1.6         24.1      8597         71.8        20.8           7.3
# 3         0.7         28.8      8294         76.8        16.1           6.7
# 4         2.3         34.9     22189         82.0        13.5           4.2
#
#    FamilyWork  Unemployment
# 0         0.0           7.6
# 1         0.4           7.5
# 2         0.1          17.6
# 3         0.4           8.3
# 4         0.4           7.7

# %% [markdown]
# # DATA SET COMPLETE

# %% [markdown]
# At this point, we collected all the columns we need. Let's see how we can clean them:

# %%
median_speaker_value = _t.groupby(['statement_year', 'speaker'])['label_as_nb'].median().reset_index()

# %%
median_speaker_value[median_speaker_value['statement_year'] == 2016]
# Out:
#       statement_year                                      speaker  label_as_nb
# 4334          2016.0                   18-percent-american-public          0.0
# 4335          2016.0                                  Jack_Graham          8.0
# 4336          2016.0                          aclu-north-carolina          0.0
# 4337          2016.0                                  actionaid-k          3.0
# 4338          2016.0                                       afscme          4.0
# 4339          2016.0                                afscme-people          2.0
# 4340          2016.0                                      al-gore          4.0
# 4341          2016.0                                 alan-grayson          3.0
# 4342          2016.0                               alcee-hastings         10.0
# 4343          2016.0                             alex-castellanos          6.0
# 4344          2016.0                                allen-buckley          2.0
# 4345          2016.0                               alternativepac          0.0
# 4346          2016.0                           america-rising-now          6.0
# 4347          2016.0                         american-future-fund          7.0
# 4348          2016.0                           american-unity-pac          8.0
# 4349          2016.0                          americanpoliticnews         10.0
# 4350          2016.0                         americans-prosperity          8.0
# 4351          2016.0                 americans-prosperity-florida          6.0
# 4352          2016.0  americans-prosperity-north-carolina-chapter          4.0
# 4353          2016.0              americans-responsible-solutions          4.0
# 4354          2016.0                      americans-united-change          4.0
# 4355          2016.0                                     ami-bera          3.0
# 4356          2016.0                                amy-klobuchar          2.0
# 4357          2016.0                                  amy-schumer          4.0
# 4358          2016.0                                 andrew-cuomo          0.0
# 4359          2016.0                            andrew-napolitano          6.0
# 4360          2016.0                                  ann-coulter          8.0
# 4361          2016.0                              ann-kirkpatrick          4.0
# 4362          2016.0                            anna-throne-holst          8.0
# 4363          2016.0                                  annies-list          0.0
# ...              ...                                          ...          ...
# 4872          2016.0                       trusted-leadership-pac          8.0
# 4873          2016.0                            turning-point-usa          8.0
# 4874          2016.0                                       tweets          8.0
# 4875          2016.0                                         uber          4.0
# 4876          2016.0                    unbreakable-kimmy-schmidt          8.0
# 4877          2016.0                                  united-care          6.0
# 4878          2016.0                          us-chamber-commerce          0.0
# 4879          2016.0                      us-dairy-export-council          6.0
# 4880          2016.0                                   usain-bolt          2.0
# 4881          2016.0                                    van-jones          2.0
# 4882          2016.0                                van-wanggaard          4.0
# 4883          2016.0                        various-media-reports          0.0
# 4884          2016.0                                vernon-keenan          0.0
# 4885          2016.0                                 vicki-martin          2.0
# 4886          2016.0                                vicki-saporta          4.0
# 4887          2016.0                              victoria-seaman          2.0
# 4888          2016.0                                        video          4.0
# 4889          2016.0                                  viral-image         10.0
# 4890          2016.0                    virginia-first-foundation          4.0
# 4891          2016.0                                    vote-no-2          4.0
# 4892          2016.0                                  wendy-davis          8.0
# 4893          2016.0                               william-barber          2.0
# 4894          2016.0                            william-devereaux          0.0
# 4895          2016.0                                 william-ruto          8.0
# 4896          2016.0                                 william-weld          4.0
# 4897          2016.0                            winning-democrats          8.0
# 4898          2016.0                    wisconsin-alliance-reform          6.0
# 4899          2016.0                           wisconsin-jobs-now         10.0
# 4900          2016.0                  yes-62-death-penalty-repeal          0.0
# 4901          2016.0                              zephyr-teachout          4.0
#
# [568 rows x 3 columns]

# %% [markdown]
# ### Non-People Speakers Handling

# %% [markdown]
# Removing non-people (_tweets, facebook posts, etc._) from the dataset:

# %%
from nltk import download
download('punkt')
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize
from nltk import sent_tokenize
from collections import Counter

model = 'nlp/stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.crf.ser.gz'
jar = 'nlp/stanford-ner-2018-10-16/stanford-ner-3.9.2.jar'
st = StanfordNERTagger(model, jar, encoding='utf-8')

def get_tag(speaker):
    ner_tag = 0
    if type(speaker) == str:
        full_speaker_name = speaker.replace("-", " ").title()

        for sent in sent_tokenize(full_speaker_name):
            tokens = word_tokenize(sent)
            tags = st.tag(tokens)
            
        ner_tag= Counter(dict(tags).values()).most_common(1)[0][0]
        print(tags, " --> ", ner_tag)
    return ner_tag
    

# just to see if/how it works
word = "Twitter-Post-Anna"
get_ner_tag(word)

full_speaker_name = "Barack-Obama"
get_ner_tag(full_speaker_name)

full_speaker_name = 0
get_ner_tag(full_speaker_name)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Jelena
# [nltk_data]     Banjac\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('Twitter', 'ORGANIZATION'), ('Post', 'ORGANIZATION'), ('Anna', 'PERSON')]  -->  ORGANIZATION
# [('Barack', 'PERSON'), ('Obama', 'PERSON')]  -->  PERSON
# 0

# %%
import os.path

file_path = 'nlp/speaker_tags.json'

if not os.path.exists(file_path):
    print(f"Total number of values to classify: {len(_t['speaker'].value_counts().index)}")

    words_with_tags = {}
    for word in _t['speaker'].value_counts().index:
        words_with_tags[word] = get_tag(word)
    
    # save tags, since it took ~3h to tag all 3214 unique speakers
    with open(file_path, 'w') as fp:
        json.dump(words_with_tags, fp, indent=4)
else:
    with open(file_path, 'r') as f:
        words_with_tags = json.load(f)
    print(f"Total number of classified values (from file): {len(words_with_tags)}")
# Out:
# Total number of classified values (from file): 3124

# %%
_t["speaker_tag"] = _t.apply(lambda row: words_with_tags[row['speaker']] if not pd.isnull(row['speaker']) else row['speaker'], axis=1)
_t[['speaker','speaker_tag']].drop_duplicates()
# Out:
#                     speaker speaker_tag
# 0            scott-surovell      PERSON
# 1              barack-obama      PERSON
# 370            bobby-jindal      PERSON
# 623           charlie-crist      PERSON
# 704               robin-vos      PERSON
# 725          oregon-lottery      PERSON
# 727           duey-stroebel      PERSON
# 728         robert-menendez      PERSON
# 739                bernie-s      PERSON
# 838             mitt-romney      PERSON
# 1039            george-will      PERSON
# 1115             gwen-moore      PERSON
# 1135               jack-lew      PERSON
# 1137      dennis-richardson      PERSON
# 1143           eric-bolling      PERSON
# 1147        hillary-clinton      PERSON
# 1422           nancy-pelosi      PERSON
# 1450             ted-nugent      PERSON
# 1454          pamela-geller      PERSON
# 1456           peter-kinder      PERSON
# 1459        nicholas-kettle      PERSON
# 1460   shelley-moore-capito      PERSON
# 1462             rick-scott      PERSON
# 1591             tom-cotton      PERSON
# 1603               ted-cruz      PERSON
# 1710        lee-leffingwell      PERSON
# 1721           kelly-ayotte      PERSON
# 1731            marco-rubio      PERSON
# 1872          rachel-maddow      PERSON
# 1893        jerry-patterson      PERSON
# ...                     ...         ...
# 11555          pat-buchanan      PERSON
# 11557          gail-buckner      PERSON
# 11558       daniel-lipinski      PERSON
# 11559            alan-essig      PERSON
# 11560            gary-kelly      PERSON
# 11561        vincent-prieto      PERSON
# 11562          bill-mcraven      PERSON
# 11563         rebecca-blank      PERSON
# 11564         john-whitmire      PERSON
# 11565           steve-deace      PERSON
# 11566          john-stossel      PERSON
# 11567       michael-cerullo      PERSON
# 11568          maureen-dowd      PERSON
# 11569         chris-chocola      PERSON
# 11570          joshua-henne      PERSON
# 11571        joel-kleefisch      PERSON
# 11572        valarie-wilson      PERSON
# 11573      hank-williams-jr      PERSON
# 11574           bob-kincaid      PERSON
# 11575         vicki-mckenna      PERSON
# 11576         francis-kungu      PERSON
# 11577          daniel-senor      PERSON
# 11579          john-sherman      PERSON
# 11580         nancy-nusbaum      PERSON
# 11581         julie-parrish      PERSON
# 11582         mike-mcfadden      PERSON
# 11583             bob-latta      PERSON
# 11584        thomas-lindsay      PERSON
# 11585         brad-rockwell      PERSON
# 11587          sal-esquivel      PERSON
#
# [2466 rows x 2 columns]

# %% [markdown]
# Seems good, so now let's remove non-people from the dataset:

# %%
_t.shape
# Out:
# (9803, 37)

# %%
_t[_t['speaker_tag'] == "PERSON"].shape
# Out:
# (9803, 37)

# %% [markdown]
# We see that we will remove ~5000 statements which are made by (speaker) _Twitter, Facebook, Blog post, Republican Party Texas, etc._

# %%
# removing non-people statements
_t = _t[_t['speaker_tag'] == "PERSON"]

# %% [markdown]
# ### Clean-up Context

# %%
_t["context"].value_counts().index.values
# Out:
# array(['an interview', 'a speech', 'a news release', ...,
#        'an immigration forum', 'Atlanta City Council meeting',
#        'an episode of The Rachel Maddow Show.'], dtype=object)

# %% [markdown]
# It would be good to try using the tool that would extract keywords from these phases. Let's use NLTK Rake:

# %%
from rake_nltk import Rake, Metric
from collections import Counter

debug = False

def do_keyword_extraction(words):
    if debug: print("---\n", words)
        
    rake_all = Rake()
    rake_all.extract_keywords_from_sentences(_t["context"].value_counts().index.values)

    word_degrees = dict(rake_all.get_word_degrees())
    
    r = Rake()
    r.extract_keywords_from_text(words)

    keywords = dict(r.get_word_degrees())
    
    if debug: print(keywords)
        
    for k, v in keywords.items():
        keywords[k] = word_degrees[k]
    
    if debug: print(keywords)

    return Counter(keywords).most_common(1)[0]

# %%
# try to see how it works
text_to_process = "a television interview"
do_keyword_extraction("an interview")
do_keyword_extraction("a television interview")
do_keyword_extraction("a TV interview")
# Out:
# ('interview', 158)

# %%
_t["context_tag"] = _t.apply(lambda row: do_keyword_extraction(row['context']) if not pd.isnull(row['context']) else row['context'], axis=1)

# %%
context_tags = _t[['context','context_tag']]['context_tag'].value_counts()
print(f"Number of different context tags is {len(context_tags)}")
context_tags
# Out:
# Number of different context tags is 271
# (interview, 158)       1268
# (speech, 175)           877
# (debate, 437)           874
# (news, 329)             833
# (campaign, 406)         729
# (press, 228)            656
# (ad, 126)               355
# (radio, 198)            267
# (state, 183)            231
# (post, 97)              205
# (show, 227)             204
# (house, 222)            194
# (tweet, 16)             181
# (senate, 229)           154
# (column, 53)            147
# (meeting, 149)          119
# (article, 78)           112
# (new, 205)               95
# (statement, 69)          91
# (video, 92)              84
# (letter, 33)             81
# (email, 48)              81
# (website, 72)            75
# (ed, 45)                 74
# (abc, 23)                70
# (texas, 168)             65
# (forum, 78)              63
# (hearing, 149)           56
# (journal, 71)            48
# (rally, 45)              46
#                        ...
# (reporter, 11)            1
# (virginia, 1)             1
# (co, 5)                   1
# (filibuster, 6)           1
# (teleconference, 1)       1
# (various, 12)             1
# (milwaukee, 24)           1
# (webcast, 1)              1
# (union, 26)               1
# (politics, 16)            1
# (nh, 9)                   1
# (series, 1)               1
# (dallas, 19)              1
# (.,, 14)                  1
# (president, 17)           1
# (pledge, 1)               1
# (clair, 2)                1
# (reilly, 6)               1
# (indianapolis, 1)         1
# (boonville, 1)            1
# (voting, 9)               1
# (atlanta, 29)             1
# (cape, 2)                 1
# (countdown, 4)            1
# (economic, 24)            1
# (commercial, 30)          1
# (david, 18)               1
# (comedy, 4)               1
# (resolution, 6)           1
# (columbia, 6)             1
# Name: context_tag, Length: 271, dtype: int64

# %% [markdown]
# We see that the number of context tags is 271, which is a preatty big number. Let's consider decreasing this number and make smaller groups.

# %%
# TODO: make smaller context groups, ideally around 10

# %%
# TODO: implement tagging on the cleaned jobs as well

# %%
# TODO: plot the answers from research questions we have

# %% [markdown]
# ## Some initial insights

# %%
_t['sum_not_so_true'] = _t['pants_on_fire_counts']/(_t['barely_true_counts'] + _t['false_counts'] + _t['half_true_counts'] + _t['mostly_true_counts'] + _t['pants_on_fire_counts'])
number_of_party_affiliation = _t.groupby('party_affiliation')['sum_not_so_true'].sum().sort_values(ascending=False)
number_of_party_affiliation
# Out:
# party_affiliation
# republican                      444.294341
# democrat                        170.195967
# none                             73.311320
# newsmaker                         5.250000
# talk-show-host                    4.500000
# libertarian                       3.333333
# independent                       2.666667
# business-leader                   2.000000
# journalist                        1.666667
# green                             1.500000
# columnist                         1.181818
# tea-party-member                  1.000000
# labor-leader                      1.000000
# organization                      1.000000
# constitution-party                0.666667
# liberal-party-canada              0.000000
# education-official                0.000000
# democratic-farmer-labor           0.000000
# ocean-state-tea-party-action      0.000000
# county-commissioner               0.000000
# state-official                    0.000000
# activist                          0.000000
# Moderate                          0.000000
# Name: sum_not_so_true, dtype: float64

# %% [markdown]
# Here are the `party_affiliations` who most lie ordered by their proportion of lies. But we already know that the 2 dominant parties in USA are republican and democrat. We see that there are lots of unknown party affiliations from which we can make identify 2 possibilities

# %%
number_of_party_affiliation = _t.groupby(['speaker'])['sum_not_so_true'].sum().sort_values(ascending=False)
number_of_party_affiliation.head(10)
# Out:
# speaker
# donald-trump        58.006135
# mitt-romney         21.051136
# rick-perry          19.636364
# michele-bachmann    15.428571
# scott-walker        12.173333
# newt-gingrich       11.763889
# barack-obama        10.446089
# rush-limbaugh        9.459459
# john-mccain          9.205479
# chris-christie       8.987654
# Name: sum_not_so_true, dtype: float64

# %% [markdown]
# Looking at the dataset content, people above are sorted quantity of lies.

# %%
all_contexts = _t['context_tag'].unique()
nb_elements_context = _t.groupby(['context_tag'])['context_tag'].count().sort_values(ascending=False)
nb_elements_context.head(50)
# Out:
# context_tag
# (interview, 158)     1268
# (speech, 175)         877
# (debate, 437)         874
# (news, 329)           833
# (campaign, 406)       729
# (press, 228)          656
# (ad, 126)             355
# (radio, 198)          267
# (state, 183)          231
# (post, 97)            205
# (show, 227)           204
# (house, 222)          194
# (tweet, 16)           181
# (senate, 229)         154
# (column, 53)          147
# (meeting, 149)        119
# (article, 78)         112
# (new, 205)             95
# (statement, 69)        91
# (video, 92)            84
# (letter, 33)           81
# (email, 48)            81
# (website, 72)          75
# (ed, 45)               74
# (abc, 23)              70
# (texas, 168)           65
# (forum, 78)            63
# (hearing, 149)         56
# (journal, 71)          48
# (rally, 45)            46
# (cnn, 34)              42
# (hall, 78)             39
# (tv, 102)              34
# (mail, 23)             34
# (appearance, 32)       33
# (comments, 18)         31
# (reporters, 24)        29
# (discussion, 31)       27
# (committee, 216)       27
# (public, 109)          27
# (newsletter, 15)       26
# (conference, 157)      26
# (broadcast, 27)        26
# (remarks, 26)          25
# (bill, 42)             24
# (newspaper, 42)        22
# (times, 77)            22
# (address, 69)          21
# (web, 74)              21
# (media, 37)            21
# Name: context_tag, dtype: int64

# %% [markdown]
# Looking at the context, it seems that people lie the most during the interviews, then speech, after debates, and so on...

# %% [markdown]
# ## [misc] One statement content visualization

# %% [markdown]
# Let's analyse first row, statement with id `1`. What is the information we get there?

# %%
sid = 1.0

# %%
_t[_t.statement_id == sid]
# Out:
#        statement_id       label  \
# 11184           1.0  pants-fire
#
#                                                                    statement  \
# 11184  The attorney general requires that rape victims pay for the rape kit.
#
#            subject                speaker speakers_job_title state_info  \
# 11184  crime,women  barbara-ann-radnofsky                NaN        NaN
#
#       party_affiliation  barely_true_counts  false_counts  half_true_counts  \
# 11184          democrat                 0.0           0.0               0.0
#
#        mostly_true_counts  pants_on_fire_counts              context  \
# 11184                 0.0                   1.0  in a Web site video
#
#        label_as_nb       author_name_slug          ruling_date  \
# 11184         10.0  meghan-ashford-grooms  2010-01-12T15:52:21
#
#       speaker_current_job speaker_first_name speaker_home_state  \
# 11184                            Barbara Ann
#
#       speaker_last_name statement_date  statement_year  \
# 11184         Radnofsky     2009-10-22          2009.0
#
#             speaker_full_name speakers_job_title_cleaned CANDIDATE NAME  \
# 11184  Radnofsky, Barbara Ann                        nan            NaN
#
#       primary_votes_senate_2014  primary_votes_senate_2014_pct  \
# 11184                       NaN                            NaN
#
#       primary_votes_house_2014  primary_votes_house_2014_pct  \
# 11184                      NaN                           NaN
#
#       primary_votes_senate_2016  primary_votes_senate_2016_pct  \
# 11184                       NaN                            NaN
#
#       primary_votes_house_2016  primary_votes_house_2016_pct  ner_lbl ner_tag
# 11184                      NaN                           NaN      NaN  PERSON

# %%
with open(f"{directory_statements}/{int(sid)}.json", "r") as f:
    data = json.load(f)

# %% [markdown]
# Just to visualize JSON hierarchy, run the following cell:

# %%
def go_further(dic, name):
    dict_vis = {"name": name, "children": []}
    for k, v in dic.items():
        if type(v) == str:
            new_el = {"name": k}
        elif type(v) == list:
            if len(v) > 0:
                new_el = go_further(v[0], k)
        elif type(v) == dict:
            new_el = go_further(v, k)
        else:
            new_el = {"name": k}
        dict_vis["children"].append(new_el)
        
    return dict_vis

my_dict = go_further(data, name="statement_info")

with open(f"{directory_visualizations}/data.json", "w") as f:
    json.dump(my_dict, f)

print(f"Checkout visualization by: \n1) cd ../visualizations \n2) python -m http.server \n3) in browser, open: http://localhost:8000/")
