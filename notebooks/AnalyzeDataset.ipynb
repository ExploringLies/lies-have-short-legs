# %% [markdown]
# # Analysing Dataset

# %%
import pandas as pd
import pandas_profiling
import requests
import os
import json
import time
import datetime

# %%
directory_liar_dataset = "../liar_dataset"
directory_statements = f"{directory_liar_dataset}/statements"
directory_visualizations = "../visualizations"

# %%
df_train = pd.read_csv(f"{directory_liar_dataset}/train.tsv", sep='\t')
df_train.columns = ['statement_id', 'label', 'statement', 'subject', 'speaker', 'speakers_job_title', 'state_info', 'party_affiliation', 'barely_true_counts', 'false_counts', 'half_true_counts', 'mostly_true_counts', 'pants_on_fire_counts', 'context']

# %%
df_valid = pd.read_csv(f"{directory_liar_dataset}/valid.tsv", sep='\t')
df_valid.columns = ['statement_id', 'label', 'statement', 'subject', 'speaker', 'speakers_job_title', 'state_info', 'party_affiliation', 'barely_true_counts', 'false_counts', 'half_true_counts', 'mostly_true_counts', 'pants_on_fire_counts', 'context']

# %%
df = pd.concat([df_train, df_valid],ignore_index=True)
df.statement_id = df.statement_id.apply(lambda x: x[:-5])  # remove .json and get just ID

# %%
df.head(3)
# Out:
#   statement_id        label  \
# 0        10540    half-true
# 1          324  mostly-true
# 2         1123        false
#
#                                            statement  \
# 0  When did the decline of coal start? It started...
# 1  Hillary Clinton agrees with John McCain "by vo...
# 2  Health care reform legislation is likely to ma...
#
#                               subject         speaker speakers_job_title  \
# 0  energy,history,job-accomplishments  scott-surovell     State delegate
# 1                      foreign-policy    barack-obama          President
# 2                         health-care    blog-posting                NaN
#
#   state_info party_affiliation  barely_true_counts  false_counts  \
# 0   Virginia          democrat                 0.0           0.0
# 1   Illinois          democrat                70.0          71.0
# 2        NaN              none                 7.0          19.0
#
#    half_true_counts  mostly_true_counts  pants_on_fire_counts          context
# 0               1.0                 1.0                   0.0  a floor speech.
# 1             160.0               163.0                   9.0           Denver
# 2               3.0                 5.0                  44.0   a news release

# %% [markdown]
# ## One row analysis

# %% [markdown]
# Let's analyse first row, statement with id `1`. What is the information we get there?

# %%
sid = '1'

# %%
df[df.statement_id == sid]
# Out:
#      statement_id       label  \
# 9403            1  pants-fire
#
#                                               statement      subject  \
# 9403  The attorney general requires that rape victim...  crime,women
#
#                     speaker speakers_job_title state_info party_affiliation  \
# 9403  barbara-ann-radnofsky                NaN        NaN          democrat
#
#       barely_true_counts  false_counts  half_true_counts  mostly_true_counts  \
# 9403                 0.0           0.0               0.0                 0.0
#
#       pants_on_fire_counts              context
# 9403                   1.0  in a Web site video

# %%
with open(f"{directory_statements}/{sid}.json", "r") as f:
    data = json.load(f)
data
# Out:
# {'art': [{'brightcove': '',
#    'caption': "We're Going to Need a Bigger List",
#    'id': 257,
#    'infogram': '',
#    'ndn': '',
#    'ndnid': '',
#    'other': '',
#    'photo': None,
#    'resource_type': {'id': 2,
#     'name': 'YouTube',
#     'resource_uri': '/api/v/2/mediatype/2/'},
#    'resource_uri': '/api/v/2/media/257/',
#    'title': 'Radnofsky video',
#    'wibbitz': '',
#    'youtube': '<iframe src="//www.youtube.com/embed/OrKDN_FL4iM?rel=0&wmode=opaque" frameborder="0" allowfullscreen></iframe>',
#    'youtubeID': 'OrKDN_FL4iM'}],
#  'author': [{'email_address': 'mashford-grooms@statesman.com',
#    'first_name': 'Meghan',
#    'id': 118,
#    'last_name': 'Ashford-Grooms',
#    'name_slug': 'meghan-ashford-grooms',
#    'on_staff_page': None,
#    'phone': None,
#    'photo': None,
#    'publication': {'id': 3,
#     'publication_name': 'Austin American-Statesman',
#     'resource_uri': '/api/v/2/publication/3/'},
#    'resource_uri': '/api/v/2/staffer/118/',
#    'title': 'PolitiFact Texas staff writer',
#    'twitter': None}],
#  'canonical_url': '/texas/statements/2010/jan/12/barbara-ann-radnofsky/radnofsky-says-attorney-general-requires-rape-vict/',
#  'edition': {'adkey': 'Editions',
#   'advalue': 'Texas',
#   'edition': 'Texas',
#   'edition_slug': 'texas',
#   'has_afterthefact': False,
#   'id': 2,
#   'index_page': False,
#   'meter_name': 'The Texas Truth-O-Meter',
#   'resource_uri': '/api/v/2/edition/2/'},
#  'editor': [{'email_address': 'bbell@statesman.com',
#    'first_name': 'Brenda',
#    'id': 267,
#    'last_name': 'Bell',
#    'name_slug': 'brenda-bell',
#    'on_staff_page': None,
#    'phone': None,
#    'photo': None,
#    'publication': {'id': 3,
#     'publication_name': 'Austin American-Statesman',
#     'resource_uri': '/api/v/2/publication/3/'},
#    'resource_uri': '/api/v/2/staffer/267/',
#    'title': 'Projects Editor',
#    'twitter': None}],
#  'facebook_headline': None,
#  'id': 1,
#  'in_future': False,
#  'is_pundit': False,
#  'make_public': True,
#  'preview': True,
#  'researcher': [{'email_address': 'mashford-grooms@statesman.com',
#    'first_name': 'Meghan',
#    'id': 118,
#    'last_name': 'Ashford-Grooms',
#    'name_slug': 'meghan-ashford-grooms',
#    'on_staff_page': None,
#    'phone': None,
#    'photo': None,
#    'publication': {'id': 3,
#     'publication_name': 'Austin American-Statesman',
#     'resource_uri': '/api/v/2/publication/3/'},
#    'resource_uri': '/api/v/2/staffer/118/',
#    'title': 'PolitiFact Texas staff writer',
#    'twitter': None}],
#  'resource_uri': '/api/v/2/statement/1/',
#  'ruling': {'adkey': 'Truth-O-Meter',
#   'advalue': 'Pants on Fire',
#   'id': 6,
#   'resource_uri': '/api/v/2/statementruling/6/',
#   'ruling': 'Pants on Fire!',
#   'ruling_graphic': 'https://s3.amazonaws.com/static.politifact.com/rulings/tom-pantsonfire.gif',
#   'ruling_slug': 'pants-fire'},
#  'ruling_comments': '<p>\r\n\tIn her campaign to become the next attorney general of Texas, Democratic candidate Barbara Ann Radnofsky is using a crime-victim issue to attack her opponent, GOP incumbent Greg Abbott.<br />\r\n\t<br />\r\n\tIn a video on her Web site, Radnofsky makes the provocative claim that &quot;the attorney general requires that rape victims pay for the rape kit&quot; &mdash; a reference to forensic examinations given to victims of sexual assault.<br />\r\n\t<br />\r\n\t<strong> </strong>We wondered whether Radnofsky&#39;s statement was true. This is what we found:<br />\r\n\t<br />\r\n\tUnder current state law, sexual assault victims in Texas should never have to pay for their forensic exams, which are done by medical professionals to collect physical evidence for the investigation and prosecution of sexual assault suspects. Local law enforcement agencies are responsible for paying hospitals for rape kits in cases in which the victims report the crimes. Those agencies can seek reimbursement of up to $700 through the Crime Victims&rsquo; Compensation Fund, which is administered by the attorney general&rsquo;s office. If a victim chooses not to report the crime, the Texas Department of Public Safety is responsible for paying for the exam and getting reimbursement from the fund.<br />\r\n\t<br />\r\n\tWhen asked about Radnofsky&rsquo;s statement in the video, Torie Camp, deputy director of the Texas Association Against Sexual Assault, a victims advocacy organization, said, &quot;That&rsquo;s not true, and if any rape victims are paying for rape kits, that shouldn&rsquo;t happen. State law is very clear on this issue, and the attorney general can&rsquo;t trump state law to make rape victims pay for rape kits.&quot;<br />\r\n\t<br />\r\n\tBut Texas law hasn&#39;t always read that way. In the past, rape exams were done by medical professionals and then paid for by law enforcement agencies only if sexual assault victims reported the crimes. The reauthorization of the Violence Against Women Act, signed by President George W. Bush in 2006, gave&nbsp;states three years to eliminate such reporting requirements so that all victims could obtain free forensic medical exams. In 2009, the Texas Legislature finally changed the law, directing the Department of Public Safety to cover the cost of a rape kit for any victim who chooses not to report.<br />\r\n\t<br />\r\n\tFor Radnofsky, that change took too long. She says that Abbott could have -- and should have -- acted earlier to bring administration of the victims&#39; compensation fund into compliance with the federal act. <br />\r\n\t<br />\r\n\tA spokesman for Abbott&#39;s office says the attorney general did not have the authority to change a policy that was mandated by state law.<br />\r\n\t<br />\r\n\tWhen asked if she knew of any instances when victims had paid for their own rape kits, Radnofsky said she did not.<br />\r\n\t<br />\r\n\tBut she isn&#39;t the first person to wade into this gnarly issue.<br />\r\n\t<br />\r\n\tIn May, a Houston television station aired a report, picked up by CNN, that caused an uproar in the advocacy community because it implied that sexual assault victims were being billed for forensic exams, Camp said.<br />\r\n\t<br />\r\n\tIn response, both the attorney general&rsquo;s office and TAASA issued public statements that termed the TV story  inaccurate and misleading. The attorney general&#39;s office said that as of Jan. 1, the office had paid for 57,702 rape exams since December 2002 and had not denied any requests for reimbursements for the kits from law enforcement agencies.<br />\r\n\t<br />\r\n\t<a href="http://taasa.org/blog/announcement/an-open-letter-to-sexual-assault-victims-in-texas/" target="_blank" title="TAASA">TAASA</a> said the TV report implied that billing victims for their rape kits &quot;was a common practice in Texas despite being told by several sources &hellip; that this was not the case. &hellip; The problem is th ...
#  'ruling_comments_date': '2010-01-07T13:49:18.464031',
#  'ruling_date': '2010-01-12T15:52:21',
#  'ruling_headline': 'Radnofsky says the attorney general requires rape victims pay for rape kits.',
#  'ruling_headline_slug': 'radnofsky-says-attorney-general-requires-rape-vict',
#  'ruling_link_text': "Victims aren't stuck with the bill",
#  'ruling_state': None,
#  'source_documents': None,
#  'sources': '<p>\r\n\tTexas Legislature, <a href="http://www.legis.state.tx.us/BillLookup/Text.aspx?LegSess=81R&amp;Bill=HB2626" target="_blank">House Bill No. 2626</a></p>\r\n<p>\r\n\tTexas Code of Criminal Procedure, Chapter 56, <a href="http://www.statutes.legis.state.tx.us/Docs/CR/htm/CR.56.htm" target="_blank">Rights of Crime Victims</a></p>\r\n<p>\r\n\tCNN transcript, <a href="http://transcripts.cnn.com/TRANSCRIPTS/0905/08/cnr.06.html" target="_blank">&quot;Victims Billed for Rape Kits,&quot;</a> May 8, 2009</p>\r\n<p>\r\n\tTexas Association Against Sexual Assault, <a href="http://taasa.org/blog/announcement/an-open-letter-to-sexual-assault-victims-in-texas/" target="_blank">Open Letter to Sexual Assault Victims in Texas</a></p>\r\n<p>\r\n\tTexas attorney general&#39;s office, <a href="http://www.oag.state.tx.us/victims/guidelines.shtml" target="_blank">Sexual Assault Exam Reimbursement Guidelines</a></p>\r\n<p>\r\n\tTexas attorney general&#39;s office, <a href="http://www.oag.state.tx.us/victims/advocate_notice.shtml" target="_blank">Notice to Crime Victim Advocates</a></p>\r\n<p>\r\n\tU.S. Department of Justice, Office on Violence Against Women, <a href="http://www.ovw.usdoj.gov/ovw-fs.htm#fs-faq" target="_blank">FAQ: Anonymous Reporting and Forensic Examinations</a>.</p>\r\n<p>\r\n\tInterview with Barbara Ann Radnofsky, Democratic candidate for Texas attorney general<br />\r\n\t<br />\r\n\tInterview with Jerry Strickland, spokesman for the Texas attorney general&#39;s office<br />\r\n\t<br />\r\n\tInterview with Torie Camp, deputy director, Texas Association Against Sexual Assault<br />\r\n\t<br />\r\n\tInterview with Gail Rice, community advocacy director, SafePlace<br />\r\n\t<br />\r\n\tInterview with Sgt. Elizabeth Donegan of the Austin Police Department</p>',
#  'speaker': {'adkey': None,
#   'advalue': None,
#   'barely_true_count': 0,
#   'current_job': '',
#   'false_count': 0,
#   'first_name': 'Barbara Ann',
#   'half_true_count': 0,
#   'home_state': '',
#   'id': 288,
#   'last_name': 'Radnofsky',
#   'mostly_true_count': 0,
#   'name_slug': 'barbara-ann-radnofsky',
#   'pants_count': 1,
#   'party': {'id': 1,
#    'party': 'Democrat',
#    'party_slug': 'democrat',
#    'resource_uri': '/api/v/2/party/1/'},
#   'photo': 'https://s3.amazonaws.com/static.politifact.com/politifact/mugs/RadnofskyPoli2.jpg',
#   'primary_edition': {'adkey': 'Editions',
#    'advalue': 'Texas',
#    'edition': 'Texas',
#    'edition_slug': 'texas',
#    'has_afterthefact': False,
#    'id': 2,
#    'index_page': False,
#    'meter_name': 'The Texas Truth-O-Meter',
#    'resource_uri': '/api/v/2/edition/2/'},
#   'promise_meter_cutout': None,
#   'resource_uri': '/api/v/2/person/288/',
#   'total_count': 1,
#   'true_count': 0,
#   'website': ''},
#  'statement': '<p>\r\n\t&quot;The attorney general requires that rape victims pay for the rape kit.&quot;</p>',
#  'statement_context': 'in a Web site video',
#  'statement_date': '2009-10-22',
#  'statement_type': {'id': 2,
#   'resource_uri': '/api/v/2/statementtype/2/',
#   'statement_type': 'Claim',
#   'type_description': 'blog post '},
#  'subject': [{'description': '',
#    'id': 38,
#    'photo': None,
#    'resource_uri': '/api/v/2/subject/38/',
#    'subject': 'Crime',
#    'subject_slug': 'crime',
#    'used_in_edition': []},
#   {'description': '',
#    'id': 146,
#    'photo': None,
#    'resource_uri': '/api/v/2/subject/146/',
#    'subject': 'Women',
#    'subject_slug': 'women',
#    'used_in_edition': []}],
#  'target': [],
#  'twitter_headline': ''}

# %% [markdown]
# Just to visualize JSON hierarchy, run the following cell:

# %%
def go_further(dic, name):
    dict_vis = {"name": name, "children": []}
    for k, v in dic.items():
        if type(v) == str:
            new_el = {"name": k}
        elif type(v) == list:
            if len(v) > 0:
                new_el = go_further(v[0], k)
        elif type(v) == dict:
            new_el = go_further(v, k)
        else:
            new_el = {"name": k}
        dict_vis["children"].append(new_el)
        
    return dict_vis

my_dict = go_further(data, name="statement_info")

with open(f"{directory_visualizations}/data.json", "w") as f:
    json.dump(my_dict, f)

print(f"Checkout visualization by: \n1) cd ../visualizations \n2) python -m http.server \n3) in browser, open: http://localhost:8000/")
# Out:
# Checkout visualization by:
# 1) cd ../visualizations
# 2) python -m http.server
# 3) in browser, open: http://localhost:8000/
