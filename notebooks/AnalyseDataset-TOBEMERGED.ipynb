# %% [markdown]
# # Analysing Dataset

# %%
def fix_layout(width:int=95):
    from IPython.core.display import display, HTML
    display(HTML('<style>.container { width:' + str(width) + '% !important; }</style>'))
    
fix_layout()
# Out:
# <style>.container { width:95% !important; }</style>

# %% [markdown]
# This notebook is dedicated to datasets analysis.
#
# Here we will concentrate on connecting our datasets into one dataframe that will later be used to extract meaningful information that can help us answer our research questions.
#
# In addition, data cleaning is performed where necessary since we will not use all the data provided. The goal of this notebook is to make data as easy as possible to use for future plotting and data story writing.
#
# So, let's dive into our data!

# %%
import os
import re
import json
import time
import datetime
from functools import reduce
from itertools import product

from json import load, JSONDecodeError
from functional import pseq, seq
import pandas as pd
import pandas_profiling
import requests
import pathlib

# necessary to load the utils, which are in src
import sys
sys.path.append('../src')

from utils import file, logging
from utils.statement_handling import extract_information, safe_json_read

# %%
def group_and_count(df, groupby_column, with_pct=False, with_avg=False):
    result = df.groupby(groupby_column).size().sort_values(ascending=False).reset_index().rename(columns={0: 'count'})
    if with_pct:
        result['count_pct'] = result['count'] / result['count'].sum()
    if with_avg:
        result['count_avg'] = result['count'].mean()
    return result

# %%
directory_liar_dataset = "../data/liar_dataset"
directory_statements = f"{directory_liar_dataset}/statements"
directory_election_results = "../data/election_results"
directory_county_data = "../data/county_data"

# %% [markdown]
# # LIAR Dataset

# %% [markdown]
# And now, let's read the data regarding corresponding statements and merge useful information from statements with the liar dataset:

# %%
lies = seq(pathlib.Path(directory_statements).iterdir()).map(safe_json_read)\
                               .filter(lambda x: len(x) > 0)\
                               .map(extract_information)\
                               .to_pandas()

lies['statement_date'] = pd.to_datetime(lies['statement_date'])
lies.head()
# Out:
# ERROR:root:File ..\data\liar_dataset\statements\5355.json is empty or something...
# ERROR:root:File ..\data\liar_dataset\statements\9.json is empty or something...
#         author_name_slug                           context        label  \
# 0  meghan-ashford-grooms               in a Web site video   pants-fire
# 1              jody-kyle             an interview on MSNBC         true
# 2             bill-adair  an interview with Pajamas Media.   pants-fire
# 3        w-gardner-selby                a debate in Austin    half-true
# 4          tom-kertscher                 a news conference  barely-true
#
#            ruling_date speaker_current_job speaker_first_name  \
# 0  2010-01-12T15:52:21                            Barbara Ann
# 1  2007-10-03T00:00:00              author               Mike
# 2  2009-04-30T18:20:28       Congresswoman            Michele
# 3  2014-10-02T14:07:32          Pharmacist            Leticia
# 4  2014-10-02T13:15:42
#
#   speaker_home_state                          speaker_last_name  \
# 0                                                     Radnofsky
# 1           Arkansas                                   Huckabee
# 2          Minnesota                                   Bachmann
# 3              Texas                               Van de Putte
# 4          Wisconsin  Wisconsin Professional Police Association
#
#                                            statement statement_date  \
# 0  The attorney general requires that rape victim...     2009-10-22
# 1  Hes sued gun manufacturers. He was supportive ...     2007-09-21
# 2  In the 1970s, the swine flu broke out . . . un...     2009-04-27
# 3  Dan Patrick said that if women get paid less t...     2014-09-29
# 4  Data on violent crime shows Wisconsin has beco...     2014-09-25
#
#    statement_id statement_type                    statement_type_description
# 0             1          Claim                                    blog post
# 1           100         Attack  <p>\r\n\tA criticism of a candidate.</p>\r\n
# 2          1000          Claim                                    blog post
# 3         10000          Claim                                    blog post
# 4         10001         Attack  <p>\r\n\tA criticism of a candidate.</p>\r\n

# %%
lies.shape
# Out:
# (15471, 13)

# %% [markdown]
# #### Label

# %%
group_and_count(lies, 'label')
# Out:
#          label  count
# 0    half-true   3009
# 1        false   2919
# 2  mostly-true   2860
# 3  barely-true   2587
# 4         true   2250
# 5   pants-fire   1604
# 6    full-flop    149
# 7    half-flip     68
# 8      no-flip     25

# %%
def label_to_nb(l): 
    """ Converting label to number
    
    Parameters
    ----------
    l: str
        Label of the lie, can be 'true', 'mostly-true', 'half-true', 'barely-true', 'false', 'pants-fire'
        
    Returns
    -------
    int
        Number in range from 0 to 5. We still need to think about lie representation.
    
    ToDos
    -----
    - think about this, this will give the false-hoods more weight
    """
    # TODO: handle FLIP-FLOPS!!!!
    #return ['true', 'mostly-true', 'half-true', 'barely-true', 'false', 'pants-fire'].index(l)
    return ['full-flop','half-flip', 'no-flip', 'true', 'mostly-true', 'half-true', 'barely-true', 'false', 'pants-fire'].index(l)

# %%
# TODO: check this cell, why it is not deleted
# no longer necessary
lies['label_as_nb'] = lies['label'].apply(label_to_nb) * 2 
lies['statement_id'] = pd.to_numeric(lies['statement_id'])

# %% [markdown]
# #### Context

# %%
group_and_count(lies, 'context').shape[0]
# Out:
# 5828

# %%
print(f"The number of different context names is: {group_and_count(lies, 'context').shape[0]}.")
# Out:
# The number of different context names is: 5828.

# %% [markdown]
# That is much too many different contexts and lots of them appear only a few times.\
# We thus need to regroup/reduce the number of contexts.

# %%
group_and_count(lies, 'context').head(100)
# Out:
#                                        context  count
# 0                                      a tweet    471
# 1                                 an interview    380
# 2                               a news release    329
# 3                              a press release    325
# 4                                     a speech    319
# 5                                      a TV ad    275
# 6                                a campaign ad    221
# 7                                   a headline    175
# 8                              a television ad    168
# 9                                                 166
# 10                           a radio interview    158
# 11                                    a debate    148
# 12                             a Facebook post    139
# 13                                 a blog post    133
# 14                          a press conference    125
# 15                           a news conference    118
# 16                       a campaign commercial     93
# 17                      a television interview     90
# 18                              a TV interview     76
# 19                                   a speech.     73
# 20                                       an ad     66
# 21                                  a radio ad     64
# 22                                    a TV ad.     62
# 23                            a press release.     59
# 24                         an interview on CNN     55
# 25                          a post on Facebook     54
# 26                    an interview on Fox News     53
# 27                              a chain e-mail     52
# 28                               an interview.     51
# 29                           a campaign mailer     50
# ..                                         ...    ...
# 70                           ABC's "This Week"     23
# 71           an interview on ABC's "This Week"     23
# 72                          a news conference.     22
# 73                              in a blog post     22
# 74                              a Twitter post     21
# 75              the second presidential debate     21
# 76          comments on NBC's "Meet the Press"     21
# 77                          a newspaper column     21
# 78                                   an e-mail     20
# 79                          a campaign mailer.     20
# 80                        a House floor speech     20
# 81                                  in a tweet     19
# 82                            an advertisement     19
# 83                a speech on the Senate floor     19
# 84                          a campaign website     19
# 85                         a fundraising email     18
# 86                                  a video ad     18
# 87                comments on "Meet the Press"     18
# 88                             a YouTube video     18
# 89                          in a press release     18
# 90                                    a column     18
# 91                           an opinion column     17
# 92       an interview on MSNBC's "Morning Joe"     17
# 93                                a statement.     17
# 94                  an interview with Fox News     17
# 95                            a campaign email     17
# 96                        a fundraising letter     17
# 97  an interview on CNN's "State of the Union"     16
# 98                             a floor speech.     16
# 99                                    a tweet.     16
#
# [100 rows x 2 columns]

# %% [markdown]
# So how to regroup all these or part of these?
# We can use the mean of communication for example:
# radio/tv/facebook/twitter/internet
# and these classes can have overlap...

# %%
# Insensitive case search of terms to regroup similar contexts together
# tweet, facebook, tv, campaign, blog, conference, fox, others
def clean_up_context(c):
    if 'tweet' in c.lower():
        return 'tweet'
    elif 'facebook' in c.lower():
        return 'facebook'
    elif any([s in c for s in ['television', 'TV', 'broadcast', 'press', 'CNN', 'radio', 'magazine']]):
        return 'tv'
    elif 'campaign' in c.lower():
        return 'campaign'
    elif 'blog' in c:
        return 'blog'
    elif 'conference' in c.lower():
        return 'conference'
    elif 'fox' in c.lower():
        return 'fox'
    else:
        return 'others'

lies['clean_context'] = lies['context'].apply(clean_up_context)

# %%
group_and_count(lies, 'clean_context')
# Out:
#   clean_context  count
# 0        others   9734
# 1            tv   2773
# 2      campaign   1030
# 3         tweet    584
# 4           fox    457
# 5      facebook    325
# 6          blog    309
# 7    conference    259

# %%
# In search for empty contexts
lies.loc[lies['context']=='']
# Out:
#             author_name_slug context        label          ruling_date  \
# 34             robert-farley            half-true  2009-05-05T15:12:52
# 353           lauren-carroll          mostly-true  2014-12-19T10:57:40
# 467              sean-gorman          mostly-true  2015-01-26T13:00:00
# 531      michael-van-sickler          barely-true  2007-10-05T00:00:00
# 686              sean-gorman          mostly-true  2015-03-23T14:30:00
# 699          w-gardner-selby          barely-true  2015-03-30T11:08:40
# 992              sarah-hauer            half-true  2015-06-10T14:26:02
# 1387           rachel-brooks          barely-true  2015-10-02T15:05:02
# 1613          james-b-nelson            full-flop  2015-11-06T05:00:00
# 1818       nancy-badertscher          mostly-true  2015-12-30T00:00:00
# 2001           david-baumann          mostly-true  2007-10-15T00:00:00
# 2105           david-baumann                 true  2007-10-15T00:00:00
# 2198            cassie-owens          mostly-true  2016-03-18T10:00:00
# 2421          amy-hollyfield          barely-true  2007-10-16T00:00:00
# 2449           tom-kertscher            half-true  2016-05-04T05:00:00
# 2610            cassie-owens          barely-true  2016-06-07T09:30:00
# 2720            cassie-owens            full-flop  2016-06-28T14:56:36
# 2728     angie-drobnic-holan          mostly-true  2007-10-17T00:00:00
# 2807              will-doran          mostly-true  2016-07-15T10:45:37
# 2816     angie-drobnic-holan            half-true  2007-10-17T00:00:00
# 3029              will-doran                false  2016-08-11T18:36:50
# 3034     angie-drobnic-holan                 true  2007-10-17T00:00:00
# 3126             sean-gorman            full-flop  2016-08-29T14:33:21
# 3466                    None                 true  2007-10-19T00:00:00
# 3549              will-doran           pants-fire  2016-10-28T19:30:38
# 3553            warren-fiske          barely-true  2016-10-31T12:16:49
# 3729          louis-jacobson                false  2016-12-15T15:14:51
# 3865            cassie-owens          barely-true  2017-01-31T09:00:00
# 3989            cassie-owens                false  2017-02-27T10:00:00
# 4159              will-doran           pants-fire  2017-04-02T06:00:00
# ...                      ...     ...          ...                  ...
# 12307          robert-farley            half-true  2008-09-04T00:00:00
# 12395          robert-farley           pants-fire  2008-09-10T00:00:00
# 12444             jake-berry                 true  2012-11-21T16:47:26
# 12541     willoughby-mariano                 true  2013-01-02T06:00:00
# 12564     willoughby-mariano            full-flop  2013-01-09T06:00:00
# 12632      adriel-bettelheim            half-flip  2008-09-19T00:00:00
# 12665          robert-farley                false  2008-09-22T00:00:00
# 12714               sue-owen          mostly-true  2013-02-08T19:58:08
# 12847  nancy-madsen-virginia            full-flop  2013-03-08T13:58:38
# 12917              tom-feran            full-flop  2013-03-25T06:00:00
# 13064           eric-stirgus              no-flip  2013-04-26T00:00:00
# 13400        w-gardner-selby          mostly-true  2013-07-11T06:00:00
# 13449     sue-owen-statesman          barely-true  2013-07-23T12:46:21
# 13553          robert-farley            half-flip  2008-10-21T00:00:00
# 13772          robert-farley          barely-true  2008-10-30T00:00:00
# 13803            wes-allison                 true  2007-09-21T00:00:00
# 14055        w-gardner-selby           pants-fire  2013-12-13T10:00:00
# 14099    angie-drobnic-holan                 true  2007-09-20T00:00:00
# 14190            amy-sherman          barely-true  2014-01-21T11:27:26
# 14191            amy-sherman          barely-true  2014-01-23T10:00:00
# 14301            amy-sherman            full-flop  2014-02-20T11:53:34
# 14408          robert-farley                false  2009-01-13T19:13:41
# 14450        w-gardner-selby          mostly-true  2014-03-17T12:16:24
# 14899         louis-jacobson           pants-fire  2014-06-18T15:38:46
# 15038              tom-tobin            half-true  2007-09-28T00:00:00
# 15146          molly-oconnor          mostly-true  2014-08-01T13:35:20
# 15147    angie-drobnic-holan          mostly-true  2007-09-23T00:00:00
# 15223          nicole-chavez          barely-true  2014-08-22T12:51:33
# 15236  nancy-madsen-virginia              no-flip  2014-08-18T00:00:00
# 15448           warren-fiske            half-flip  2014-09-29T12:00:00
#
#                                    speaker_current_job speaker_first_name  \
# 34
# 353                                       U.S. Senator              Marco
# 467
# 531                                             author               Mike
# 686                                     State delegate                Ken
# 699                                            Senator                Ted
# 992                               State Representative               Dale
# 1387
# 1613                               U.S. representative              Glenn
# 1818                            promoting safe driving              State
# 2001                                      U.S. senator              Chris
# 2105                                      U.S. senator                Joe
# 2198                                                                Katie
# 2421                               U.S. representative                Tom
# 2449                                                                  Ron
# 2610                         Candidate for U.S. Senate                Pat
# 2720                                Philadelphia Mayor                Jim
# 2728                                      U.S. senator                Joe
# 2807
# 2816                                      U.S. senator                Joe
# 3029
# 3034                                      U.S. senator                Joe
# 3126                                      U.S. Senator                Tim
# 3466                            Presidential candidate            Hillary
# 3549                     N.C. House of Representatives              Chris
# 3553                        Richmond mayoral candidate              Levar
# 3729                                           website
# 3865   Philadelphia Republican City Committee Chairman                Joe
# 3989                                     State Senator               John
# 4159
# ...                                                ...                ...
# 12307                                     U.S. senator               John
# 12395
# 12444                                         Attorney                Ann
# 12541                                                                Jack
# 12564                                                               Kasim
# 12632                                     U.S. senator               John
# 12665                                        President             Barack
# 12714                                     Austin mayor                Lee
# 12847                                         Governor                Bob
# 12917                             State representative         William G.
# 13064                                     U.S. Senator             Johnny
# 13400                            U.S. Energy Secretary               Rick
# 13449                                      Businessman              Roger
# 13553                                        President             Barack
# 13772                                        President             Barack
# 13803
# 14055                Member, Texas Railroad Commission              Barry
# 14099                                        President             Barack
# 14190
# 14191
# 14301                                                             Charlie
# 14408                              U.S. Representative           Spencer
# 14450                              Lieutenant governor              David
# 14899
# 15038                                         Attorney               Rudy
# 15146                    U.S. House of Representatives              Bruce
# 15147                                         Governor               Bill
# 15223                              U.S. Representative              Henry
# 15236                                     U.S. Senator               Mark
# 15448                                     U.S. Senator               Mark
#
#       speaker_home_state                               speaker_last_name  \
# 34                                                           Chain email
# 353              Florida                                           Rubio
# 467                                     Virginia House Democratic Caucus
# 531             Arkansas                                        Huckabee
# 686             Virginia                                            Plum
# 699                Texas                                            Cruz
# 992            Wisconsin                                        Kooyenga
# 1387                            National Republican Senatorial Committee
# 1613           Wisconsin                                        Grothman
# 1818             Georgia                     Public Service Announcement
# 2001         Connecticut                                            Dodd
# 2105            Delaware                                           Biden
# 2198        Pennsylvania                                         McGinty
# 2421            Colorado                                        Tancredo
# 2449           Wisconsin                                         Johnson
# 2610        Pennsylvania                                          Toomey
# 2720        Pennsylvania                                          Kenney
# 2728            Delaware                                           Biden
# 2807                                                         Moms Rising
# 2816            Delaware                                           Biden
# 3029                                          National Rifle Association
# 3034            Delaware                                           Biden
# 3126            Virginia                                           Kaine
# 3466            New York                                         Clinton
# 3549      North Carolina                                          Malone
# 3553            Virginia                                          Stoney
# 3729                                                   Realtime Politics
# 3865        Pennsylvania                                        DeFelice
# 3989        Pennsylvania                                    Eichelberger
# 4159                                                            Bloggers
# ...                  ...                                             ...
# 12307            Arizona                                          McCain
# 12395                                                        Chain email
# 12444      New Hampshire                                   McLane Kuster
# 12541            Georgia                                        Kingston
# 12564                                                               Reed
# 12632            Arizona                                          McCain
# 12665           Illinois                                           Obama
# 12714              Texas                                     Leffingwell
# 12847           Virginia                                       McDonnell
# 12917               Ohio                                      Batchelder
# 13064            Georgia                                         Isakson
# 13400              Texas                                           Perry
# 13449              Texas                                        Williams
# 13553           Illinois                                           Obama
# 13772           Illinois                                           Obama
# 13803                                      Republican National Committee
# 14055              Texas                                      Smitherman
# 14099           Illinois                                           Obama
# 14190            Florida  Democratic Hispanic Caucus, Miami-Dade Chapter
# 14191            Florida                                 Florida for All
# 14301            Florida                                           Crist
# 14408            Alabama                                          Bachus
# 14450              Texas                                        Dewhurst
# 14899                                                        Chain email
# 15038           New York                                        Giuliani
# 15146               Iowa                                          Braley
# 15147         New Mexico                                      Richardson
# 15223              Texas                                         Cuellar
# 15236           Virginia                                          Warner
# 15448           Virginia                                          Warner
#
#                                                statement statement_date  \
# 34     Barack Obamas nominee for regulatory czar has ...     2009-04-27
# 353    The reason why Cubans don&#39;t have access to...     2014-12-17
# 467    Assault weapons and handguns are allowed in th...     2015-01-19
# 531    The reality is, with a $2 trillion-a-year heal...     2007-09-02
# 686    We&#39;ve got 40 years of study now that show ...     2015-03-12
# 699    Today roughly half of born-again Christians ar...     2015-03-23
# 992    <p dir=ltr>Since Republicans took over after t...     2015-05-22
# 1387   Says Missouri Democratic Senate candidate&nbsp...     2015-09-14
# 1613               On support for the Export-Import Bank     2015-11-06
# 1818   By the end of 2015, more than 1,300 people wil...     2015-12-28
# 2001   With the resources it takes to execute just ov...     2007-10-03
# 2105   With one stroke of his pen, President Bush has...     2007-10-15
# 2198   <strong></strong><strong>Here in Pennsylvania,...     2016-03-08
# 2421   In 2006, Arizona had four ballot issues that w...     2007-09-10
# 2449   Says he started the Pacur plastics manufacturi...     2016-04-29
# 2610   Says Merrick Garland authored an opinion that ...     2016-04-15
# 2720   On eliminating the influence of money in polic...     2015-04-25
# 2728   First, he was in favor of my plan, now hes att...     2007-10-12
# 2807   In North Carolina, paid family leave is more p...     2016-07-13
# 2816   First, he said he would take all of our troops...     2007-10-12
# 3029   Says Hillary Clinton doesn&rsquo;t believe in ...     2016-08-10
# 3034   First, he said he would leave residual forces ...     2007-10-12
# 3126                  On drilling off the Atlantic coast     2016-08-13
# 3466    Nearly half of Hispanic voters in Arizonas la...     2007-10-19
# 3549   Says Democratic challenger for his N.C. House ...     2016-09-28
# 3553   Jack Berry voted for a plan to cut $23.8 milli...     2016-10-17
# 3729   Democrats Filing TREASON Charges Against Trump...     2016-12-11
# 3865   From the release of a child rapist from the Do...     2017-01-25
# 3989   Inner-city students fall back and don&rsquo;t ...     2017-02-13
# 4159   The Notebook is finally getting a sequel. Prod...     2017-03-27
# ...                                                  ...            ...
# 12307  Senator Obama thinks we can achieve energy ind...     2008-09-04
# 12395        The Books Sarah Palin tried to have banned.     2008-09-08
# 12444  Says she is entering in the most diverse class...     2012-11-11
# 12541  Connecticut has the fifth toughest gun control...     2012-12-18
# 12564                               On same-sex marriage     2012-12-11
# 12632  On whether the government should bail out insu...     2008-09-17
# 12665  But if my opponent had his way, the millions o...     2008-09-20
# 12714  Says Austin trains are full at rush hour and p...     2013-02-05
# 12847                                  On raising taxes.     2013-03-08
# 12917  On support of Gov. John Kasich&rsquo;s drillin...     2013-03-17
# 13064  On allowing a vote on universal gun background...     2013-04-09
# 13400  Says a growing number of extremely premature b...     2013-06-27
# 13449  Says Obama policies contributed to gas prices ...     2013-07-01
# 13553  On which team he&#39;s rooting for in the Worl...     2008-10-21
# 13772  For my energy plan, my economic plan, and the ...     2008-10-29
# 13803  Obama Skips Out On Condemning Left-Wing Attack...     2007-09-21
# 14055                          The Earth is not warming.     2013-11-17
# 14099          Obama won health care for 150,000 people.     2007-08-08
# 14190  In 2011, Carlos L&oacute;pez-Cantera staunchly...     2014-01-16
# 14191  Rick Scott&rsquo;s Administration spent over $...     2014-01-20
# 14301                         On adoption by gay couples     2014-02-10
# 14408  Even with recent changes, the average hourly w...     2008-11-19
# 14450  Dan Patrick called for increasing the gas tax ...     2014-03-02
# 14899  Barack Obama is the<strong> </strong>first pre...     2014-06-18
# 15038  When I was mayor of New York City, I encourage...     2007-05-03
# 15146  Says U.S. Senate candidate Joni Ernst does not...     2014-07-29
# 15147  Bill Richardson is the only major Democratic c...     2007-09-25
# 15223  Says drug cartels are using social media to of...     2014-07-16
# 15236                    On offshore drilling for energy     2014-07-26
# 15448  On opposing legislation that would take away e...     2014-09-29
#
#        statement_id statement_type  \
# 34             1003          Claim
# 353           10330          Claim
# 467           10439          Claim
# 531             105          Claim
# 686           10643          Claim
# 699           10655          Claim
# 992           10931          Claim
# 1387          11302          Claim
# 1613          11527           Flip
# 1818          11720          Claim
# 2001            119          Claim
# 2105            120          Claim
# 2198          12089          Claim
# 2421            123          Claim
# 2449          12328          Claim
# 2610          12488          Claim
# 2720          12592           Flip
# 2728            126         Attack
# 2807          12691          Claim
# 2816            127         Attack
# 3029          12895          Claim
# 3034            129         Attack
# 3126          12983           Flip
# 3466            133          Claim
# 3549          13378          Claim
# 3553          13381         Attack
# 3729          13543          Claim
# 3865          13670         Attack
# 3989          13786          Claim
# 4159          13943          Claim
# ...             ...            ...
# 12307           699         Attack
# 12395           707         Attack
# 12444          7113          Claim
# 12541          7207          Claim
# 12564          7228           Flip
# 12632           729           Flip
# 12665           732         Attack
# 12714          7364          Claim
# 12847          7493           Flip
# 12917          7559           Flip
# 13064          7695           Flip
# 13400          8003          Claim
# 13449          8061          Claim
# 13553           816           Flip
# 13772           837          Claim
# 13803            84         Attack
# 14055          8655          Claim
# 14099            87          Claim
# 14190          8792         Attack
# 14191          8793          Claim
# 14301          8903           Flip
# 14408           901          Claim
# 14450          9052          Claim
# 14899          9467          Claim
# 15038            96          Claim
# 15146          9699          Claim
# 15147            97          Claim
# 15223          9770          Claim
# 15236          9784           Flip
# 15448          9979           Flip
#
#                          statement_type_description  label_as_nb clean_context
# 34                                       blog post            10        others
# 353                                      blog post             8        others
# 467                                      blog post             8        others
# 531                                      blog post            12        others
# 686                                      blog post             8        others
# 699                                      blog post            12        others
# 992                                      blog post            10        others
# 1387                                     blog post            12        others
# 1613                             Flip-o-Meter items            0        others
# 1818                                     blog post             8        others
# 2001                                     blog post             8        others
# 2105                                     blog post             6        others
# 2198                                     blog post             8        others
# 2421                                     blog post            12        others
# 2449                                     blog post            10        others
# 2610                                     blog post            12        others
# 2720                             Flip-o-Meter items            0        others
# 2728   <p>\r\n\tA criticism of a candidate.</p>\r\n            8        others
# 2807                                     blog post             8        others
# 2816   <p>\r\n\tA criticism of a candidate.</p>\r\n           10        others
# 3029                                     blog post            14        others
# 3034   <p>\r\n\tA criticism of a candidate.</p>\r\n            6        others
# 3126                             Flip-o-Meter items            0        others
# 3466                                     blog post             6        others
# 3549                                     blog post            16        others
# 3553   <p>\r\n\tA criticism of a candidate.</p>\r\n           12        others
# 3729                                     blog post            14        others
# 3865   <p>\r\n\tA criticism of a candidate.</p>\r\n           12        others
# 3989                                     blog post            14        others
# 4159                                     blog post            16        others
# ...                                             ...          ...           ...
# 12307  <p>\r\n\tA criticism of a candidate.</p>\r\n           10        others
# 12395  <p>\r\n\tA criticism of a candidate.</p>\r\n           16        others
# 12444                                    blog post             6        others
# 12541                                    blog post             6        others
# 12564                            Flip-o-Meter items            0        others
# 12632                            Flip-o-Meter items            2        others
# 12665  <p>\r\n\tA criticism of a candidate.</p>\r\n           14        others
# 12714                                    blog post             8        others
# 12847                            Flip-o-Meter items            0        others
# 12917                            Flip-o-Meter items            0        others
# 13064                            Flip-o-Meter items            4        others
# 13400                                    blog post             8        others
# 13449                                    blog post            12        others
# 13553                            Flip-o-Meter items            2        others
# 13772                                    blog post            12        others
# 13803  <p>\r\n\tA criticism of a candidate.</p>\r\n            6        others
# 14055                                    blog post            16        others
# 14099                                    blog post             6        others
# 14190  <p>\r\n\tA criticism of a candidate.</p>\r\n           12        others
# 14191                                    blog post            12        others
# 14301                            Flip-o-Meter items            0        others
# 14408                                    blog post            14        others
# 14450                                    blog post             8        others
# 14899                                    blog post            16        others
# 15038                                    blog post            10        others
# 15146                                    blog post             8        others
# 15147                                    blog post             8        others
# 15223                                    blog post            12        others
# 15236                            Flip-o-Meter items            4        others
# 15448                            Flip-o-Meter items            2        others
#
# [166 rows x 15 columns]

# %%
# What are the other contexts about
lies.loc[lies['clean_context']=='others']
# We need to consider also column called statement_type_description
# Out:
#             author_name_slug                                      context  \
# 0      meghan-ashford-grooms                          in a Web site video
# 1                  jody-kyle                        an interview on MSNBC
# 2                 bill-adair             an interview with Pajamas Media.
# 3            w-gardner-selby                           a debate in Austin
# 10             dylan-baddour           a debate in the Rio Grande Valley.
# 13       angie-drobnic-holan                                  interviews.
# 15            louis-jacobson          a speech at Northwestern University
# 16                 al-mckeon                                        an ad
# 17            c-eugene-emery             a Providence Journal-WPRI debate
# 18                 al-mckeon                                        an ad
# 21              alex-kuffner                                     a debate
# 22     nancy-madsen-virginia                              a news release.
# 24     nancy-madsen-virginia                                    a mailer.
# 27                april-hunt                                        an ad
# 31             katie-sanders                              an AP interview
# 32                bill-adair                               a news release
# 33         nancy-badertscher                              candidate forum
# 34             robert-farley
# 35            louis-jacobson                  a speech in Princeton, Ind.
# 37             katie-sanders  an interview on "Real Time with Bill Maher"
# 39                 dana-tims                                     an email
# 40            lauren-carroll                                     a debate
# 41            louis-jacobson                                     a debate
# 42                bill-adair                                    a debate
# 44            lauren-carroll          a speech at Northwestern University
# 45       angie-drobnic-holan             an interview on "The Today Show"
# 48            louis-jacobson                                     a debate
# 49             jon-greenberg                an article on the WND website
# 53            louis-jacobson                               a news release
# 54                april-hunt                         a U.S. Senate debate
# ...                      ...                                          ...
# 15406          dylan-baddour                              oped commentary
# 15410         steve-contorno                 a panel on ABC's "This Week"
# 15411            sean-gorman                                     a video.
# 15417    angie-drobnic-holan                             a news interview
# 15421        w-gardner-selby           a debate in the Rio Grande Valley.
# 15422        w-gardner-selby           a debate in the Rio Grande Valley.
# 15423              dana-tims                                a chain email
# 15424            amy-sherman              a speech to a college GOP group
# 15426          tom-kertscher                                 an interview
# 15429       aaron-sharockman                             her book "Drift"
# 15431        w-gardner-selby       an Austin City Council candidate forum
# 15435        w-gardner-selby           a debate in the Rio Grande Valley.
# 15436          katie-sanders         an interview on "America's Newsroom"
# 15437         lauren-carroll                       an email to supporters
# 15438        w-gardner-selby                        speaking to reporters
# 15443          jon-greenberg                           a speech at the UN
# 15447          jon-greenberg                comments on ABC's "This Week"
# 15448           warren-fiske
# 15449    angie-drobnic-holan                            an opinion piece.
# 15451          tom-kertscher                               a news release
# 15453         louis-jacobson                                     a debate
# 15455         lauren-carroll                                     a debate
# 15456         james-b-nelson                                     a speech
# 15462        w-gardner-selby           a debate in the Rio Grande Valley.
# 15463          jon-greenberg              an op-ed in the "New York Post"
# 15465         louis-jacobson                                     a debate
# 15466          dave-umhoefer                                 an interview
# 15468         lauren-carroll                                     a debate
# 15469        w-gardner-selby                                     a debate
# 15470        w-gardner-selby                           a debate in Austin
#
#              label          ruling_date  \
# 0       pants-fire  2010-01-12T15:52:21
# 1             true  2007-10-03T00:00:00
# 2       pants-fire  2009-04-30T18:20:28
# 3        half-true  2014-10-02T14:07:32
# 10           false  2014-10-03T13:00:00
# 13       full-flop  2009-05-01T14:56:32
# 15       half-true  2014-10-06T15:49:39
# 16     mostly-true  2014-10-03T17:20:47
# 17            true  2014-10-05T00:01:00
# 18     mostly-true  2014-10-03T17:31:05
# 21     mostly-true  2014-10-06T00:02:00
# 22       half-true  2014-10-06T00:00:00
# 24     mostly-true  2014-10-06T13:20:52
# 27     barely-true  2014-10-07T00:00:00
# 31            true  2014-10-07T14:47:02
# 32     mostly-true  2014-10-07T13:28:40
# 33            true  2014-10-08T00:00:00
# 34       half-true  2009-05-05T15:12:52
# 35       half-true  2014-10-09T11:48:05
# 37           false  2014-10-07T17:09:27
# 39            true  2014-10-07T17:46:28
# 40       half-true  2014-10-07T21:17:36
# 41     barely-true  2014-10-07T22:01:19
# 42     mostly-true  2014-10-08T11:44:12
# 44     mostly-true  2014-10-08T14:09:46
# 45      pants-fire  2009-05-04T16:10:21
# 48       half-true  2014-10-08T16:23:21
# 49      pants-fire  2014-10-08T17:34:31
# 53     barely-true  2014-10-10T11:25:07
# 54     barely-true  2014-10-10T00:00:00
# ...            ...                  ...
# 15406   pants-fire  2014-09-21T06:00:00
# 15410    half-true  2014-09-21T18:38:03
# 15411         true  2014-09-22T00:00:00
# 15417    half-flip  2009-04-28T19:49:06
# 15421  mostly-true  2014-09-24T11:32:52
# 15422  mostly-true  2014-09-24T11:20:31
# 15423   pants-fire  2014-09-23T16:51:49
# 15424        false  2014-09-24T11:47:28
# 15426  mostly-true  2014-09-29T05:00:00
# 15429  barely-true  2014-09-24T18:17:51
# 15431  mostly-true  2014-09-25T12:00:00
# 15435    half-true  2014-09-25T16:31:48
# 15436  barely-true  2014-09-25T18:10:04
# 15437        false  2014-09-25T18:21:45
# 15438   pants-fire  2014-09-25T18:01:15
# 15443    half-true  2014-09-29T11:24:37
# 15447        false  2014-09-28T16:59:28
# 15448    half-flip  2014-09-29T12:00:00
# 15449         true  2009-04-30T17:06:05
# 15451        false  2014-09-29T14:49:14
# 15453  barely-true  2014-09-30T11:18:37
# 15455    half-true  2014-09-30T16:04:26
# 15456  barely-true  2014-10-01T05:00:00
# 15462  barely-true  2014-09-30T17:39:50
# 15463   pants-fire  2014-10-01T14:49:27
# 15465        false  2014-10-01T17:06:38
# 15466  mostly-true  2014-10-02T05:00:00
# 15468        false  2014-10-02T11:16:19
# 15469  barely-true  2014-10-02T10:00:00
# 15470        false  2014-10-02T12:00:00
#
#                                      speaker_current_job speaker_first_name  \
# 0                                                               Barbara Ann
# 1                                                 author               Mike
# 2                                          Congresswoman            Michele
# 3                                             Pharmacist            Leticia
# 10                                              governor               Greg
# 13                                               Senator              Arlen
# 15                                             President             Barack
# 16
# 17                                         Law professor              Jorge
# 18
# 21                                         Law professor              Jorge
# 22
# 24
# 27                                 U.S. Senate candidate              David
# 31                                                                   Gloria
# 32                                   Former U.S. Senator               Kay
# 33                                                                   Nathan
# 34
# 35                                             President             Barack
# 37                             Actor, director, activist                Ben
# 39                                  radio talk show host               Lars
# 40                                   Former U.S. Senator               Kay
# 41               House Speaker and U.S. Senate candidate               Thom
# 42                                   Former U.S. Senator               Kay
# 44                                             President             Barack
# 45                                          U.S. senator                Joe
# 48               House Speaker and U.S. Senate candidate               Thom
# 49                                                                   Morgan
# 53                                               Senator             Jeanne
# 54                                 U.S. Senate candidate              David
# ...                                                  ...                ...
# 15406                     state agriculture commissioner               Todd
# 15410                                                               Katrina
# 15411                                   U.S. Congressman                Bob
# 15417                                                                  Newt
# 15421                                           governor               Greg
# 15422                                      state senator              Wendy
# 15423
# 15424                     Miami-Dade school board member             Carlos
# 15426                        Madison school board member               Mary
# 15429                                         MSNBC host             Rachel
# 15431                                           Attorney                Jay
# 15435                                      state senator              Wendy
# 15436                                   Military analyst             Ralph
# 15437  Alaska Department of Public Resources commissi...                Dan
# 15438                                      state senator              Wendy
# 15443                                                                  Emma
# 15447     Political commentator and radio talk show host              Laura
# 15448                                       U.S. Senator               Mark
# 15449            Speaker of the House of Representatives               John
# 15451
# 15453                                       U.S. senator               Joni
# 15455                                       U.S. senator               Joni
# 15456                                U.S. Representative               Paul
# 15462                                           governor               Greg
# 15463                                                        William Benson
# 15465                      U.S. House of Representatives              Bruce
# 15466                        Madison school board member               Mary
# 15468                                       U.S. senator               Joni
# 15469                                         Pharmacist            Leticia
# 15470                          Lieutenant governor-elect                Dan
#
#       speaker_home_state                    speaker_last_name  \
# 0                                                   Radnofsky
# 1               Arkansas                             Huckabee
# 2              Minnesota                             Bachmann
# 3                  Texas                         Van de Putte
# 10                 Texas                               Abbott
# 13          Pennsylvania                              Specter
# 15              Illinois                                Obama
# 16                        Americans for Responsible Solutions
# 17          Rhode Island                               Elorza
# 18                        Americans for Responsible Solutions
# 21          Rhode Island                               Elorza
# 22              Virginia         Democratic Party of Virginia
# 24                                 National Rifle Association
# 27               Georgia                               Perdue
# 31                                                    Steinem
# 32        North Carolina                                Hagan
# 33                                                       Deal
# 34                                                Chain email
# 35              Illinois                                Obama
# 37                                                    Affleck
# 39                Oregon                               Larson
# 40        North Carolina                                Hagan
# 41        North Carolina                               Tillis
# 42        North Carolina                                Hagan
# 44              Illinois                                Obama
# 45              Delaware                                Biden
# 48        North Carolina                               Tillis
# 49                                                   Brittany
# 53         New Hampshire                              Shaheen
# 54               Georgia                               Perdue
# ...                  ...                                  ...
# 15406              Texas                              Staples
# 15410                                           vanden Heuvel
# 15411           Virginia                            Goodlatte
# 15417            Georgia                             Gingrich
# 15421              Texas                               Abbott
# 15422              Texas                                Davis
# 15423                                                Bloggers
# 15424            Florida                              Curbelo
# 15426          Wisconsin                                Burke
# 15429                                                  Maddow
# 15431              Texas                                Wiley
# 15435              Texas                                Davis
# 15436                                                  Peters
# 15437             Alaska                             Sullivan
# 15438              Texas                                Davis
# 15443                                                  Watson
# 15447                                                Ingraham
# 15448           Virginia                               Warner
# 15449               Ohio                              Boehner
# 15451          Wisconsin                    One Wisconsin Now
# 15453               Iowa                                Ernst
# 15455               Iowa                                Ernst
# 15456          Wisconsin                                 Ryan
# 15462              Texas                               Abbott
# 15463                                                   Huber
# 15465               Iowa                               Braley
# 15466          Wisconsin                                Burke
# 15468               Iowa                                Ernst
# 15469              Texas                         Van de Putte
# 15470              Texas                              Patrick
#
#                                                statement statement_date  \
# 0      The attorney general requires that rape victim...     2009-10-22
# 1      Hes sued gun manufacturers. He was supportive ...     2007-09-21
# 2      In the 1970s, the swine flu broke out . . . un...     2009-04-27
# 3      Dan Patrick said that if women get paid less t...     2014-09-29
# 10     I&rsquo;ve been involved in prosecuting a terr...     2014-09-19
# 13                                 On switching parties.     2009-04-28
# 15     When I took office, the deficit was nearly 10 ...     2014-10-02
# 16     Republican House candidate&nbsp;Marilinda Garc...     2014-09-16
# 17     We have a retiree that is collecting a $17,000...     2014-09-30
# 18     Most people in New Hampshire want to raise the...     2014-09-16
# 21     In the last six years of Cianci&rsquo;s admini...     2014-09-30
# 22     Hospitals have already begun layoffs, a direct...     2014-09-16
# 24     Says Mark Warner has supported restrictions on...     2014-09-08
# 27                    Says Michelle Nunn is for amnesty.     2014-09-17
# 31     More women were killed by their husbands or bo...     2014-10-01
# 32     Says Thom Tillis refuses to say what we should...     2014-10-03
# 33     <strong>The state&rsquo;s overall revenues onl...     2014-09-15
# 34     Barack Obamas nominee for regulatory czar has ...     2009-04-27
# 35     The states that have raised the minimum wage (...     2014-10-03
# 37     The Islamic State is so small it couldn&#39;t ...     2014-10-03
# 39     TSA WILL ACCEPT DRIVERS PRIV CARDS FOR ID AT T...     2014-10-02
# 40     Says Thom Tillis has cut $500 million from pub...     2014-10-07
# 41     By voting for Obamacare, Sen. Kay Hagan voted ...     2014-10-07
# 42     The Common Core was not put together by the De...     2014-10-07
# 44     The cost of health care is now the single-bigg...     2014-10-02
# 45     When one person sneezes, it goes all the way t...     2009-04-30
# 48     In North Carolina, now we&#39;re near the nati...     2014-10-07
# 49     According to a government supplier of emergenc...     2014-10-07
# 53     Says Scott Brown co-sponsored legislation&nbsp...     2014-09-29
# 54     Michelle Nunn ranks agriculture issues as the ...     2014-10-07
# ...                                                  ...            ...
# 15406  To deprive underprivileged children of a meat-...     2014-09-08
# 15410  Americans now support strikes (against ISIS) b...     2014-09-21
# 15411  The U.S. Constitution is the oldest written co...     2014-09-17
# 15417                                        On torture.     2009-04-24
# 15421  The FBI is involved in an investigation about ...     2014-09-19
# 15422  Greg Abbott heads up a party whose platform ca...     2014-09-19
# 15423  Was Martha Kanter dispatched to Corvallis with...     2014-09-18
# 15424   Social Security and Medicare are a Ponzi scheme.     2014-09-18
# 15426  Under Scott Walker, right now, we&rsquo;re 46t...     2014-09-22
# 15429  Not even old Gen. Eisenhower &hellip; saluted ...     2012-03-27
# 15431  Austin has over 1,000 city employees that make...     2014-09-15
# 15435  Greg Abbott has campaigned with a sexual preda...     2014-09-19
# 15436  Says President Barack Obama attacked potential...     2014-09-24
# 15437  Sen.&nbsp;Mark Begich cast the deciding vote i...     2014-09-19
# 15438  Greg Abbott and his surrogates have referred t...     2014-09-23
# 15443  Based on current trends, 15.5 million girls wi...     2014-09-20
# 15447  This Congress&nbsp;adjourned earliest of any t...     2014-09-28
# 15448  On opposing legislation that would take away e...     2014-09-29
# 15449  <span class=middlecopy><span class=middlecopy>...     2009-04-22
# 15451  Scott Walker was elected governor on a promise...     2014-09-26
# 15453  94 percent of those that are employed by the D...     2014-09-28
# 15455  Says personhood legislation she sponsored woul...     2014-09-28
# 15456  After the 2012 redistricting, Wisconsin has co...     2014-09-02
# 15462  A 2011 measure passed into law with Wendy Davi...     2014-09-19
# 15463  The non-profit group&nbsp;Feeding America is l...     2014-09-28
# 15465  I recently had the opportunity to vote to give...     2014-09-28
# 15466  We have 41,000 people right now on the waitlis...     2014-09-22
# 15468  Says Bruce Braley threatened to sue a neighbor...     2014-09-28
# 15469  The state-hired company that evaluates state-m...     2014-09-29
# 15470  Leticia Van de Putte voted to give illegal imm...     2014-09-29
#
#        statement_id statement_type  \
# 0                 1          Claim
# 1               100         Attack
# 2              1000          Claim
# 3             10000          Claim
# 10            10007          Claim
# 13             1001           Flip
# 15            10012          Claim
# 16            10013          Claim
# 17            10014          Claim
# 18            10015          Claim
# 21            10018          Claim
# 22            10019          Claim
# 24            10020         Attack
# 27            10023          Claim
# 31            10027          Claim
# 32            10028          Claim
# 33            10029          Claim
# 34             1003          Claim
# 35            10030          Claim
# 37            10032          Claim
# 39            10034          Claim
# 40            10035          Claim
# 41            10036          Claim
# 42            10037          Claim
# 44            10039          Claim
# 45             1004          Claim
# 48            10042          Claim
# 49            10043          Claim
# 53            10047          Claim
# 54            10048          Claim
# ...             ...            ...
# 15406          9938          Claim
# 15410          9943          Claim
# 15411          9944          Claim
# 15417           995           Flip
# 15421          9953          Claim
# 15422          9954          Claim
# 15423          9955          Claim
# 15424          9956          Claim
# 15426          9958         Attack
# 15429          9960          Claim
# 15431          9962          Claim
# 15435          9966          Claim
# 15436          9967          Claim
# 15437          9968          Claim
# 15438          9969          Claim
# 15443          9973          Claim
# 15447          9977          Claim
# 15448          9979           Flip
# 15449           998          Claim
# 15451          9981         Attack
# 15453          9983          Claim
# 15455          9985          Claim
# 15456          9986          Claim
# 15462          9991          Claim
# 15463          9992          Claim
# 15465          9994          Claim
# 15466          9995          Claim
# 15468          9997          Claim
# 15469          9998          Claim
# 15470          9999          Claim
#
#                          statement_type_description  label_as_nb clean_context
# 0                                        blog post            16        others
# 1      <p>\r\n\tA criticism of a candidate.</p>\r\n            6        others
# 2                                        blog post            16        others
# 3                                        blog post            10        others
# 10                                       blog post            14        others
# 13                               Flip-o-Meter items            0        others
# 15                                       blog post            10        others
# 16                                       blog post             8        others
# 17                                       blog post             6        others
# 18                                       blog post             8        others
# 21                                       blog post             8        others
# 22                                       blog post            10        others
# 24     <p>\r\n\tA criticism of a candidate.</p>\r\n            8        others
# 27                                       blog post            12        others
# 31                                       blog post             6        others
# 32                                       blog post             8        others
# 33                                       blog post             6        others
# 34                                       blog post            10        others
# 35                                       blog post            10        others
# 37                                       blog post            14        others
# 39                                       blog post             6        others
# 40                                       blog post            10        others
# 41                                       blog post            12        others
# 42                                       blog post             8        others
# 44                                       blog post             8        others
# 45                                       blog post            16        others
# 48                                       blog post            10        others
# 49                                       blog post            16        others
# 53                                       blog post            12        others
# 54                                       blog post            12        others
# ...                                             ...          ...           ...
# 15406                                    blog post            16        others
# 15410                                    blog post            10        others
# 15411                                    blog post             6        others
# 15417                            Flip-o-Meter items            2        others
# 15421                                    blog post             8        others
# 15422                                    blog post             8        others
# 15423                                    blog post            16        others
# 15424                                    blog post            14        others
# 15426  <p>\r\n\tA criticism of a candidate.</p>\r\n            8        others
# 15429                                    blog post            12        others
# 15431                                    blog post             8        others
# 15435                                    blog post            10        others
# 15436                                    blog post            12        others
# 15437                                    blog post            14        others
# 15438                                    blog post            16        others
# 15443                                    blog post            10        others
# 15447                                    blog post            14        others
# 15448                            Flip-o-Meter items            2        others
# 15449                                    blog post             6        others
# 15451  <p>\r\n\tA criticism of a candidate.</p>\r\n           14        others
# 15453                                    blog post            12        others
# 15455                                    blog post            10        others
# 15456                                    blog post            12        others
# 15462                                    blog post            12        others
# 15463                                    blog post            16        others
# 15465                                    blog post            14        others
# 15466                                    blog post             8        others
# 15468                                    blog post            14        others
# 15469                                    blog post            12        others
# 15470                                    blog post            14        others
#
# [9734 rows x 15 columns]

# %% [markdown]
# Let's just see what we have here:

# %%
def _count_for_last_name_(df, last_name):
    return group_and_count(lies.loc[lies['speaker_last_name'].str.contains(last_name, flags=re.IGNORECASE), :], 'label', with_pct=True)\
            .rename(columns={'count': f'count_{last_name}', 'count_pct': f'count_pct{last_name}'})

# %%
pd.merge(_count_for_last_name_(lies, 'obama'), _count_for_last_name_(lies, 'trump'), on='label')
# Out:
#          label  count_obama  count_pctobama  count_trump  count_pcttrump
# 0  mostly-true          169        0.267829           74        0.112977
# 1    half-true          162        0.256735           93        0.141985
# 2         true          127        0.201268           30        0.045802
# 3        false           73        0.115689          217        0.331298
# 4  barely-true           71        0.112520          137        0.209160
# 5    full-flop           13        0.020602            7        0.010687
# 6   pants-fire            9        0.014263           97        0.148092

# %% [markdown]
# Here we can see that Barack Obama had 549 statements labeled with _pants on fire_.

# %%
lies[lies['speaker_current_job'].str.contains('County') == True].shape
# Out:
# (335, 15)

# %%
lies['statement_date'].describe()
# Out:
# count                   15471
# unique                   3555
# top       2011-10-11 00:00:00
# freq                       26
# first     1995-04-01 00:00:00
# last      2018-11-22 00:00:00
# Name: statement_date, dtype: object

# %% [markdown]
# Above, we can see that statements range from 1995 to 2016.

# %% [markdown]
# Now, let's do some profiling to get some more insights, get some intuitive understanding of data and to see certain patterns if they exist.

# %%
profile = pandas_profiling.ProfileReport(lies)
profile.to_file(outputfile="profiler/output.html")

# %% [markdown]
# # Federal Election Results

# %% [markdown]
# We have another dataset that we will explore and merge to our LIAR dataset in order to get some more insight into data. This one is regarding election results.

# %%
pd.options.display.max_colwidth = 300
pd.options.display.max_columns = 300

# %%
from itertools import product
from functools import reduce

# %%
def add_ending(f):
    """ File ending depending on a year
    
    Parameters
    ----------
    f: str
        Name of the file
    
    ToDos:
    - do 2012 it's a special snowflake
    """
    if '2016' in f:
        return f"{f}x"
    else:
        return f


election_files = [(add_ending(f'{directory_election_results}/federalelections{year}.xls'), year) for year in [2014, 2016]]

# %% [markdown]
# Now, let's prepare some data for viewing:

# %%
election_results_cols_of_interest = ['CANDIDATE NAME', 'PRIMARY VOTES', 'PRIMARY %']

def fix_columns_election_results(df, year, type_):
    """we are only interested in the primary votes, since these reflect the opinion the most"""
    df = df.loc[:, election_results_cols_of_interest]
    df[f'primary_votes_{type_.lower()}_{year}'] = df['PRIMARY VOTES']
    df[f'primary_votes_{type_.lower()}_{year}_pct'] = df['PRIMARY %']
    return df.drop(columns=['PRIMARY VOTES', 'PRIMARY %'])


def get_only_voting_results(df):
    return df.loc[df['CANDIDATE NAME'].notna() & df['PRIMARY VOTES'].notna() & df['CANDIDATE NAME'].ne('Scattered') & df['CANDIDATE NAME'].ne('All Others'), :]


def prep_election_results(df, year, type_):
    return fix_columns_election_results(get_only_voting_results(df), year, type_)

# %%
election_results = [prep_election_results(pd.read_excel(f, sheet_name=f'{year} US {type_} Results by State'), year, type_) for (f, year), type_ in product(election_files, ['Senate', 'House'])]

# we let the results as they are, merge, and then check if the person is a senator or a member of the house based on the other results
# yes they did a spelling mistake
election_results += [prep_election_results(pd.read_excel(f'{directory_election_results}/federalelections2012.xls', sheet_name=f'2012 US House & Senate Resuts'), 2012, 'all')]
election_results = reduce(lambda acc, el: pd.merge(acc, el, on='CANDIDATE NAME', how='outer'), election_results)

# %%
election_results.head()
# Out:
#        CANDIDATE NAME primary_votes_senate_2014  \
# 0      Sessions, Jeff                 Unopposed
# 1       Sullivan, Dan                     44740
# 2         Miller, Joe                     35904
# 3     Treadwell, Mead                     27807
# 4  Jaramillo, John M.                      3246
#
#    primary_votes_senate_2014_pct primary_votes_house_2014  \
# 0                            NaN                      NaN
# 1                       0.400548                      NaN
# 2                       0.321441                      NaN
# 3                       0.248950                      NaN
# 4                       0.029061                      NaN
#
#    primary_votes_house_2014_pct primary_votes_senate_2016  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
#
#    primary_votes_senate_2016_pct primary_votes_house_2016  \
# 0                            NaN                      NaN
# 1                            NaN                      NaN
# 2                            NaN                      NaN
# 3                            NaN                      NaN
# 4                            NaN                      NaN
#
#    primary_votes_house_2016_pct primary_votes_all_2012  \
# 0                           NaN                    NaN
# 1                           NaN                    NaN
# 2                           NaN                    NaN
# 3                           NaN                    NaN
# 4                           NaN                    NaN
#
#   primary_votes_all_2012_pct
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN

# %%
idx_multiple_election_results = election_results.loc[:, [c for c in election_results.columns if any((c.endswith(str(y)) for y in [2012, 2014, 2016]))]].notna().sum(axis=1) > 1

# %%
print(f"we have multple election results for {idx_multiple_election_results.sum()} politicians")
# Out:
# we have multple election results for 1110 politicians

# %%
idx_multiple_election_results.mean()
# Out:
# 0.19618239660657477

# %%
election_results[idx_multiple_election_results].head()
# Out:
#               CANDIDATE NAME primary_votes_senate_2014  \
# 16             Gardner, Cory                    338324
# 19               Wade, Kevin                     18181
# 32             Schatz, Brian                    115445
# 33  Hanabusa, Colleen Wakako                    113663
# 36             Roco, John P.                      4425
#
#     primary_votes_senate_2014_pct primary_votes_house_2014  \
# 16                       1.000000                      NaN
# 19                       0.756627                      NaN
# 32                       0.493460                      NaN
# 33                       0.485843                      NaN
# 36                       0.123572                      NaN
#
#     primary_votes_house_2014_pct primary_votes_senate_2016  \
# 16                           NaN                       NaN
# 19                           NaN                       NaN
# 32                           NaN                    162905
# 33                           NaN                       NaN
# 36                           NaN                      3956
#
#     primary_votes_senate_2016_pct primary_votes_house_2016  \
# 16                            NaN                      NaN
# 19                            NaN                      NaN
# 32                       0.861662                      NaN
# 33                            NaN                    74022
# 36                       0.110303                      NaN
#
#     primary_votes_house_2016_pct primary_votes_all_2012  \
# 16                           NaN                  49340
# 19                           NaN              Unopposed
# 32                           NaN                    NaN
# 33                      0.803757                    NaN
# 36                           NaN                    545
#
#    primary_votes_all_2012_pct
# 16                          1
# 19                        NaN
# 32                        NaN
# 33                        NaN
# 36                  0.0112848

# %%
# yeah ... let's see how many we can join. the one letter endings might be a problem
election_results['CANDIDATE NAME'].value_counts()
# Out:
# Tonko, Paul D.                  36
# Reed, Thomas W., II             36
# Collins, Chris                  24
# Lowey, Nita M.                  12
# Slaughter, Louise M.            12
# Katko, John M.                  12
# Crowley, Joseph                 12
# Higgins, Brian                  12
# Maloney, Sean Patrick           12
# Engel, Eliot L.                 12
# Nadler, Jerrold L.              12
# King, Peter T.                   9
# Gibson, Christopher P.           9
# Israel, Steve J.                 9
# Kuster, Ann McLane               8
# Jeffries, Hakeem S.              8
# Assini, Mark W.                  8
# Stefanik, Elise M.               8
# Maloney, Carolyn B.              8
# Clarke, Yvette D.                8
# Zeldin, Lee M.                   6
# Long, Wendy                      6
# Bishop, Timothy H.               6
# Grimm, Michael G.                6
# Hayworth, Nan                    6
# Guinta, Frank C.                 4
# Turek, Jessica L.                4
# Hanna, Richard L.                4
# Rice, Kathleen M.                4
# Smith, Adrian                    4
#                                 ..
# Blaydes, Jeffery Oliver          1
# Brown, Hal                       1
# Brimm, Jacob                     1
# Dagnesses, Rafael Alberto        1
# Broun, Paul C                    1
# Phillips, Jeff                   1
# Adame, Marshall                  1
# Nguyen, Phat                     1
# Sheil, John                      1
# Tran, Stanford                   1
# Kultala, Kelly                   1
# Vaughn, Curtis Alphonzo, III     1
# Junaid, Murphy Alade             1
# Concepcion, Hector               1
# Whitmire, Tom                    1
# Hatch, Orrin G.                  1
# Seim, Gavin                      1
# Thompson, Tommy G.               1
# Williamson, Marianne             1
# Welsh, Barry                     1
# Graham, Lindsey                  1
# VanLandingham, Joel              1
# Cook, Tamarkus                   1
# Eggman, Michael                  1
# Beinstein, Alexander             1
# Holbrook, Mark I.                1
# Townsend, Les                    1
# Nightenhelser, Todd              1
# Luetkemeyer, Blaine              1
# Lind, Howard R. "Howie"          1
# Name: CANDIDATE NAME, Length: 5106, dtype: int64

# %%
# we are only interest in people and they have a first name
lies = lies.loc[lies['speaker_first_name'].notnull(), :]

# %%
# to aggregate the statements
lies['statement_year'] = lies['statement_date'].dt.year

# for the merging
lies['speaker_full_name'] = lies['speaker_last_name'] + ', ' + lies['speaker_first_name']

# %% [markdown]
# ### Cleaning job titles

# %%
# todo expand this and check this! this is just a quick and dirty fix
# is it really houseman? probably not...
_job_titles_of_interest = [('senat', 'senator'), ('governor', None), ('congress', 'congressman'), ('mayor', None), ('president', None), ('house', 'houseman'), ('rep', 'houseman')]
job_titles_of_interest = [out if out is not None else j for j, out in _job_titles_of_interest]

def cleaned_job_title(jt):
    jt = str(jt).lower()
    
    for j, out in _job_titles_of_interest:
        if j in jt:
            return out if out is not None else j
    else:
        return jt

lies['speakers_job_title_cleaned'] = lies['speaker_current_job'].apply(cleaned_job_title)

# %%
_t = lies.merge(election_results, left_on='speaker_full_name', right_on='CANDIDATE NAME', how='outer')

# %%
print(f"found election results for {_t['CANDIDATE NAME'].notnull().sum()} ({_t['CANDIDATE NAME'].notnull().mean()}%) people")
# Out:
# found election results for 8272 (0.39341767335679634%) people

# %%
votes_cols = [c for c in _t.columns if 'votes' in c]
useful_idx = reduce(lambda acc, el: acc | el, [_t[c].notnull() for c in votes_cols]) & _t['speaker_full_name'].notnull() 

print(f"found useful results for {useful_idx.sum()} people")

columns_of_interest = ['label', 'label_as_nb', 'subject', 'speaker_full_name', 'speakers_job_title_cleaned', 'state_info', 'party_affiliation', 'context', 'statement_date'] + votes_cols
_t.loc[useful_idx, columns_of_interest]
# Out:
# found useful results for 3020 people
# C:\Users\Jelena Banjac\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#              label  label_as_nb  subject      speaker_full_name  \
# 42      pants-fire         16.0      NaN      Bachmann, Michele
# 43           false         14.0      NaN      Bachmann, Michele
# 44      pants-fire         16.0      NaN      Bachmann, Michele
# 45      pants-fire         16.0      NaN      Bachmann, Michele
# 46           false         14.0      NaN      Bachmann, Michele
# 47           false         14.0      NaN      Bachmann, Michele
# 48      pants-fire         16.0      NaN      Bachmann, Michele
# 49           false         14.0      NaN      Bachmann, Michele
# 50           false         14.0      NaN      Bachmann, Michele
# 51           false         14.0      NaN      Bachmann, Michele
# 52      pants-fire         16.0      NaN      Bachmann, Michele
# 53           false         14.0      NaN      Bachmann, Michele
# 54      pants-fire         16.0      NaN      Bachmann, Michele
# 55     barely-true         12.0      NaN      Bachmann, Michele
# 56       half-true         10.0      NaN      Bachmann, Michele
# 57       half-true         10.0      NaN      Bachmann, Michele
# 58     barely-true         12.0      NaN      Bachmann, Michele
# 59           false         14.0      NaN      Bachmann, Michele
# 60     barely-true         12.0      NaN      Bachmann, Michele
# 61      pants-fire         16.0      NaN      Bachmann, Michele
# 62           false         14.0      NaN      Bachmann, Michele
# 63     barely-true         12.0      NaN      Bachmann, Michele
# 64            true          6.0      NaN      Bachmann, Michele
# 65           false         14.0      NaN      Bachmann, Michele
# 66           false         14.0      NaN      Bachmann, Michele
# 67     barely-true         12.0      NaN      Bachmann, Michele
# 68     mostly-true          8.0      NaN      Bachmann, Michele
# 69           false         14.0      NaN      Bachmann, Michele
# 70     mostly-true          8.0      NaN      Bachmann, Michele
# 71           false         14.0      NaN      Bachmann, Michele
# ...            ...          ...      ...                    ...
# 15545  barely-true         12.0      NaN          Sullivan, Dan
# 15546  barely-true         12.0      NaN          Sullivan, Dan
# 15547        false         14.0      NaN          Sullivan, Dan
# 15548    half-true         10.0      NaN          Sullivan, Dan
# 15549        false         14.0      NaN          Sullivan, Dan
# 15550    half-true         10.0      NaN         Alameel, David
# 15551        false         14.0      NaN         Alameel, David
# 15552   pants-fire         16.0      NaN         Alameel, David
# 15580    half-true         10.0      NaN          Rogers, Kesha
# 15581  barely-true         12.0      NaN          Rogers, Kesha
# 15591  mostly-true          8.0      NaN           Begich, Mark
# 15592  mostly-true          8.0      NaN           Begich, Mark
# 15593   pants-fire         16.0      NaN           Begich, Mark
# 15618    half-true         10.0      NaN           Peters, Gary
# 15626        false         14.0      NaN         McFadden, Mike
# 15638  mostly-true          8.0      NaN            Smith, Fred
# 15681        false         14.0      NaN          Buchal, James
# 15685        false         14.0      NaN          Amash, Justin
# 15688         true          6.0      NaN         Cuellar, Henry
# 15689  barely-true         12.0      NaN         Cuellar, Henry
# 15711        false         14.0      NaN          Leibham, Joe
# 15719  barely-true         12.0      NaN         MacDougall, Ed
# 15723    half-true         10.0      NaN          Jenkins, Lynn
# 15725  barely-true         12.0      NaN  Capito, Shelley Moore
# 15726        false         14.0      NaN  Capito, Shelley Moore
# 15738        false         14.0      NaN            Miller, Joe
# 15742    half-true         10.0      NaN      Robertson, Martha
# 15743    half-true         10.0      NaN      Robertson, Martha
# 15755        false         14.0      NaN            Garcia, Joe
# 15756        false         14.0      NaN            Garcia, Joe
#
#                                speakers_job_title_cleaned  state_info  \
# 42                                            congressman         NaN
# 43                                            congressman         NaN
# 44                                            congressman         NaN
# 45                                            congressman         NaN
# 46                                            congressman         NaN
# 47                                            congressman         NaN
# 48                                            congressman         NaN
# 49                                            congressman         NaN
# 50                                            congressman         NaN
# 51                                            congressman         NaN
# 52                                            congressman         NaN
# 53                                            congressman         NaN
# 54                                            congressman         NaN
# 55                                            congressman         NaN
# 56                                            congressman         NaN
# 57                                            congressman         NaN
# 58                                            congressman         NaN
# 59                                            congressman         NaN
# 60                                            congressman         NaN
# 61                                            congressman         NaN
# 62                                            congressman         NaN
# 63                                            congressman         NaN
# 64                                            congressman         NaN
# 65                                            congressman         NaN
# 66                                            congressman         NaN
# 67                                            congressman         NaN
# 68                                            congressman         NaN
# 69                                            congressman         NaN
# 70                                            congressman         NaN
# 71                                            congressman         NaN
# ...                                                   ...         ...
# 15545  alaska department of public resources commissioner         NaN
# 15546  alaska department of public resources commissioner         NaN
# 15547  alaska department of public resources commissioner         NaN
# 15548  alaska department of public resources commissioner         NaN
# 15549  alaska department of public resources commissioner         NaN
# 15550                                            investor         NaN
# 15551                                            investor         NaN
# 15552                                            investor         NaN
# 15580                                                             NaN
# 15581                                                             NaN
# 15591                                             senator         NaN
# 15592                                             senator         NaN
# 15593                                             senator         NaN
# 15618                                            houseman         NaN
# 15626                                                             NaN
# 15638                                                             NaN
# 15681                                            attorney         NaN
# 15685                                            houseman         NaN
# 15688                                            houseman         NaN
# 15689                                            houseman         NaN
# 15711                                                             NaN
# 15719                                               mayor         NaN
# 15723                                            houseman         NaN
# 15725                                            houseman         NaN
# 15726                                            houseman         NaN
# 15738                                                             NaN
# 15742                         tompkins county legislator          NaN
# 15743                         tompkins county legislator          NaN
# 15755                                              lawyer         NaN
# 15756                                              lawyer         NaN
#
#        party_affiliation  \
# 42                   NaN
# 43                   NaN
# 44                   NaN
# 45                   NaN
# 46                   NaN
# 47                   NaN
# 48                   NaN
# 49                   NaN
# 50                   NaN
# 51                   NaN
# 52                   NaN
# 53                   NaN
# 54                   NaN
# 55                   NaN
# 56                   NaN
# 57                   NaN
# 58                   NaN
# 59                   NaN
# 60                   NaN
# 61                   NaN
# 62                   NaN
# 63                   NaN
# 64                   NaN
# 65                   NaN
# 66                   NaN
# 67                   NaN
# 68                   NaN
# 69                   NaN
# 70                   NaN
# 71                   NaN
# ...                  ...
# 15545                NaN
# 15546                NaN
# 15547                NaN
# 15548                NaN
# 15549                NaN
# 15550                NaN
# 15551                NaN
# 15552                NaN
# 15580                NaN
# 15581                NaN
# 15591                NaN
# 15592                NaN
# 15593                NaN
# 15618                NaN
# 15626                NaN
# 15638                NaN
# 15681                NaN
# 15685                NaN
# 15688                NaN
# 15689                NaN
# 15711                NaN
# 15719                NaN
# 15723                NaN
# 15725                NaN
# 15726                NaN
# 15738                NaN
# 15742                NaN
# 15743                NaN
# 15755                NaN
# 15756                NaN
#
#                                                                 context  \
# 42                                     an interview with Pajamas Media.
# 43                                                      a press release
# 44                                         a Washington Times interview
# 45                              an interview with the Washington Times.
# 46                                       a statement on the House floor
# 47                                                  an interview on CNN
# 48         an interview on Sean Hannity's show on the Fox News Channel.
# 49                                an interview on CNN's Larry King Live
# 50                                           on CBS's "Face the Nation"
# 51
# 52                                  a speech to the Values Voter Summit
# 53                                                      a CNN interview
# 54                              an interview on "Good Morning America."
# 55                                 a response to the State of the Union
# 56                         a rebuttal to the State of the Union address
# 57                         a rebuttal to the State of the Union address
# 58                         a response to the State of the Union address
# 59                            an interview on "The Laura Ingraham Show"
# 60                               an interview on NBC's "Meet the Press"
# 61               a speech at the Conservative Principles PAC Conference
# 62                                   an interview on NBC's "Today" show
# 63                                            a debate in New Hampshire
# 64                                            a debate in New Hampshire
# 65                              an interview on CBS's "Face the Nation"
# 66                             an interview on WKXL-AM in Concord, N.H.
# 67                                                 CBS' Face the Nation
# 68                                      several speeches and interviews
# 69                                             an interview on Fox News
# 70                                                 a prepared statement
# 71                                               a debate in Ames, Iowa
# ...                                                                 ...
# 15545                                            a campaign email blast
# 15546                                                        a radio ad
# 15547                                                        a radio ad
# 15548                                                   a Facebook meme
# 15549                                            an email to supporters
# 15550                                                    an email blast
# 15551  his speech at the state convention of the Texas Democratic Party
# 15552               his speech at the Texas Democratic Party convention
# 15580                                statements on her campaign website
# 15581                                                      an interview
# 15591                                                           a TV ad
# 15592                                                        a radio ad
# 15593                                                     a campaign ad
# 15618                                                   a press release
# 15626                                                           a TV ad
# 15638                                     appearance on ABC's This Week
# 15681                                      a campaign website statement
# 15685                                                     a campaign ad
# 15688                        an interview on CNN's "State of the Union"
# 15689
# 15711                                                    a news release
# 15719                                                        a radio ad
# 15723                                                a press conference
# 15725                                                     a campaign ad
# 15726                                                     a campaign ad
# 15738                                                 a campaign mailer
# 15742                                                     a campaign ad
# 15743                                                     a campaign ad
# 15755                                                          a Web ad
# 15756                                                          a web ad
#
#       statement_date primary_votes_senate_2014  primary_votes_senate_2014_pct  \
# 42        2009-04-27                       NaN                            NaN
# 43        2009-05-06                       NaN                            NaN
# 44        2009-06-17                       NaN                            NaN
# 45        2009-06-17                       NaN                            NaN
# 46        2009-07-27                       NaN                            NaN
# 47        2015-09-10                       NaN                            NaN
# 48        2009-10-30                       NaN                            NaN
# 49        2010-03-03                       NaN                            NaN
# 50        2010-03-28                       NaN                            NaN
# 51        2010-06-11                       NaN                            NaN
# 52        2010-09-17                       NaN                            NaN
# 53        2010-11-03                       NaN                            NaN
# 54        2010-11-16                       NaN                            NaN
# 55        2011-01-25                       NaN                            NaN
# 56        2011-01-25                       NaN                            NaN
# 57        2011-01-25                       NaN                            NaN
# 58        2011-01-25                       NaN                            NaN
# 59        2011-02-15                       NaN                            NaN
# 60        2011-03-06                       NaN                            NaN
# 61        2011-03-26                       NaN                            NaN
# 62        2011-04-13                       NaN                            NaN
# 63        2011-06-13                       NaN                            NaN
# 64        2011-06-13                       NaN                            NaN
# 65        2011-06-26                       NaN                            NaN
# 66        2011-06-01                       NaN                            NaN
# 67        2011-06-26                       NaN                            NaN
# 68        2011-06-27                       NaN                            NaN
# 69        2011-06-26                       NaN                            NaN
# 70        2011-07-24                       NaN                            NaN
# 71        2011-08-11                       NaN                            NaN
# ...              ...                       ...                            ...
# 15545     2014-02-20                     44740                       0.400548
# 15546     2014-04-29                     44740                       0.400548
# 15547     2014-06-20                     44740                       0.400548
# 15548     2014-09-17                     44740                       0.400548
# 15549     2014-09-19                     44740                       0.400548
# 15550     2014-02-07                       NaN                            NaN
# 15551     2014-06-28                       NaN                            NaN
# 15552     2014-06-28                       NaN                            NaN
# 15580     2014-03-19                    110146                       0.215969
# 15581     2014-03-27                    110146                       0.215969
# 15591     2014-03-20                     58092                       0.966332
# 15592     2014-07-14                     58092                       0.966332
# 15593     2014-08-29                     58092                       0.966332
# 15618     2014-04-14                    504102                       1.000000
# 15626     2014-04-17                    129601                       0.717367
# 15638     2009-02-05                       NaN                            NaN
# 15681     2014-06-16                       NaN                            NaN
# 15685     2014-07-01                       NaN                            NaN
# 15688     2014-07-06                       NaN                            NaN
# 15689     2014-07-16                       NaN                            NaN
# 15711     2014-07-19                       NaN                            NaN
# 15719     2014-07-26                       NaN                            NaN
# 15723     2014-07-29                       NaN                            NaN
# 15725     2014-07-29                       NaN                            NaN
# 15726     2014-07-29                       NaN                            NaN
# 15738     2014-08-09                     35904                       0.321441
# 15742     2014-08-12                       NaN                            NaN
# 15743     2014-08-12                       NaN                            NaN
# 15755     2014-09-05                       NaN                            NaN
# 15756     2014-09-05                       NaN                            NaN
#
#       primary_votes_house_2014  primary_votes_house_2014_pct  \
# 42                         NaN                           NaN
# 43                         NaN                           NaN
# 44                         NaN                           NaN
# 45                         NaN                           NaN
# 46                         NaN                           NaN
# 47                         NaN                           NaN
# 48                         NaN                           NaN
# 49                         NaN                           NaN
# 50                         NaN                           NaN
# 51                         NaN                           NaN
# 52                         NaN                           NaN
# 53                         NaN                           NaN
# 54                         NaN                           NaN
# 55                         NaN                           NaN
# 56                         NaN                           NaN
# 57                         NaN                           NaN
# 58                         NaN                           NaN
# 59                         NaN                           NaN
# 60                         NaN                           NaN
# 61                         NaN                           NaN
# 62                         NaN                           NaN
# 63                         NaN                           NaN
# 64                         NaN                           NaN
# 65                         NaN                           NaN
# 66                         NaN                           NaN
# 67                         NaN                           NaN
# 68                         NaN                           NaN
# 69                         NaN                           NaN
# 70                         NaN                           NaN
# 71                         NaN                           NaN
# ...                        ...                           ...
# 15545                      NaN                           NaN
# 15546                      NaN                           NaN
# 15547                      NaN                           NaN
# 15548                      NaN                           NaN
# 15549                      NaN                           NaN
# 15550                      NaN                           NaN
# 15551                      NaN                           NaN
# 15552                      NaN                           NaN
# 15580                      NaN                           NaN
# 15581                      NaN                           NaN
# 15591                      NaN                           NaN
# 15592                      NaN                           NaN
# 15593                      NaN                           NaN
# 15618                      NaN                           NaN
# 15626                      NaN                           NaN
# 15638                      NaN                           NaN
# 15681                    15083                      0.978082
# 15685                    39706                      0.574384
# 15688                    36821                      1.000000
# 15689                    36821                      1.000000
# 15711                    23028                      0.358162
# 15719                     7455                      0.252840
# 15723                    41850                      0.691393
# 15725                      NaN                           NaN
# 15726                      NaN                           NaN
# 15738                      NaN                           NaN
# 15742                Unopposed                           NaN
# 15743                Unopposed                           NaN
# 15755                Unopposed                           NaN
# 15756                Unopposed                           NaN
#
#       primary_votes_senate_2016  primary_votes_senate_2016_pct  \
# 42                          NaN                            NaN
# 43                          NaN                            NaN
# 44                          NaN                            NaN
# 45                          NaN                            NaN
# 46                          NaN                            NaN
# 47                          NaN                            NaN
# 48                          NaN                            NaN
# 49                          NaN                            NaN
# 50                          NaN                            NaN
# 51                          NaN                            NaN
# 52                          NaN                            NaN
# 53                          NaN                            NaN
# 54                          NaN                            NaN
# 55                          NaN                            NaN
# 56                          NaN                            NaN
# 57                          NaN                            NaN
# 58                          NaN                            NaN
# 59                          NaN                            NaN
# 60                          NaN                            NaN
# 61                          NaN                            NaN
# 62                          NaN                            NaN
# 63                          NaN                            NaN
# 64                          NaN                            NaN
# 65                          NaN                            NaN
# 66                          NaN                            NaN
# 67                          NaN                            NaN
# 68                          NaN                            NaN
# 69                          NaN                            NaN
# 70                          NaN                            NaN
# 71                          NaN                            NaN
# ...                         ...                            ...
# 15545                       NaN                            NaN
# 15546                       NaN                            NaN
# 15547                       NaN                            NaN
# 15548                       NaN                            NaN
# 15549                       NaN                            NaN
# 15550                       NaN                            NaN
# 15551                       NaN                            NaN
# 15552                       NaN                            NaN
# 15580                       NaN                            NaN
# 15581                       NaN                            NaN
# 15591                       NaN                            NaN
# 15592                       NaN                            NaN
# 15593                       NaN                            NaN
# 15618                       NaN                            NaN
# 15626                       NaN                            NaN
# 15638                       NaN                            NaN
# 15681                       NaN                            NaN
# 15685                       NaN                            NaN
# 15688                       NaN                            NaN
# 15689                       NaN                            NaN
# 15711                       NaN                            NaN
# 15719                       NaN                            NaN
# 15723                       NaN                            NaN
# 15725                       NaN                            NaN
# 15726                       NaN                            NaN
# 15738                       NaN                            NaN
# 15742                       NaN                            NaN
# 15743                       NaN                            NaN
# 15755                       NaN                            NaN
# 15756                       NaN                            NaN
#
#       primary_votes_house_2016  primary_votes_house_2016_pct  \
# 42                         NaN                           NaN
# 43                         NaN                           NaN
# 44                         NaN                           NaN
# 45                         NaN                           NaN
# 46                         NaN                           NaN
# 47                         NaN                           NaN
# 48                         NaN                           NaN
# 49                         NaN                           NaN
# 50                         NaN                           NaN
# 51                         NaN                           NaN
# 52                         NaN                           NaN
# 53                         NaN                           NaN
# 54                         NaN                           NaN
# 55                         NaN                           NaN
# 56                         NaN                           NaN
# 57                         NaN                           NaN
# 58                         NaN                           NaN
# 59                         NaN                           NaN
# 60                         NaN                           NaN
# 61                         NaN                           NaN
# 62                         NaN                           NaN
# 63                         NaN                           NaN
# 64                         NaN                           NaN
# 65                         NaN                           NaN
# 66                         NaN                           NaN
# 67                         NaN                           NaN
# 68                         NaN                           NaN
# 69                         NaN                           NaN
# 70                         NaN                           NaN
# 71                         NaN                           NaN
# ...                        ...                           ...
# 15545                      NaN                           NaN
# 15546                      NaN                           NaN
# 15547                      NaN                           NaN
# 15548                      NaN                           NaN
# 15549                      NaN                           NaN
# 15550                      NaN                           NaN
# 15551                      NaN                           NaN
# 15552                      NaN                           NaN
# 15580                      NaN                           NaN
# 15581                      NaN                           NaN
# 15591                      NaN                           NaN
# 15592                      NaN                           NaN
# 15593                      NaN                           NaN
# 15618                      NaN                           NaN
# 15626                      NaN                           NaN
# 15638                      NaN                           NaN
# 15681                      NaN                           NaN
# 15685                    55889                      1.000000
# 15688                    49993                      0.897927
# 15689                    49993                      0.897927
# 15711                      NaN                           NaN
# 15719                      NaN                           NaN
# 15723                    54958                      1.000000
# 15725                      NaN                           NaN
# 15726                      NaN                           NaN
# 15738                      NaN                           NaN
# 15742                      NaN                           NaN
# 15743                      NaN                           NaN
# 15755                      NaN                           NaN
# 15756                      NaN                           NaN
#
#       primary_votes_all_2012 primary_votes_all_2012_pct
# 42                     14569                   0.803452
# 43                     14569                   0.803452
# 44                     14569                   0.803452
# 45                     14569                   0.803452
# 46                     14569                   0.803452
# 47                     14569                   0.803452
# 48                     14569                   0.803452
# 49                     14569                   0.803452
# 50                     14569                   0.803452
# 51                     14569                   0.803452
# 52                     14569                   0.803452
# 53                     14569                   0.803452
# 54                     14569                   0.803452
# 55                     14569                   0.803452
# 56                     14569                   0.803452
# 57                     14569                   0.803452
# 58                     14569                   0.803452
# 59                     14569                   0.803452
# 60                     14569                   0.803452
# 61                     14569                   0.803452
# 62                     14569                   0.803452
# 63                     14569                   0.803452
# 64                     14569                   0.803452
# 65                     14569                   0.803452
# 66                     14569                   0.803452
# 67                     14569                   0.803452
# 68                     14569                   0.803452
# 69                     14569                   0.803452
# 70                     14569                   0.803452
# 71                     14569                   0.803452
# ...                      ...                        ...
# 15545                    NaN                        NaN
# 15546                    NaN                        NaN
# 15547                    NaN                        NaN
# 15548                    NaN                        NaN
# 15549                    NaN                        NaN
# 15550                   2064                   0.109392
# 15551                   2064                   0.109392
# 15552                   2064                   0.109392
# 15580                   3666                   0.507124
# 15581                   3666                   0.507124
# 15591                    NaN                        NaN
# 15592                    NaN                        NaN
# 15593                    NaN                        NaN
# 15618                  41230                   0.470302
# 15626                    NaN                        NaN
# 15638                   2232                  0.0290002
# 15681                    NaN                        NaN
# 15685                  51113                   0.999687
# 15688                  35350                          1
# 15689                  35350                          1
# 15711                    NaN                        NaN
# 15719                    NaN                        NaN
# 15723                  64008                          1
# 15725                  35008                   0.829298
# 15726                  35008                   0.829298
# 15738                    NaN                        NaN
# 15742                    NaN                        NaN
# 15743                    NaN                        NaN
# 15755                  13927                   0.533683
# 15756                  13927                   0.533683
#
# [3020 rows x 19 columns]

# %%
_t.loc[useful_idx, 'speakers_job_title_cleaned'].value_counts()
# Out:
# senator                                                                                                 1070
# houseman                                                                                                 700
# congressman                                                                                              442
#                                                                                                          261
# milwaukee county executive                                                                               211
# governor                                                                                                  89
# ohio treasurer                                                                                            29
# state assembly member, 78th district                                                                      25
# actor                                                                                                     19
# businessman                                                                                               19
# small business owner                                                                                      13
# lawyer                                                                                                    13
# assemblywoman                                                                                              9
# mayor                                                                                                      9
# incoming speaker of state assembly                                                                         8
# attorney                                                                                                   8
# retired social worker                                                                                      8
# conservative activist                                                                                      7
# director of the office of management and budget                                                            6
# former pastor                                                                                              5
# alaska department of public resources commissioner                                                         5
# member of state assembly, 82nd district                                                                    5
# miami-dade school board member                                                                             4
# pediatric neurosurgeon                                                                                     4
# nova southeastern university law professor                                                                 4
# developer                                                                                                  4
# investor                                                                                                   3
# investment manager                                                                                         3
# candidate                                                                                                  3
# state assemblyman                                                                                          2
# tompkins county legislator                                                                                 2
# management consultant                                                                                      2
# legislator                                                                                                 2
# immigration attorney                                                                                       2
# winnebago county executive                                                                                 2
# theater owner, activist                                                                                    2
# fayette county commissioner                                                                                2
# radiologist and radio station owner                                                                        2
# former espn analyst                                                                                        2
# civil engineer                                                                                             2
# restaurant owner                                                                                           2
# bexar county tax assessor-collector                                                                        1
# private attorney                                                                                           1
# real estate investor                                                                                       1
# secretary, libertarian party of wisconsin midwest regional director, our america initiative lead coo       1
# student                                                                                                    1
# managing partner at nexus homes                                                                            1
# pinal county sheriff                                                                                       1
# director of communications for lamp post group, a venture capital incubator in chatt                       1
# vice chairperson of the new york state democratic committee                                                1
# businesswoman                                                                                              1
# Name: speakers_job_title_cleaned, dtype: int64

# %%
_t.loc[_t['speakers_job_title_cleaned'].isin(job_titles_of_interest) & useful_idx, columns_of_interest]
# Out:
# C:\Users\Jelena Banjac\Anaconda3\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#              label  label_as_nb  subject      speaker_full_name  \
# 42      pants-fire         16.0      NaN      Bachmann, Michele
# 43           false         14.0      NaN      Bachmann, Michele
# 44      pants-fire         16.0      NaN      Bachmann, Michele
# 45      pants-fire         16.0      NaN      Bachmann, Michele
# 46           false         14.0      NaN      Bachmann, Michele
# 47           false         14.0      NaN      Bachmann, Michele
# 48      pants-fire         16.0      NaN      Bachmann, Michele
# 49           false         14.0      NaN      Bachmann, Michele
# 50           false         14.0      NaN      Bachmann, Michele
# 51           false         14.0      NaN      Bachmann, Michele
# 52      pants-fire         16.0      NaN      Bachmann, Michele
# 53           false         14.0      NaN      Bachmann, Michele
# 54      pants-fire         16.0      NaN      Bachmann, Michele
# 55     barely-true         12.0      NaN      Bachmann, Michele
# 56       half-true         10.0      NaN      Bachmann, Michele
# 57       half-true         10.0      NaN      Bachmann, Michele
# 58     barely-true         12.0      NaN      Bachmann, Michele
# 59           false         14.0      NaN      Bachmann, Michele
# 60     barely-true         12.0      NaN      Bachmann, Michele
# 61      pants-fire         16.0      NaN      Bachmann, Michele
# 62           false         14.0      NaN      Bachmann, Michele
# 63     barely-true         12.0      NaN      Bachmann, Michele
# 64            true          6.0      NaN      Bachmann, Michele
# 65           false         14.0      NaN      Bachmann, Michele
# 66           false         14.0      NaN      Bachmann, Michele
# 67     barely-true         12.0      NaN      Bachmann, Michele
# 68     mostly-true          8.0      NaN      Bachmann, Michele
# 69           false         14.0      NaN      Bachmann, Michele
# 70     mostly-true          8.0      NaN      Bachmann, Michele
# 71           false         14.0      NaN      Bachmann, Michele
# ...            ...          ...      ...                    ...
# 15238  barely-true         12.0      NaN       Bridenstine, Jim
# 15244  mostly-true          8.0      NaN           Lee, Barbara
# 15245  mostly-true          8.0      NaN           Lee, Barbara
# 15254  mostly-true          8.0      NaN            Green, Gene
# 15255        false         14.0      NaN            Young, Todd
# 15275  mostly-true          8.0      NaN           Foster, Bill
# 15276    half-true         10.0      NaN           Foster, Bill
# 15277    half-true         10.0      NaN           Foster, Bill
# 15278         true          6.0      NaN           Foster, Bill
# 15279  barely-true         12.0      NaN           Foster, Bill
# 15280  mostly-true          8.0      NaN           Foster, Bill
# 15295    half-true         10.0      NaN          Schatz, Brian
# 15330  mostly-true          8.0      NaN        Lummis, Cynthia
# 15331   pants-fire         16.0      NaN        Lummis, Cynthia
# 15360         true          6.0      NaN           Ross, Dennis
# 15491  mostly-true          8.0      NaN      Garcia, Marilinda
# 15492  mostly-true          8.0      NaN      Garcia, Marilinda
# 15493  barely-true         12.0      NaN      Garcia, Marilinda
# 15494  barely-true         12.0      NaN      Garcia, Marilinda
# 15591  mostly-true          8.0      NaN           Begich, Mark
# 15592  mostly-true          8.0      NaN           Begich, Mark
# 15593   pants-fire         16.0      NaN           Begich, Mark
# 15618    half-true         10.0      NaN           Peters, Gary
# 15685        false         14.0      NaN          Amash, Justin
# 15688         true          6.0      NaN         Cuellar, Henry
# 15689  barely-true         12.0      NaN         Cuellar, Henry
# 15719  barely-true         12.0      NaN         MacDougall, Ed
# 15723    half-true         10.0      NaN          Jenkins, Lynn
# 15725  barely-true         12.0      NaN  Capito, Shelley Moore
# 15726        false         14.0      NaN  Capito, Shelley Moore
#
#       speakers_job_title_cleaned  state_info  party_affiliation  \
# 42                   congressman         NaN                NaN
# 43                   congressman         NaN                NaN
# 44                   congressman         NaN                NaN
# 45                   congressman         NaN                NaN
# 46                   congressman         NaN                NaN
# 47                   congressman         NaN                NaN
# 48                   congressman         NaN                NaN
# 49                   congressman         NaN                NaN
# 50                   congressman         NaN                NaN
# 51                   congressman         NaN                NaN
# 52                   congressman         NaN                NaN
# 53                   congressman         NaN                NaN
# 54                   congressman         NaN                NaN
# 55                   congressman         NaN                NaN
# 56                   congressman         NaN                NaN
# 57                   congressman         NaN                NaN
# 58                   congressman         NaN                NaN
# 59                   congressman         NaN                NaN
# 60                   congressman         NaN                NaN
# 61                   congressman         NaN                NaN
# 62                   congressman         NaN                NaN
# 63                   congressman         NaN                NaN
# 64                   congressman         NaN                NaN
# 65                   congressman         NaN                NaN
# 66                   congressman         NaN                NaN
# 67                   congressman         NaN                NaN
# 68                   congressman         NaN                NaN
# 69                   congressman         NaN                NaN
# 70                   congressman         NaN                NaN
# 71                   congressman         NaN                NaN
# ...                          ...         ...                ...
# 15238                   houseman         NaN                NaN
# 15244                congressman         NaN                NaN
# 15245                congressman         NaN                NaN
# 15254                   houseman         NaN                NaN
# 15255                congressman         NaN                NaN
# 15275                      mayor         NaN                NaN
# 15276                      mayor         NaN                NaN
# 15277                      mayor         NaN                NaN
# 15278                      mayor         NaN                NaN
# 15279                      mayor         NaN                NaN
# 15280                      mayor         NaN                NaN
# 15295                    senator         NaN                NaN
# 15330                   houseman         NaN                NaN
# 15331                   houseman         NaN                NaN
# 15360                   houseman         NaN                NaN
# 15491                   houseman         NaN                NaN
# 15492                   houseman         NaN                NaN
# 15493                   houseman         NaN                NaN
# 15494                   houseman         NaN                NaN
# 15591                    senator         NaN                NaN
# 15592                    senator         NaN                NaN
# 15593                    senator         NaN                NaN
# 15618                   houseman         NaN                NaN
# 15685                   houseman         NaN                NaN
# 15688                   houseman         NaN                NaN
# 15689                   houseman         NaN                NaN
# 15719                      mayor         NaN                NaN
# 15723                   houseman         NaN                NaN
# 15725                   houseman         NaN                NaN
# 15726                   houseman         NaN                NaN
#
#                                                             context  \
# 42                                 an interview with Pajamas Media.
# 43                                                  a press release
# 44                                     a Washington Times interview
# 45                          an interview with the Washington Times.
# 46                                   a statement on the House floor
# 47                                              an interview on CNN
# 48     an interview on Sean Hannity's show on the Fox News Channel.
# 49                            an interview on CNN's Larry King Live
# 50                                       on CBS's "Face the Nation"
# 51
# 52                              a speech to the Values Voter Summit
# 53                                                  a CNN interview
# 54                          an interview on "Good Morning America."
# 55                             a response to the State of the Union
# 56                     a rebuttal to the State of the Union address
# 57                     a rebuttal to the State of the Union address
# 58                     a response to the State of the Union address
# 59                        an interview on "The Laura Ingraham Show"
# 60                           an interview on NBC's "Meet the Press"
# 61           a speech at the Conservative Principles PAC Conference
# 62                               an interview on NBC's "Today" show
# 63                                        a debate in New Hampshire
# 64                                        a debate in New Hampshire
# 65                          an interview on CBS's "Face the Nation"
# 66                         an interview on WKXL-AM in Concord, N.H.
# 67                                             CBS' Face the Nation
# 68                                  several speeches and interviews
# 69                                         an interview on Fox News
# 70                                             a prepared statement
# 71                                           a debate in Ames, Iowa
# ...                                                             ...
# 15238                                          a House floor speech
# 15244                                       an interview with MSNBC
# 15245                               an episode of CNN's "Crossfire"
# 15254                                               a press release
# 15255                                     a letter to a constituent
# 15275                                           a campaign brochure
# 15276                                              a mayoral debate
# 15277                                               a mayoral forum
# 15278                                               a mayoral forum
# 15279                                               a mayoral forum
# 15280                           a Tampa Bay Times/Bay News 9 debate
# 15295                      a speech on the floor of the U.S. Senate
# 15330                                             a radio interview
# 15331                                            a news conference.
# 15360                               an op-ed in the Tampa Bay Times
# 15491                                                       a tweet
# 15492                                                       a tweet
# 15493                                           in a campaign tweet
# 15494                                           in a campaign tweet
# 15591                                                       a TV ad
# 15592                                                    a radio ad
# 15593                                                 a campaign ad
# 15618                                               a press release
# 15685                                                 a campaign ad
# 15688                    an interview on CNN's "State of the Union"
# 15689
# 15719                                                    a radio ad
# 15723                                            a press conference
# 15725                                                 a campaign ad
# 15726                                                 a campaign ad
#
#       statement_date primary_votes_senate_2014  primary_votes_senate_2014_pct  \
# 42        2009-04-27                       NaN                            NaN
# 43        2009-05-06                       NaN                            NaN
# 44        2009-06-17                       NaN                            NaN
# 45        2009-06-17                       NaN                            NaN
# 46        2009-07-27                       NaN                            NaN
# 47        2015-09-10                       NaN                            NaN
# 48        2009-10-30                       NaN                            NaN
# 49        2010-03-03                       NaN                            NaN
# 50        2010-03-28                       NaN                            NaN
# 51        2010-06-11                       NaN                            NaN
# 52        2010-09-17                       NaN                            NaN
# 53        2010-11-03                       NaN                            NaN
# 54        2010-11-16                       NaN                            NaN
# 55        2011-01-25                       NaN                            NaN
# 56        2011-01-25                       NaN                            NaN
# 57        2011-01-25                       NaN                            NaN
# 58        2011-01-25                       NaN                            NaN
# 59        2011-02-15                       NaN                            NaN
# 60        2011-03-06                       NaN                            NaN
# 61        2011-03-26                       NaN                            NaN
# 62        2011-04-13                       NaN                            NaN
# 63        2011-06-13                       NaN                            NaN
# 64        2011-06-13                       NaN                            NaN
# 65        2011-06-26                       NaN                            NaN
# 66        2011-06-01                       NaN                            NaN
# 67        2011-06-26                       NaN                            NaN
# 68        2011-06-27                       NaN                            NaN
# 69        2011-06-26                       NaN                            NaN
# 70        2011-07-24                       NaN                            NaN
# 71        2011-08-11                       NaN                            NaN
# ...              ...                       ...                            ...
# 15238     2013-06-11                       NaN                            NaN
# 15244     2013-06-17                       NaN                            NaN
# 15245     2013-12-04                       NaN                            NaN
# 15254     2013-06-28                       NaN                            NaN
# 15255     2013-06-19                       NaN                            NaN
# 15275     2013-07-09                       NaN                            NaN
# 15276     2013-08-06                       NaN                            NaN
# 15277     2013-08-06                       NaN                            NaN
# 15278     2013-08-14                       NaN                            NaN
# 15279     2013-09-10                       NaN                            NaN
# 15280     2013-10-15                       NaN                            NaN
# 15295     2013-07-24                    115445                       0.493460
# 15330     2013-08-23                       NaN                            NaN
# 15331     2009-03-24                       NaN                            NaN
# 15360     2013-10-07                       NaN                            NaN
# 15491     2013-12-11                       NaN                            NaN
# 15492     2013-12-11                       NaN                            NaN
# 15493     2014-06-27                       NaN                            NaN
# 15494     2014-06-27                       NaN                            NaN
# 15591     2014-03-20                     58092                       0.966332
# 15592     2014-07-14                     58092                       0.966332
# 15593     2014-08-29                     58092                       0.966332
# 15618     2014-04-14                    504102                       1.000000
# 15685     2014-07-01                       NaN                            NaN
# 15688     2014-07-06                       NaN                            NaN
# 15689     2014-07-16                       NaN                            NaN
# 15719     2014-07-26                       NaN                            NaN
# 15723     2014-07-29                       NaN                            NaN
# 15725     2014-07-29                       NaN                            NaN
# 15726     2014-07-29                       NaN                            NaN
#
#       primary_votes_house_2014  primary_votes_house_2014_pct  \
# 42                         NaN                           NaN
# 43                         NaN                           NaN
# 44                         NaN                           NaN
# 45                         NaN                           NaN
# 46                         NaN                           NaN
# 47                         NaN                           NaN
# 48                         NaN                           NaN
# 49                         NaN                           NaN
# 50                         NaN                           NaN
# 51                         NaN                           NaN
# 52                         NaN                           NaN
# 53                         NaN                           NaN
# 54                         NaN                           NaN
# 55                         NaN                           NaN
# 56                         NaN                           NaN
# 57                         NaN                           NaN
# 58                         NaN                           NaN
# 59                         NaN                           NaN
# 60                         NaN                           NaN
# 61                         NaN                           NaN
# 62                         NaN                           NaN
# 63                         NaN                           NaN
# 64                         NaN                           NaN
# 65                         NaN                           NaN
# 66                         NaN                           NaN
# 67                         NaN                           NaN
# 68                         NaN                           NaN
# 69                         NaN                           NaN
# 70                         NaN                           NaN
# 71                         NaN                           NaN
# ...                        ...                           ...
# 15238                Unopposed                           NaN
# 15244                    77461                      0.825934
# 15245                    77461                      0.825934
# 15254                     6244                      1.000000
# 15255                    30402                      0.793744
# 15275                      NaN                           NaN
# 15276                      NaN                           NaN
# 15277                      NaN                           NaN
# 15278                      NaN                           NaN
# 15279                      NaN                           NaN
# 15280                      NaN                           NaN
# 15295                      NaN                           NaN
# 15330                    70918                      0.758944
# 15331                    70918                      0.758944
# 15360                      NaN                           NaN
# 15491                       79                      0.003663
# 15492                    27285                      0.491941
# 15493                       79                      0.003663
# 15494                    27285                      0.491941
# 15591                      NaN                           NaN
# 15592                      NaN                           NaN
# 15593                      NaN                           NaN
# 15618                      NaN                           NaN
# 15685                    39706                      0.574384
# 15688                    36821                      1.000000
# 15689                    36821                      1.000000
# 15719                     7455                      0.252840
# 15723                    41850                      0.691393
# 15725                      NaN                           NaN
# 15726                      NaN                           NaN
#
#       primary_votes_senate_2016  primary_votes_senate_2016_pct  \
# 42                          NaN                            NaN
# 43                          NaN                            NaN
# 44                          NaN                            NaN
# 45                          NaN                            NaN
# 46                          NaN                            NaN
# 47                          NaN                            NaN
# 48                          NaN                            NaN
# 49                          NaN                            NaN
# 50                          NaN                            NaN
# 51                          NaN                            NaN
# 52                          NaN                            NaN
# 53                          NaN                            NaN
# 54                          NaN                            NaN
# 55                          NaN                            NaN
# 56                          NaN                            NaN
# 57                          NaN                            NaN
# 58                          NaN                            NaN
# 59                          NaN                            NaN
# 60                          NaN                            NaN
# 61                          NaN                            NaN
# 62                          NaN                            NaN
# 63                          NaN                            NaN
# 64                          NaN                            NaN
# 65                          NaN                            NaN
# 66                          NaN                            NaN
# 67                          NaN                            NaN
# 68                          NaN                            NaN
# 69                          NaN                            NaN
# 70                          NaN                            NaN
# 71                          NaN                            NaN
# ...                         ...                            ...
# 15238                       NaN                            NaN
# 15244                       NaN                            NaN
# 15245                       NaN                            NaN
# 15254                       NaN                            NaN
# 15255                    661136                       0.670819
# 15275                       NaN                            NaN
# 15276                       NaN                            NaN
# 15277                       NaN                            NaN
# 15278                       NaN                            NaN
# 15279                       NaN                            NaN
# 15280                       NaN                            NaN
# 15295                    162905                       0.861662
# 15330                       NaN                            NaN
# 15331                       NaN                            NaN
# 15360                       NaN                            NaN
# 15491                       NaN                            NaN
# 15492                       NaN                            NaN
# 15493                       NaN                            NaN
# 15494                       NaN                            NaN
# 15591                       NaN                            NaN
# 15592                       NaN                            NaN
# 15593                       NaN                            NaN
# 15618                       NaN                            NaN
# 15685                       NaN                            NaN
# 15688                       NaN                            NaN
# 15689                       NaN                            NaN
# 15719                       NaN                            NaN
# 15723                       NaN                            NaN
# 15725                       NaN                            NaN
# 15726                       NaN                            NaN
#
#       primary_votes_house_2016  primary_votes_house_2016_pct  \
# 42                         NaN                           NaN
# 43                         NaN                           NaN
# 44                         NaN                           NaN
# 45                         NaN                           NaN
# 46                         NaN                           NaN
# 47                         NaN                           NaN
# 48                         NaN                           NaN
# 49                         NaN                           NaN
# 50                         NaN                           NaN
# 51                         NaN                           NaN
# 52                         NaN                           NaN
# 53                         NaN                           NaN
# 54                         NaN                           NaN
# 55                         NaN                           NaN
# 56                         NaN                           NaN
# 57                         NaN                           NaN
# 58                         NaN                           NaN
# 59                         NaN                           NaN
# 60                         NaN                           NaN
# 61                         NaN                           NaN
# 62                         NaN                           NaN
# 63                         NaN                           NaN
# 64                         NaN                           NaN
# 65                         NaN                           NaN
# 66                         NaN                           NaN
# 67                         NaN                           NaN
# 68                         NaN                           NaN
# 69                         NaN                           NaN
# 70                         NaN                           NaN
# 71                         NaN                           NaN
# ...                        ...                           ...
# 15238                      NaN                           NaN
# 15244                   192227                      0.919548
# 15245                   192227                      0.919548
# 15254                    17814                      0.574460
# 15255                      NaN                           NaN
# 15275                    82984                      1.000000
# 15276                    82984                      1.000000
# 15277                    82984                      1.000000
# 15278                    82984                      1.000000
# 15279                    82984                      1.000000
# 15280                    82984                      1.000000
# 15295                      NaN                           NaN
# 15330                      NaN                           NaN
# 15331                      NaN                           NaN
# 15360                      NaN                           NaN
# 15491                      NaN                           NaN
# 15492                      NaN                           NaN
# 15493                      NaN                           NaN
# 15494                      NaN                           NaN
# 15591                      NaN                           NaN
# 15592                      NaN                           NaN
# 15593                      NaN                           NaN
# 15618                      NaN                           NaN
# 15685                    55889                      1.000000
# 15688                    49993                      0.897927
# 15689                    49993                      0.897927
# 15719                      NaN                           NaN
# 15723                    54958                      1.000000
# 15725                      NaN                           NaN
# 15726                      NaN                           NaN
#
#       primary_votes_all_2012 primary_votes_all_2012_pct
# 42                     14569                   0.803452
# 43                     14569                   0.803452
# 44                     14569                   0.803452
# 45                     14569                   0.803452
# 46                     14569                   0.803452
# 47                     14569                   0.803452
# 48                     14569                   0.803452
# 49                     14569                   0.803452
# 50                     14569                   0.803452
# 51                     14569                   0.803452
# 52                     14569                   0.803452
# 53                     14569                   0.803452
# 54                     14569                   0.803452
# 55                     14569                   0.803452
# 56                     14569                   0.803452
# 57                     14569                   0.803452
# 58                     14569                   0.803452
# 59                     14569                   0.803452
# 60                     14569                   0.803452
# 61                     14569                   0.803452
# 62                     14569                   0.803452
# 63                     14569                   0.803452
# 64                     14569                   0.803452
# 65                     14569                   0.803452
# 66                     14569                   0.803452
# 67                     14569                   0.803452
# 68                     14569                   0.803452
# 69                     14569                   0.803452
# 70                     14569                   0.803452
# 71                     14569                   0.803452
# ...                      ...                        ...
# 15238                    NaN                        NaN
# 15244                    NaN                        NaN
# 15245                    NaN                        NaN
# 15254                  10667                          1
# 15255                  59327                          1
# 15275                  12126                   0.584752
# 15276                  12126                   0.584752
# 15277                  12126                   0.584752
# 15278                  12126                   0.584752
# 15279                  12126                   0.584752
# 15280                  12126                   0.584752
# 15295                    NaN                        NaN
# 15330                    NaN                        NaN
# 15331                    NaN                        NaN
# 15360              Unopposed                        NaN
# 15491                    NaN                        NaN
# 15492                    NaN                        NaN
# 15493                    NaN                        NaN
# 15494                    NaN                        NaN
# 15591                    NaN                        NaN
# 15592                    NaN                        NaN
# 15593                    NaN                        NaN
# 15618                  41230                   0.470302
# 15685                  51113                   0.999687
# 15688                  35350                          1
# 15689                  35350                          1
# 15719                    NaN                        NaN
# 15723                  64008                          1
# 15725                  35008                   0.829298
# 15726                  35008                   0.829298
#
# [2310 rows x 19 columns]

# %% [markdown]
# Now, our dataframe looks like this:

# %%
_t.head(1)
# Out:
#         author_name_slug              context       label  \
# 0  meghan-ashford-grooms  in a Web site video  pants-fire
#
#            ruling_date speaker_current_job speaker_first_name  \
# 0  2010-01-12T15:52:21                            Barbara Ann
#
#   speaker_home_state speaker_last_name  \
# 0                            Radnofsky
#
#                                                                statement  \
# 0  The attorney general requires that rape victims pay for the rape kit.
#
#   statement_date  statement_id statement_type statement_type_description  \
# 0     2009-10-22           1.0          Claim                 blog post
#
#    label_as_nb clean_context  statement_year       speaker_full_name  \
# 0         16.0        others          2009.0  Radnofsky, Barbara Ann
#
#   speakers_job_title_cleaned CANDIDATE NAME primary_votes_senate_2014  \
# 0                                       NaN                       NaN
#
#    primary_votes_senate_2014_pct primary_votes_house_2014  \
# 0                            NaN                      NaN
#
#    primary_votes_house_2014_pct primary_votes_senate_2016  \
# 0                           NaN                       NaN
#
#    primary_votes_senate_2016_pct primary_votes_house_2016  \
# 0                            NaN                      NaN
#
#    primary_votes_house_2016_pct primary_votes_all_2012  \
# 0                           NaN                    NaN
#
#   primary_votes_all_2012_pct
# 0                        NaN

# %% [markdown]
# # County Data

# %%
# load data file
county_raw = pd.read_csv(f"{directory_county_data}/acs2015_county_data.csv")
US_states = county_raw['State'].unique()
county_raw.head()
# Out:
#    CensusId    State   County  TotalPop    Men  Women  Hispanic  White  Black  \
# 0      1001  Alabama  Autauga     55221  26745  28476       2.6   75.8   18.5
# 1      1003  Alabama  Baldwin    195121  95314  99807       4.5   83.1    9.5
# 2      1005  Alabama  Barbour     26932  14497  12435       4.6   46.2   46.7
# 3      1007  Alabama     Bibb     22604  12073  10531       2.2   74.5   21.4
# 4      1009  Alabama   Blount     57710  28512  29198       8.6   87.9    1.5
#
#    Native  Asian  Pacific  Citizen   Income  IncomeErr  IncomePerCap  \
# 0     0.4    1.0      0.0    40725  51281.0     2391.0         24974
# 1     0.6    0.7      0.0   147695  50254.0     1263.0         27317
# 2     0.2    0.4      0.0    20714  32964.0     2973.0         16824
# 3     0.4    0.1      0.0    17495  38678.0     3995.0         18431
# 4     0.3    0.1      0.0    42345  45813.0     3141.0         20532
#
#    IncomePerCapErr  Poverty  ChildPoverty  Professional  Service  Office  \
# 0             1080     12.9          18.6          33.2     17.0    24.2
# 1              711     13.4          19.2          33.1     17.7    27.1
# 2              798     26.7          45.3          26.8     16.1    23.1
# 3             1618     16.8          27.9          21.5     17.9    17.8
# 4              708     16.7          27.2          28.5     14.1    23.9
#
#    Construction  Production  Drive  Carpool  Transit  Walk  OtherTransp  \
# 0           8.6        17.1   87.5      8.8      0.1   0.5          1.3
# 1          10.8        11.2   84.7      8.8      0.1   1.0          1.4
# 2          10.8        23.1   83.8     10.9      0.4   1.8          1.5
# 3          19.0        23.7   83.2     13.5      0.5   0.6          1.5
# 4          13.5        19.9   84.9     11.2      0.4   0.9          0.4
#
#    WorkAtHome  MeanCommute  Employed  PrivateWork  PublicWork  SelfEmployed  \
# 0         1.8         26.5     23986         73.6        20.9           5.5
# 1         3.9         26.4     85953         81.5        12.3           5.8
# 2         1.6         24.1      8597         71.8        20.8           7.3
# 3         0.7         28.8      8294         76.8        16.1           6.7
# 4         2.3         34.9     22189         82.0        13.5           4.2
#
#    FamilyWork  Unemployment
# 0         0.0           7.6
# 1         0.4           7.5
# 2         0.1          17.6
# 3         0.4           8.3
# 4         0.4           7.7

# %% [markdown]
# # DATA SET COMPLETE

# %% [markdown]
# At this point, we collected all the columns we need. Let's see how we can clean them:

# %%
median_speaker_value = _t.groupby(['statement_year', 'speaker_full_name'])['label_as_nb'].median().reset_index()

# %%
median_speaker_value[median_speaker_value['statement_year'] == 2016]
# Out:
#       statement_year  \
# 4637          2016.0
# 4638          2016.0
# 4639          2016.0
# 4640          2016.0
# 4641          2016.0
# 4642          2016.0
# 4643          2016.0
# 4644          2016.0
# 4645          2016.0
# 4646          2016.0
# 4647          2016.0
# 4648          2016.0
# 4649          2016.0
# 4650          2016.0
# 4651          2016.0
# 4652          2016.0
# 4653          2016.0
# 4654          2016.0
# 4655          2016.0
# 4656          2016.0
# 4657          2016.0
# 4658          2016.0
# 4659          2016.0
# 4660          2016.0
# 4661          2016.0
# 4662          2016.0
# 4663          2016.0
# 4664          2016.0
# 4665          2016.0
# 4666          2016.0
# ...              ...
# 5259          2016.0
# 5260          2016.0
# 5261          2016.0
# 5262          2016.0
# 5263          2016.0
# 5264          2016.0
# 5265          2016.0
# 5266          2016.0
# 5267          2016.0
# 5268          2016.0
# 5269          2016.0
# 5270          2016.0
# 5271          2016.0
# 5272          2016.0
# 5273          2016.0
# 5274          2016.0
# 5275          2016.0
# 5276          2016.0
# 5277          2016.0
# 5278          2016.0
# 5279          2016.0
# 5280          2016.0
# 5281          2016.0
# 5282          2016.0
# 5283          2016.0
# 5284          2016.0
# 5285          2016.0
# 5286          2016.0
# 5287          2016.0
# 5288          2016.0
#
#                                                        speaker_full_name  \
# 4637                                                        , Foodmentum
# 4638                                                    My City Bikes,
# 4639                                        18% of the American public,
# 4640                                                   57 campaign, Stop
# 4641                                            ACLU of North Carolina,
# 4642                                                     AFSCME People,
# 4643                                                           AFSCME,
# 4644                                                        Abbott, Greg
# 4645                                                        Abele, Chris
# 4646                                              Action Fund, ClearPath
# 4647                                                       Adkins, Janet
# 4648                                                        Adler, Steve
# 4649                                                         Aiken, Clay
# 4650                                                       Allen, Travis
# 4651                                                    AlternativePAC,
# 4652                                                      America, Oxfam
# 4653                                              American Future Fund,
# 4654                                                American Unity PAC,
# 4655                                               AmericanPoliticNews,
# 4656                  Americans For Prosperity, North Carolina chapter,
# 4657                                       Americans United for Change,
# 4658                                          Americans for Prosperity,
# 4659                                 Americans for Prosperity: Florida,
# 4660                               Americans for Responsible Solutions,
# 4661                                                      Angle, Sharron
# 4662                                                         Annan, Kofi
# 4663                                     Arizona Grassroots Action PAC,
# 4664                                                        Assini, Mark
# 4665                                      Association of Business, Texas
# 4666                                                        Austin, Bike
# ...                                                                  ...
# 5259                                                Wisconsin Jobs Now,
# 5260                                  Wisconsin Working Families Party,
# 5261                                            Without Borders, Doctors
# 5262                                                        Wittman, Rob
# 5263                                                          Wolf, Tom
# 5264                                                     Wolfowitz, Paul
# 5265                                                        Woods, James
# 5266                                                      Workman, Ritch
# 5267                                       Works for Austin, Ridesharing
# 5268                                                       Wright, Robin
# 5269                                                   Yarborough, Larry
# 5270                                                         Young, Dana
# 5271                                             Your Choice Colorado ,
# 5272                                                    Zappala, Stephen
# 5273                                                         Ziemer, Tim
# 5274                                                      Zimmerman, Roy
# 5275  and House Republican Organization, Citizens for Michael McAuliffe
# 5276                                                campaign , No on 56
# 5277        campaign against condom requirement in adult films, No on 60
# 5278          campaign to abolish California's death penalty, Yes On 62
# 5279                                                     de Blasio, Bill
# 5280                                                      de León, Kevin
# 5281                                for Illinois PAC , Independent Voice
# 5282                               for Research on Globalization, Centre
# 5283                             for Responsible Drug Policy, Arizonans
# 5284                                              media reports, Various
# 5285                                                media reports, Viral
# 5286                                                         on 55, Yes
# 5287                                                          on 67, No
# 5288                                                       tmzbreaking,
#
#       label_as_nb
# 4637          8.0
# 4638         14.0
# 4639          6.0
# 4640         12.0
# 4641          6.0
# 4642          8.0
# 4643         10.0
# 4644         14.0
# 4645         15.0
# 4646         12.0
# 4647          8.0
# 4648         14.0
# 4649          8.0
# 4650         16.0
# 4651          6.0
# 4652          8.0
# 4653         13.0
# 4654         14.0
# 4655         16.0
# 4656         10.0
# 4657         10.0
# 4658         14.0
# 4659         12.0
# 4660         10.0
# 4661         12.0
# 4662          8.0
# 4663         10.0
# 4664         14.0
# 4665         12.0
# 4666         12.0
# ...           ...
# 5259         16.0
# 5260         14.0
# 5261          9.0
# 5262         14.0
# 5263         12.0
# 5264         12.0
# 5265         11.0
# 5266         12.0
# 5267         14.0
# 5268         12.0
# 5269          8.0
# 5270         10.0
# 5271         10.0
# 5272         10.0
# 5273          8.0
# 5274         10.0
# 5275         12.0
# 5276         12.0
# 5277         10.0
# 5278          6.0
# 5279         10.0
# 5280          8.0
# 5281         12.0
# 5282         14.0
# 5283         11.0
# 5284          6.0
# 5285         12.0
# 5286         12.0
# 5287         10.0
# 5288         16.0
#
# [652 rows x 3 columns]

# %% [markdown]
# ### Non-People Speakers Handling

# %% [markdown]
# Removing non-people (_tweets, facebook posts, etc._) from the dataset:

# %%
from nltk import download
download('punkt')
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize
from nltk import sent_tokenize
from collections import Counter

model = 'nlp/stanford-ner-2018-10-16/classifiers/english.all.3class.distsim.crf.ser.gz'
jar = 'nlp/stanford-ner-2018-10-16/stanford-ner-3.9.2.jar'
st = StanfordNERTagger(model, jar, encoding='utf-8')

def get_tag(speaker):
    ner_tag = 0
    if type(speaker) == str:
        full_speaker_name = speaker.replace("-", " ").title()

        for sent in sent_tokenize(full_speaker_name):
            tokens = word_tokenize(sent)
            tags = st.tag(tokens)
            
        ner_tag= Counter(dict(tags).values()).most_common(1)[0][0]
        print(tags, " --> ", ner_tag)
    return ner_tag
    

# just to see if/how it works
word = "Twitter-Post-Anna"
get_tag(word)

full_speaker_name = "Barack-Obama"
get_tag(full_speaker_name)

full_speaker_name = 0
get_tag(full_speaker_name)
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Jelena
# [nltk_data]     Banjac\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [('Twitter', 'ORGANIZATION'), ('Post', 'ORGANIZATION'), ('Anna', 'PERSON')]  -->  ORGANIZATION
# [('Barack', 'PERSON'), ('Obama', 'PERSON')]  -->  PERSON
# 0

# %%
_t["speaker"] = _t.apply(lambda row: "-".join([str(row["speaker_first_name"]).strip().replace(" ","-").lower(), str(row["speaker_last_name"]).strip().replace(" ","-").lower()]), axis=1)
_t["speaker"] = _t.apply(lambda row: row["speaker"][1:] if row["speaker"].startswith("-") else row["speaker"][:-1] if row["speaker"].endswith("-") else row["speaker"], axis=1)

# %%
import os.path

file_path = 'nlp/speaker_tags_lg.json'

if not os.path.exists(file_path):
    print(f"Total number of values to classify: {len(_t['speaker'].value_counts().index)}")

    words_with_tags = {}
    for word in _t['speaker'].value_counts().index:
        words_with_tags[word] = get_tag(word)
    
    # save tags, since it took ~3h to tag all 3214 unique speakers
    with open(file_path, 'w') as fp:
        json.dump(words_with_tags, fp, indent=4)
else:
    with open(file_path, 'r') as f:
        words_with_tags = json.load(f)
    print(f"Total number of classified values (from file): {len(words_with_tags)}")
# Out:
# Total number of classified values (from file): 3962

# %%
_t["speaker_tag"] = _t.apply(lambda row: words_with_tags.get(row['speaker'], "UNKNOWN") if not pd.isnull(row['speaker']) else row['speaker'], axis=1)
_t[['speaker','speaker_tag']].drop_duplicates()
# Out:
#                                          speaker   speaker_tag
# 0                          barbara-ann-radnofsky        PERSON
# 1                                  mike-huckabee        PERSON
# 42                              michele-bachmann        PERSON
# 103                         leticia-van-de-putte        PERSON
# 115    wisconsin-professional-police-association  ORGANIZATION
# 117                                   allen-west        PERSON
# 143                           georgians-together             O
# 145                                  thom-tillis        PERSON
# 151                                   reza-aslan        PERSON
# 152                  republican-party-of-florida  ORGANIZATION
# 189                                  greg-abbott        PERSON
# 245             republican-governors-association             O
# 265                                   mary-burke        PERSON
# 299                                arlen-specter        PERSON
# 302                                 barack-obama        PERSON
# 921          americans-for-responsible-solutions             O
# 925                                 jorge-elorza        PERSON
# 930                                  george-will        PERSON
# 963                               lindsey-graham        PERSON
# 975                 democratic-party-of-virginia  ORGANIZATION
# 982                               wayne-lapierre        PERSON
# 991                   national-rifle-association  ORGANIZATION
# 1011                             terri-lynn-land        PERSON
# 1012                                 john-cornyn        PERSON
# 1043                                david-perdue        PERSON
# 1063                                 dick-cheney        PERSON
# 1080                               charlie-crist        PERSON
# 1170                              gloria-steinem        PERSON
# 1171                                   kay-hagan        PERSON
# 1175                                 nathan-deal        PERSON
# ...                                          ...           ...
# 15744                               john-padgett        PERSON
# 15745                             michael-medved        PERSON
# 15746                             cato-institute  ORGANIZATION
# 15747                            anthony-johnson        PERSON
# 15748                             martha-raddatz        PERSON
# 15749                                cornel-west        PERSON
# 15750                           marc-lamont-hill        PERSON
# 15751                        truth-in-accounting             O
# 15752                          drug-free-america             O
# 15753                                burger-king        PERSON
# 15754                                  jody-hice        PERSON
# 15755                                 joe-garcia        PERSON
# 15757                            henry-kissinger        PERSON
# 15758                              maria-cardona        PERSON
# 15759                              connie-stokes        PERSON
# 15760                               shemia-fagan        PERSON
# 15761                             michael-hayden        PERSON
# 15762                                  mike-wise        PERSON
# 15763                                  rhue-reis        PERSON
# 15764                                james-brown        PERSON
# 15765                              media-matters             O
# 15766                            mika-brzezinski        PERSON
# 15767                                jeff-amason        PERSON
# 15768                                 ryan-lizza        PERSON
# 15769                                  jay-wiley        PERSON
# 15770                               ralph-peters        PERSON
# 15771                              lz-granderson        PERSON
# 15772                                jane-harman        PERSON
# 15773                       william-benson-huber        PERSON
# 15774                                    nan-nan        PERSON
#
# [3962 rows x 2 columns]

# %% [markdown]
# Seems good, so now let's remove non-people from the dataset:

# %%
_t.shape
# Out:
# (21026, 31)

# %%
_t[_t['speaker_tag'] == "PERSON"].shape
# Out:
# (18194, 31)

# %%
_t[_t['speaker_tag'] == "UNKNOWN"].shape
# Out:
# (0, 31)

# %% [markdown]
# We see that there are ~5000 statements which are made by (speaker) _Twitter, Facebook, Blog post, Republican Party Texas, etc._

# %%
# removing non-people statements
# _t = _t[_t['speaker_tag'] == "PERSON"]

# %% [markdown]
# ### Clean-up Context

# %%
_t["context"].value_counts().index.values
# Out:
# array(['a tweet', 'an interview', 'a news release', ...,
#        'a press release from the Communication Workers of America',
#        ' Conference call with reporters', 'a CBS4 interview'],
#       dtype=object)

# %% [markdown]
# It would be good to try using the tool that would extract keywords from these phases. Let's use NLTK Rake:

# %%
from rake_nltk import Rake, Metric
from collections import Counter

def do_keyword_extraction(words, debug = False):
    if debug: print("---\n", words)
        
    rake_all = Rake()
    rake_all.extract_keywords_from_sentences(_t["context"].value_counts().index.values)

    word_degrees = dict(rake_all.get_word_degrees())
    
    r = Rake()
    r.extract_keywords_from_text(words)

    keywords = dict(r.get_word_degrees())
    
    if debug: print(keywords)
        
    for k, v in keywords.items():
        keywords[k] = word_degrees[k]
    
    if debug: print(keywords)
#     print(Counter(keywords).most_common(1))
#     print(Counter(keywords).most_common(1)[0])
    return Counter(keywords).most_common(1)[0] if len(Counter(keywords).most_common(1)) > 0 else "OTHER"

# %%
# try to see how it works
text_to_process = "a television interview"
do_keyword_extraction("an interview")
do_keyword_extraction("a television interview")
do_keyword_extraction("a TV interview")
# Out:
# ('interview', 219)

# %%
_t["context_tag"] = _t.apply(lambda row: do_keyword_extraction(row['context']) if not pd.isnull(row['context']) else row['context'], axis=1)

# %%
context_tags = _t[['context','context_tag']]['context_tag'].value_counts()
print(f"Number of different context tags is {len(context_tags)}")
context_tags
# Out:
# Number of different context tags is 345
# (interview, 219)       1753
# (news, 478)            1282
# (campaign, 533)        1177
# (speech, 226)          1107
# (press, 304)           1017
# (debate, 476)          1010
# (ad, 240)               973
# (post, 159)             631
# (tweet, 41)             573
# (radio, 236)            315
# (state, 247)            314
# (house, 309)            293
# (show, 265)             255
# (senate, 311)           203
# (email, 82)             201
# (headline, 9)           178
# OTHER                   166
# (website, 153)          165
# (article, 108)          158
# (mail, 73)              158
# (column, 63)            155
# (meeting, 184)          154
# (statement, 86)         147
# (web, 163)              143
# (video, 144)            142
# (new, 251)              128
# (letter, 40)            103
# (internet, 45)           99
# (op, 50)                 96
# (comments, 29)           87
#                        ...
# (.,, 18)                  1
# (executive, 24)           1
# (retweet, 1)              1
# (reilly, 6)               1
# (church, 9)               1
# (los, 5)                  1
# (first, 41)               1
# (advisory, 6)             1
# (david, 23)               1
# (televised, 27)           1
# (poll, 5)                 1
# (recall, 4)               1
# (workers, 11)             1
# (reporter, 15)            1
# (full, 10)                1
# (island, 46)              1
# (presidential, 168)       1
# (proposal, 18)            1
# (voicemail, 1)            1
# (platform, 11)            1
# (columbia, 6)             1
# (virginia, 3)             1
# (friends, 13)             1
# (snapchat, 1)             1
# (flyer, 12)               1
# (image, 14)               1
# (politico, 11)            1
# (nevada, 9)               1
# (document, 15)            1
# (graphic, 18)             1
# Name: context_tag, Length: 345, dtype: int64

# %% [markdown]
# We see that the number of context tags is 271, which is a preatty big number. Let's consider decreasing this number and make smaller groups.

# %% [markdown]
# ## Dataset we will use for our visualizations

# %%
_t.head()
# Out:
#         author_name_slug                            context        label  \
# 0  meghan-ashford-grooms                in a Web site video   pants-fire
# 1              jody-kyle              an interview on MSNBC         true
# 2    michael-van-sickler                                     barely-true
# 3         louis-jacobson                            a video  barely-true
# 4         lauren-carroll  an interview on "Fox News Sunday"  barely-true
#
#            ruling_date speaker_current_job speaker_first_name  \
# 0  2010-01-12T15:52:21                            Barbara Ann
# 1  2007-10-03T00:00:00              author               Mike
# 2  2007-10-05T00:00:00              author               Mike
# 3  2015-05-04T17:10:31              author               Mike
# 4  2015-05-29T10:00:50              author               Mike
#
#   speaker_home_state speaker_last_name  \
# 0                            Radnofsky
# 1           Arkansas          Huckabee
# 2           Arkansas          Huckabee
# 3           Arkansas          Huckabee
# 4           Arkansas          Huckabee
#
#                                                                                                                                                                                                     statement  \
# 0                                                                                                                                       The attorney general requires that rape victims pay for the rape kit.
# 1                                                                                               Hes sued gun manufacturers. He was supportive of Brady. He was supportive of things like assault weapon bans.
# 2  The reality is, with a $2 trillion-a-year health care budget, were spending more on health care, nearly 17 percent of our gross domestic product, versus 3.8 percent of GDP on the entire military budget.
# 3                                                                                                                  Says he raised average family income by 50 percent during his tenure as Arkansas governor.
# 4                                                                                                                     The Supreme Court can&rsquo;t overrule the other two branches&nbsp;of government.&nbsp;
#
#   statement_date  statement_id statement_type  \
# 0     2009-10-22           1.0          Claim
# 1     2007-09-21         100.0         Attack
# 2     2007-09-02         105.0          Claim
# 3     2015-05-01       10796.0          Claim
# 4     2015-05-24       10879.0          Claim
#
#                      statement_type_description  label_as_nb clean_context  \
# 0                                    blog post          16.0        others
# 1  <p>\r\n\tA criticism of a candidate.</p>\r\n          6.0        others
# 2                                    blog post          12.0        others
# 3                                    blog post          12.0        others
# 4                                    blog post          12.0           fox
#
#    statement_year       speaker_full_name speakers_job_title_cleaned  \
# 0          2009.0  Radnofsky, Barbara Ann
# 1          2007.0          Huckabee, Mike                     author
# 2          2007.0          Huckabee, Mike                     author
# 3          2015.0          Huckabee, Mike                     author
# 4          2015.0          Huckabee, Mike                     author
#
#   CANDIDATE NAME primary_votes_senate_2014  primary_votes_senate_2014_pct  \
# 0            NaN                       NaN                            NaN
# 1            NaN                       NaN                            NaN
# 2            NaN                       NaN                            NaN
# 3            NaN                       NaN                            NaN
# 4            NaN                       NaN                            NaN
#
#   primary_votes_house_2014  primary_votes_house_2014_pct  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
#
#   primary_votes_senate_2016  primary_votes_senate_2016_pct  \
# 0                       NaN                            NaN
# 1                       NaN                            NaN
# 2                       NaN                            NaN
# 3                       NaN                            NaN
# 4                       NaN                            NaN
#
#   primary_votes_house_2016  primary_votes_house_2016_pct  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                      NaN                           NaN
# 3                      NaN                           NaN
# 4                      NaN                           NaN
#
#   primary_votes_all_2012 primary_votes_all_2012_pct                speaker  \
# 0                    NaN                        NaN  barbara-ann-radnofsky
# 1                    NaN                        NaN          mike-huckabee
# 2                    NaN                        NaN          mike-huckabee
# 3                    NaN                        NaN          mike-huckabee
# 4                    NaN                        NaN          mike-huckabee
#
#   speaker_tag       context_tag
# 0      PERSON        (web, 163)
# 1      PERSON  (interview, 219)
# 2      PERSON             OTHER
# 3      PERSON      (video, 144)
# 4      PERSON       (news, 478)

# %%
_t.shape
# Out:
# (21026, 32)

# %%
_t.to_json('data/liar_dataset.json')

# %%
# TODO: make smaller context groups, ideally around 10

# %%
# TODO: implement tagging on the cleaned jobs as well

# %%
# TODO: plot the answers from research questions we have

# %% [markdown]
# ## Some initial insights

# %%
_t['sum_not_so_true'] = _t['pants_on_fire_counts']/(_t['barely_true_counts'] + _t['false_counts'] + _t['half_true_counts'] + _t['mostly_true_counts'] + _t['pants_on_fire_counts'])
number_of_party_affiliation = _t.groupby('party_affiliation')['sum_not_so_true'].sum().sort_values(ascending=False)
number_of_party_affiliation

# %% [markdown]
# Here are the `party_affiliations` who most lie ordered by their proportion of lies. But we already know that the 2 dominant parties in USA are republican and democrat. We see that there are lots of unknown party affiliations from which we can make identify 2 possibilities

# %%
number_of_party_affiliation = _t.groupby(['speaker'])['sum_not_so_true'].sum().sort_values(ascending=False)
number_of_party_affiliation.head(10)

# %% [markdown]
# Looking at the dataset content, people above are sorted quantity of lies.

# %%
all_contexts = _t['context_tag'].unique()
nb_elements_context = _t.groupby(['context_tag'])['context_tag'].count().sort_values(ascending=False)
nb_elements_context.head(50)

# %% [markdown]
# Looking at the context, it seems that people lie the most during the interviews, then speech, after debates, and so on...
